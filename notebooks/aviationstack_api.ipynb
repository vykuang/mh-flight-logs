# %% [markdown]
# # Testing aviationstack's api

# %%
import os
import requests
import sqlite3
import json
from pathlib import Path
from dotenv import load_dotenv

# %%
load_dotenv(dotenv_path="../.env")
AVIATION_API_KEY = os.getenv("AVIATION_API_KEY", "")

# %% [markdown]
# ## Retrieving flights for malaysia airlines

# %%
# basic plan must use http, not https
AVIATION_API_URL = "http://api.aviationstack.com/v1/"
AIRLINE_API_URL = AVIATION_API_URL + "airlines"
params = {
    "access_key": AVIATION_API_KEY,
}

# %%
api_result = requests.get(AIRLINE_API_URL, params)
airline_response = api_result.json()
airline_response
# Out:
# {'pagination': {'offset': 0, 'limit': 100, 'count': 100, 'total': 13130},
#  'data': [{'id': '1',
#    'fleet_average_age': '10.9',
#    'airline_id': '1',
#    'callsign': 'AMERICAN',
#    'hub_code': 'DFW',
#    'iata_code': 'AA',
#    'icao_code': 'AAL',
#    'country_iso2': 'US',
#    'date_founded': '1934',
#    'iata_prefix_accounting': '1',
#    'airline_name': 'American Airlines',
#    'country_name': 'United States',
#    'fleet_size': '963',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '2',
#    'fleet_average_age': '17',
#    'airline_id': '2',
#    'callsign': 'DELTA',
#    'hub_code': 'ATL',
#    'iata_code': 'DL',
#    'icao_code': 'DAL',
#    'country_iso2': 'US',
#    'date_founded': '1928',
#    'iata_prefix_accounting': '6',
#    'airline_name': 'Delta Air Lines',
#    'country_name': 'United States',
#    'fleet_size': '823',
#    'status': 'active',
#    'type': 'scheduled,division'},
#   {'id': '3',
#    'fleet_average_age': '13.8',
#    'airline_id': '3',
#    'callsign': 'UNITED',
#    'hub_code': 'ORD',
#    'iata_code': 'UA',
#    'icao_code': 'UAL',
#    'country_iso2': 'US',
#    'date_founded': '1931',
#    'iata_prefix_accounting': '16',
#    'airline_name': 'United Airlines',
#    'country_name': 'United States',
#    'fleet_size': '715',
#    'status': 'active',
#    'type': 'scheduled,division'},
#   {'id': '4',
#    'fleet_average_age': '12.3',
#    'airline_id': '4',
#    'callsign': 'SOUTHWEST',
#    'hub_code': 'DAL',
#    'iata_code': 'WN',
#    'icao_code': 'SWA',
#    'country_iso2': 'UM',
#    'date_founded': '1967',
#    'iata_prefix_accounting': '526',
#    'airline_name': 'Southwest Airlines Co.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '712',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '5',
#    'fleet_average_age': '6.9',
#    'airline_id': '5',
#    'callsign': 'CHINA SOUTHERN',
#    'hub_code': 'CAN',
#    'iata_code': 'CZ',
#    'icao_code': 'CSN',
#    'country_iso2': 'CN',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '784',
#    'airline_name': 'China Southern Airlines',
#    'country_name': 'China',
#    'fleet_size': '498',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '6',
#    'fleet_average_age': '8.4',
#    'airline_id': '6',
#    'callsign': 'CHINA EASTERN',
#    'hub_code': 'PVG',
#    'iata_code': 'MU',
#    'icao_code': 'CES',
#    'country_iso2': 'CN',
#    'date_founded': '1988',
#    'iata_prefix_accounting': '781',
#    'airline_name': 'China Eastern',
#    'country_name': 'China',
#    'fleet_size': '407',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '7',
#    'fleet_average_age': '11.1',
#    'airline_id': '7',
#    'callsign': 'SKYWEST',
#    'hub_code': 'SLC',
#    'iata_code': 'OO',
#    'icao_code': 'SKW',
#    'country_iso2': 'UM',
#    'date_founded': '1972',
#    'iata_prefix_accounting': '302',
#    'airline_name': 'SkyWest Airlines',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '382',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '8',
#    'fleet_average_age': '6.2',
#    'airline_id': '8',
#    'callsign': 'AIR CHINA',
#    'hub_code': 'PEK',
#    'iata_code': 'CA',
#    'icao_code': 'CCA',
#    'country_iso2': 'CN',
#    'date_founded': '1988',
#    'iata_prefix_accounting': '999',
#    'airline_name': 'Air China Limited',
#    'country_name': 'China',
#    'fleet_size': '369',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '9',
#    'fleet_average_age': '21.9',
#    'airline_id': '9',
#    'callsign': 'FEDEX',
#    'hub_code': 'MEM',
#    'iata_code': 'FX',
#    'icao_code': 'FDX',
#    'country_iso2': 'US',
#    'date_founded': '1971',
#    'iata_prefix_accounting': '23',
#    'airline_name': 'Federal Express',
#    'country_name': 'United States',
#    'fleet_size': '367',
#    'status': 'active',
#    'type': 'scheduled,cargo'},
#   {'id': '10',
#    'fleet_average_age': '6.4',
#    'airline_id': '10',
#    'callsign': 'RYANAIR',
#    'hub_code': 'STN',
#    'iata_code': 'FR',
#    'icao_code': 'RYR',
#    'country_iso2': 'IE',
#    'date_founded': '1985',
#    'iata_prefix_accounting': '224',
#    'airline_name': 'Ryanair Ltd.',
#    'country_name': 'Ireland',
#    'fleet_size': '353',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '11',
#    'fleet_average_age': '13.2',
#    'airline_id': '11',
#    'callsign': 'JET LINK',
#    'hub_code': None,
#    'iata_code': 'XE',
#    'icao_code': 'BTA',
#    'country_iso2': 'UM',
#    'date_founded': None,
#    'iata_prefix_accounting': None,
#    'airline_name': 'Expressjet',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '319',
#    'status': 'active',
#    'type': None},
#   {'id': '12',
#    'fleet_average_age': '6.3',
#    'airline_id': '12',
#    'callsign': 'TURKISH',
#    'hub_code': 'IST',
#    'iata_code': 'TK',
#    'icao_code': 'THY',
#    'country_iso2': 'TR',
#    'date_founded': '1933',
#    'iata_prefix_accounting': '235',
#    'airline_name': 'THY - Turkish Airlines',
#    'country_name': 'Turkey',
#    'fleet_size': '285',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '13',
#    'fleet_average_age': '10.9',
#    'airline_id': '13',
#    'callsign': 'LUFTHANSA',
#    'hub_code': 'FRA',
#    'iata_code': 'LH',
#    'icao_code': 'GEC',
#    'country_iso2': 'DE',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '20',
#    'airline_name': 'Lufthansa Cargo',
#    'country_name': 'Germany',
#    'fleet_size': '276',
#    'status': 'active',
#    'type': 'scheduled,cargo'},
#   {'id': '14',
#    'fleet_average_age': '12.7',
#    'airline_id': '14',
#    'callsign': 'SPEEDBIRD',
#    'hub_code': 'LHR',
#    'iata_code': 'BA',
#    'icao_code': 'BAW',
#    'country_iso2': 'GB',
#    'date_founded': '1974',
#    'iata_prefix_accounting': '125',
#    'airline_name': 'British Airways',
#    'country_name': 'United Kingdom',
#    'fleet_size': '265',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '15',
#    'fleet_average_age': '6.1',
#    'airline_id': '15',
#    'callsign': 'EMIRATES',
#    'hub_code': 'DXB',
#    'iata_code': 'EK',
#    'icao_code': 'UAE',
#    'country_iso2': 'AE',
#    'date_founded': '1985',
#    'iata_prefix_accounting': '176',
#    'airline_name': 'Emirates',
#    'country_name': 'United Arab Emirates',
#    'fleet_size': '249',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '16',
#    'fleet_average_age': '17.5',
#    'airline_id': '16',
#    'callsign': 'UPS',
#    'hub_code': 'SDF',
#    'iata_code': '5X',
#    'icao_code': 'UPS',
#    'country_iso2': 'US',
#    'date_founded': '1907',
#    'iata_prefix_accounting': '406',
#    'airline_name': 'UPS Airlines',
#    'country_name': 'United States',
#    'fleet_size': '237',
#    'status': 'active',
#    'type': 'cargo'},
#   {'id': '17',
#    'fleet_average_age': '6.6',
#    'airline_id': '17',
#    'callsign': 'EASY',
#    'hub_code': 'LGW',
#    'iata_code': 'U2',
#    'icao_code': 'EZY',
#    'country_iso2': 'GB',
#    'date_founded': '1995',
#    'iata_prefix_accounting': None,
#    'airline_name': 'Easyjet Airline Company Limited',
#    'country_name': 'United Kingdom',
#    'fleet_size': '228',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '18',
#    'fleet_average_age': '11.7',
#    'airline_id': '18',
#    'callsign': 'AIRFRANS',
#    'hub_code': 'CDG',
#    'iata_code': 'AF',
#    'icao_code': 'AFR',
#    'country_iso2': 'FR',
#    'date_founded': '1933',
#    'iata_prefix_accounting': '57',
#    'airline_name': 'Air France',
#    'country_name': 'France',
#    'fleet_size': '226',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '19',
#    'fleet_average_age': '8.7',
#    'airline_id': '19',
#    'callsign': 'JETBLUE',
#    'hub_code': 'JFK',
#    'iata_code': 'B6',
#    'icao_code': 'JBU',
#    'country_iso2': 'US',
#    'date_founded': '2000',
#    'iata_prefix_accounting': '279',
#    'airline_name': 'JetBlue',
#    'country_name': 'United States',
#    'fleet_size': '218',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '20',
#    'fleet_average_age': '9.5',
#    'airline_id': '20',
#    'callsign': 'ALL NIPPON',
#    'hub_code': 'HND',
#    'iata_code': 'NH',
#    'icao_code': 'ANA',
#    'country_iso2': 'JP',
#    'date_founded': '1952',
#    'iata_prefix_accounting': '205',
#    'airline_name': 'All Nippon Airways',
#    'country_name': 'Japan',
#    'fleet_size': '206',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '21',
#    'fleet_average_age': '5.7',
#    'airline_id': '21',
#    'callsign': 'QATARI',
#    'hub_code': 'DOH',
#    'iata_code': 'QR',
#    'icao_code': 'QTR',
#    'country_iso2': 'QA',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '157',
#    'airline_name': 'Qatar Airways',
#    'country_name': 'Qatar',
#    'fleet_size': '176',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '22',
#    'fleet_average_age': '11.6',
#    'airline_id': '22',
#    'callsign': 'ENVOY',
#    'hub_code': 'DFW',
#    'iata_code': 'MQ',
#    'icao_code': 'ENY',
#    'country_iso2': 'UM',
#    'date_founded': '2014',
#    'iata_prefix_accounting': '93',
#    'airline_name': 'Envoy Air Inc.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '171',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '23',
#    'fleet_average_age': '4.3',
#    'airline_id': '23',
#    'callsign': 'AEROFLOT',
#    'hub_code': 'SVO',
#    'iata_code': 'SU',
#    'icao_code': 'AFL',
#    'country_iso2': 'RU',
#    'date_founded': '1923',
#    'iata_prefix_accounting': '555',
#    'airline_name': 'Aeroflot',
#    'country_name': 'Russia',
#    'fleet_size': '168',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '24',
#    'fleet_average_age': '5.8',
#    'airline_id': '24',
#    'callsign': 'SHENZHEN AIR',
#    'hub_code': 'SZX',
#    'iata_code': 'ZH',
#    'icao_code': 'CSZ',
#    'country_iso2': 'CN',
#    'date_founded': '1992',
#    'iata_prefix_accounting': '479',
#    'airline_name': 'Shenzhen Airlines',
#    'country_name': 'China',
#    'fleet_size': '165',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '25',
#    'fleet_average_age': '25',
#    'airline_id': '25',
#    'callsign': 'AIR CANADA',
#    'hub_code': 'YYZ',
#    'iata_code': 'AC',
#    'icao_code': 'ACA',
#    'country_iso2': 'CA',
#    'date_founded': '2001',
#    'iata_prefix_accounting': '14',
#    'airline_name': 'Air Canada',
#    'country_name': 'Canada',
#    'fleet_size': '164',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '26',
#    'fleet_average_age': '7.4',
#    'airline_id': '26',
#    'callsign': 'TAM',
#    'hub_code': 'CGH',
#    'iata_code': 'JJ',
#    'icao_code': 'TAM',
#    'country_iso2': 'BR',
#    'date_founded': '1976',
#    'iata_prefix_accounting': '957',
#    'airline_name': 'TAM Linhas Aereas',
#    'country_name': 'Brazil',
#    'fleet_size': '163',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '27',
#    'fleet_average_age': '9',
#    'airline_id': '27',
#    'callsign': 'JAPANAIR',
#    'hub_code': 'HND',
#    'iata_code': 'JL',
#    'icao_code': 'JAL',
#    'country_iso2': 'JP',
#    'date_founded': '1951',
#    'iata_prefix_accounting': '131',
#    'airline_name': 'Japan Airlines',
#    'country_name': 'Japan',
#    'fleet_size': '163',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '28',
#    'fleet_average_age': '9.5',
#    'airline_id': '28',
#    'callsign': 'KOREANAIR',
#    'hub_code': 'ICN',
#    'iata_code': 'KE',
#    'icao_code': 'KAL',
#    'country_iso2': 'KR',
#    'date_founded': '1962',
#    'iata_prefix_accounting': '180',
#    'airline_name': 'Korean Air',
#    'country_name': 'South Korea',
#    'fleet_size': '159',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '29',
#    'fleet_average_age': '9.5',
#    'airline_id': '29',
#    'callsign': 'ALASKA',
#    'hub_code': 'SEA',
#    'iata_code': 'AS',
#    'icao_code': 'ASA',
#    'country_iso2': 'US',
#    'date_founded': '1932',
#    'iata_prefix_accounting': '27',
#    'airline_name': 'Alaska Airlines',
#    'country_name': 'United States',
#    'fleet_size': '156',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '30',
#    'fleet_average_age': '4.9',
#    'airline_id': '30',
#    'callsign': 'HAINAN',
#    'hub_code': 'HAK',
#    'iata_code': 'HU',
#    'icao_code': 'CHH',
#    'country_iso2': 'CN',
#    'date_founded': '1989',
#    'iata_prefix_accounting': '880',
#    'airline_name': 'Hainan Airlines',
#    'country_name': 'China',
#    'fleet_size': '155',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '31',
#    'fleet_average_age': '11.1',
#    'airline_id': '31',
#    'callsign': 'SCANDINAVIAN',
#    'hub_code': 'CPH',
#    'iata_code': 'SK',
#    'icao_code': 'SAS',
#    'country_iso2': 'SE',
#    'date_founded': '1946',
#    'iata_prefix_accounting': '117',
#    'airline_name': 'SAS',
#    'country_name': 'Sweden',
#    'fleet_size': '155',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '32',
#    'fleet_average_age': '5',
#    'airline_id': '32',
#    'callsign': 'INDONESIA',
#    'hub_code': 'CGK',
#    'iata_code': 'GA',
#    'icao_code': 'GIA',
#    'country_iso2': 'ID',
#    'date_founded': '1949',
#    'iata_prefix_accounting': '126',
#    'airline_name': 'Garuda',
#    'country_name': 'Indonesia',
#    'fleet_size': '148',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '33',
#    'fleet_average_age': '8.3',
#    'airline_id': '33',
#    'callsign': 'CATHAY',
#    'hub_code': 'HKG',
#    'iata_code': 'CX',
#    'icao_code': 'CPA',
#    'country_iso2': 'HK',
#    'date_founded': '1946',
#    'iata_prefix_accounting': '160',
#    'airline_name': 'Cathay Pacific',
#    'country_name': 'Hong Kong',
#    'fleet_size': '143',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '34',
#    'fleet_average_age': '5.9',
#    'airline_id': '34',
#    'callsign': 'BRICKYARD',
#    'hub_code': 'IND',
#    'iata_code': 'RW',
#    'icao_code': 'RPA',
#    'country_iso2': 'US',
#    'date_founded': '2003',
#    'iata_prefix_accounting': '52',
#    'airline_name': 'Republic Airlines',
#    'country_name': 'United States',
#    'fleet_size': '139',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '35',
#    'fleet_average_age': '7.8',
#    'airline_id': '35',
#    'callsign': 'SAUDIA',
#    'hub_code': 'JED',
#    'iata_code': 'SV',
#    'icao_code': 'SVA',
#    'country_iso2': 'SA',
#    'date_founded': '1945',
#    'iata_prefix_accounting': '65',
#    'airline_name': 'Saudi Arabian Airlines',
#    'country_name': 'Saudi Arabia',
#    'fleet_size': '138',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '36',
#    'fleet_average_age': '4.3',
#    'airline_id': '36',
#    'callsign': 'AZUL',
#    'hub_code': 'VCP',
#    'iata_code': 'AD',
#    'icao_code': 'AZU',
#    'country_iso2': 'BR',
#    'date_founded': '2008',
#    'iata_prefix_accounting': '577',
#    'airline_name': 'Azul Brazilian Airlines',
#    'country_name': 'Brazil',
#    'fleet_size': '132',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '37',
#    'fleet_average_age': '5.2',
#    'airline_id': '37',
#    'callsign': 'XIAMEN AIR',
#    'hub_code': 'XMN',
#    'iata_code': 'MF',
#    'icao_code': 'CXA',
#    'country_iso2': 'CN',
#    'date_founded': '1984',
#    'iata_prefix_accounting': '731',
#    'airline_name': 'Xiamen Airlines',
#    'country_name': 'China',
#    'fleet_size': '132',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '38',
#    'fleet_average_age': '7.8',
#    'airline_id': '38',
#    'callsign': 'GOL',
#    'hub_code': 'CGH',
#    'iata_code': 'G3',
#    'icao_code': 'GLO',
#    'country_iso2': 'BR',
#    'date_founded': '2000',
#    'iata_prefix_accounting': '127',
#    'airline_name': 'Gol Linhas Aéreas Inteligentes\nGol Linhas Aéreas Inteligentes\n',
#    'country_name': 'Brazil',
#    'fleet_size': '127',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '39',
#    'fleet_average_age': '16.8',
#    'airline_id': '39',
#    'callsign': 'JAZZ',
#    'hub_code': 'YHZ',
#    'iata_code': 'QK',
#    'icao_code': 'JZA',
#    'country_iso2': 'CA',
#    'date_founded': None,
#    'iata_prefix_accounting': '983',
#    'airline_name': 'Jazz Aviation LP',
#    'country_name': 'Canada',
#    'fleet_size': '127',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '40',
#    'fleet_average_age': '5.8',
#    'airline_id': '40',
#    'callsign': 'ETIHAD',
#    'hub_code': 'AUH',
#    'iata_code': 'EY',
#    'icao_code': 'ETD',
#    'country_iso2': 'AE',
#    'date_founded': '2003',
#    'iata_prefix_accounting': '607',
#    'airline_name': 'Etihad Airways',
#    'country_name': 'United Arab Emirates',
#    'fleet_size': '126',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '41',
#    'fleet_average_age': '5.1',
#    'airline_id': '41',
#    'callsign': 'LAN',
#    'hub_code': 'SCL',
#    'iata_code': 'LA',
#    'icao_code': 'LAN',
#    'country_iso2': 'CL',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '45',
#    'airline_name': 'Lan Airlines',
#    'country_name': 'Chile',
#    'fleet_size': '126',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '42',
#    'fleet_average_age': '7.5',
#    'airline_id': '42',
#    'callsign': 'FLAGSHIP',
#    'hub_code': 'MSP',
#    'iata_code': '9E',
#    'icao_code': 'FLG',
#    'country_iso2': 'UM',
#    'date_founded': '2013',
#    'iata_prefix_accounting': '430',
#    'airline_name': 'Endeavor Air',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '122',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '43',
#    'fleet_average_age': '7.4',
#    'airline_id': '43',
#    'callsign': 'AIR SHUTTLE',
#    'hub_code': 'PHX',
#    'iata_code': 'YV',
#    'icao_code': 'ASH',
#    'country_iso2': 'UM',
#    'date_founded': '1980',
#    'iata_prefix_accounting': '533',
#    'airline_name': 'Mesa Airlines, Inc.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '122',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '44',
#    'fleet_average_age': '9.2',
#    'airline_id': '44',
#    'callsign': 'Q LINK',
#    'hub_code': 'TMW',
#    'iata_code': 'QF',
#    'icao_code': 'QFA',
#    'country_iso2': 'AU',
#    'date_founded': '1920',
#    'iata_prefix_accounting': '81',
#    'airline_name': 'Qantas',
#    'country_name': 'Australia',
#    'fleet_size': '118',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '45',
#    'fleet_average_age': '5.7',
#    'airline_id': '45',
#    'callsign': 'LION INTER',
#    'hub_code': 'CGK',
#    'iata_code': 'JT',
#    'icao_code': 'LNI',
#    'country_iso2': 'ID',
#    'date_founded': '1999',
#    'iata_prefix_accounting': '990',
#    'airline_name': 'Lion Airlines',
#    'country_name': 'Indonesia',
#    'fleet_size': '117',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '46',
#    'fleet_average_age': '8.4',
#    'airline_id': '46',
#    'callsign': 'WESTJET',
#    'hub_code': 'YYC',
#    'iata_code': 'WS',
#    'icao_code': 'WJA',
#    'country_iso2': 'CA',
#    'date_founded': '1995',
#    'iata_prefix_accounting': '838',
#    'airline_name': 'WestJet',
#    'country_name': 'Canada',
#    'fleet_size': '117',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '47',
#    'fleet_average_age': '11.1',
#    'airline_id': '47',
#    'callsign': 'KLM',
#    'hub_code': 'AMS',
#    'iata_code': 'KL',
#    'icao_code': 'KLM',
#    'country_iso2': 'NL',
#    'date_founded': '1919',
#    'iata_prefix_accounting': '74',
#    'airline_name': 'KLM',
#    'country_name': 'Netherlands',
#    'fleet_size': '116',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '48',
#    'fleet_average_age': '8.1',
#    'airline_id': '48',
#    'callsign': 'SINGAPORE',
#    'hub_code': 'SIN',
#    'iata_code': 'SQ',
#    'icao_code': 'SIA',
#    'country_iso2': 'SG',
#    'date_founded': '1972',
#    'iata_prefix_accounting': '618',
#    'airline_name': 'SIA Cargo',
#    'country_name': 'Singapore',
#    'fleet_size': '111',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '49',
#    'fleet_average_age': '7.1',
#    'airline_id': '49',
#    'callsign': 'BLUE STREAK',
#    'hub_code': 'DAY',
#    'iata_code': 'OH',
#    'icao_code': 'JIA',
#    'country_iso2': 'US',
#    'date_founded': '1979',
#    'iata_prefix_accounting': '320',
#    'airline_name': 'PSA Airlines',
#    'country_name': 'United States',
#    'fleet_size': '109',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '50',
#    'fleet_average_age': '9.4',
#    'airline_id': '50',
#    'callsign': 'AIR INDIA',
#    'hub_code': 'DEL',
#    'iata_code': 'AI',
#    'icao_code': 'AIC',
#    'country_iso2': 'IN',
#    'date_founded': '1948',
#    'iata_prefix_accounting': '98',
#    'airline_name': 'Air India',
#    'country_name': 'India',
#    'fleet_size': '108',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '51',
#    'fleet_average_age': '4.8',
#    'airline_id': '51',
#    'callsign': 'SICHUAN',
#    'hub_code': 'CTU',
#    'iata_code': '3U',
#    'icao_code': 'CSC',
#    'country_iso2': 'CN',
#    'date_founded': '1986',
#    'iata_prefix_accounting': '876',
#    'airline_name': 'Sichuan Airlines',
#    'country_name': 'China',
#    'fleet_size': '107',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '52',
#    'fleet_average_age': '4.7',
#    'airline_id': '52',
#    'callsign': 'IFLY',
#    'hub_code': 'DEL',
#    'iata_code': '6E',
#    'icao_code': 'IGO',
#    'country_iso2': 'IN',
#    'date_founded': '2006',
#    'iata_prefix_accounting': '312',
#    'airline_name': 'Interglobe Aviation Ltd. dba Indigo',
#    'country_name': 'India',
#    'fleet_size': '107',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '53',
#    'fleet_average_age': '6.7',
#    'airline_id': '53',
#    'callsign': 'VUELING',
#    'hub_code': 'BCN',
#    'iata_code': 'VY',
#    'icao_code': 'VLG',
#    'country_iso2': 'ES',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '30',
#    'airline_name': 'Vueling',
#    'country_name': 'Spain',
#    'fleet_size': '105',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '54',
#    'fleet_average_age': '10.5',
#    'airline_id': '54',
#    'callsign': 'ALITALIA',
#    'hub_code': 'FCO',
#    'iata_code': 'AZ',
#    'icao_code': 'AZA',
#    'country_iso2': 'IT',
#    'date_founded': '1957',
#    'iata_prefix_accounting': '55',
#    'airline_name': 'Alitalia',
#    'country_name': 'Italy',
#    'fleet_size': '102',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '55',
#    'fleet_average_age': '4.5',
#    'airline_id': '55',
#    'callsign': 'AVIANCA',
#    'hub_code': 'BOG',
#    'iata_code': 'AV',
#    'icao_code': 'AVA',
#    'country_iso2': 'CO',
#    'date_founded': '1933',
#    'iata_prefix_accounting': '134',
#    'airline_name': 'AVIANCA',
#    'country_name': 'Colombia',
#    'fleet_size': '99',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '56',
#    'fleet_average_age': '6.3',
#    'airline_id': '56',
#    'callsign': 'VIRGIN',
#    'hub_code': 'BNE',
#    'iata_code': 'VA',
#    'icao_code': 'VAU',
#    'country_iso2': 'AU',
#    'date_founded': '2011',
#    'iata_prefix_accounting': '795',
#    'airline_name': 'Virgin Australia',
#    'country_name': 'Australia',
#    'fleet_size': '98',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '57',
#    'fleet_average_age': '11.5',
#    'airline_id': '57',
#    'callsign': 'MERCURY',
#    'hub_code': 'FWA',
#    'iata_code': 'S5',
#    'icao_code': 'TCF',
#    'country_iso2': 'UM',
#    'date_founded': None,
#    'iata_prefix_accounting': '919',
#    'airline_name': 'Shuttle America',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '95',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '58',
#    'fleet_average_age': '4.6',
#    'airline_id': '58',
#    'callsign': 'SHANDONG',
#    'hub_code': 'TNA',
#    'iata_code': 'SC',
#    'icao_code': 'CDG',
#    'country_iso2': 'CN',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '324',
#    'airline_name': 'Shandong Airlines',
#    'country_name': 'China',
#    'fleet_size': '93',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '59',
#    'fleet_average_age': '6.7',
#    'airline_id': '59',
#    'callsign': 'JET AIRWAYS',
#    'hub_code': 'BOM',
#    'iata_code': '9W',
#    'icao_code': 'JAI',
#    'country_iso2': 'IN',
#    'date_founded': '1992',
#    'iata_prefix_accounting': '589',
#    'airline_name': 'Jet Airways',
#    'country_name': 'India',
#    'fleet_size': '92',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '60',
#    'fleet_average_age': '5.2',
#    'airline_id': '60',
#    'callsign': 'CHINA DRAGON',
#    'hub_code': 'TSN',
#    'iata_code': 'GS',
#    'icao_code': 'GCR',
#    'country_iso2': 'CN',
#    'date_founded': '2009',
#    'iata_prefix_accounting': '826',
#    'airline_name': 'Tianjin Airlines',
#    'country_name': 'China',
#    'fleet_size': '91',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '61',
#    'fleet_average_age': '5.4',
#    'airline_id': '61',
#    'callsign': 'VIETNAM AIRLINES',
#    'hub_code': 'SGN',
#    'iata_code': 'VN',
#    'icao_code': 'HVN',
#    'country_iso2': 'VN',
#    'date_founded': '1951',
#    'iata_prefix_accounting': '738',
#    'airline_name': 'Vietnam Airlines',
#    'country_name': 'Vietnam',
#    'fleet_size': '89',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '62',
#    'fleet_average_age': '6.1',
#    'airline_id': '62',
#    'callsign': 'COPA',
#    'hub_code': 'PTY',
#    'iata_code': 'CM',
#    'icao_code': 'CMP',
#    'country_iso2': 'PA',
#    'date_founded': '1947',
#    'iata_prefix_accounting': '230',
#    'airline_name': 'COPA Airlines',
#    'country_name': 'Panama',
#    'fleet_size': '88',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '63',
#    'fleet_average_age': '5.7',
#    'airline_id': '63',
#    'callsign': 'SHANGHAI AIR',
#    'hub_code': 'SHA',
#    'iata_code': 'FM',
#    'icao_code': 'CSH',
#    'country_iso2': 'CN',
#    'date_founded': '1985',
#    'iata_prefix_accounting': '774',
#    'airline_name': 'Shanghai Airlines',
#    'country_name': 'China',
#    'fleet_size': '86',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '64',
#    'fleet_average_age': '8.1',
#    'airline_id': '64',
#    'callsign': 'AIR BERLIN',
#    'hub_code': 'TXL',
#    'iata_code': 'AB',
#    'icao_code': 'BER',
#    'country_iso2': 'DE',
#    'date_founded': '1978',
#    'iata_prefix_accounting': '745',
#    'airline_name': 'Air Berlin',
#    'country_name': 'Germany',
#    'fleet_size': '85',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '65',
#    'fleet_average_age': '15.8',
#    'airline_id': '65',
#    'callsign': 'AUSTRIAN',
#    'hub_code': 'VIE',
#    'iata_code': 'OS',
#    'icao_code': 'AUA',
#    'country_iso2': 'AT',
#    'date_founded': '1957',
#    'iata_prefix_accounting': '257',
#    'airline_name': 'Austrian',
#    'country_name': 'Austria',
#    'fleet_size': '85',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '66',
#    'fleet_average_age': '5.2',
#    'airline_id': '66',
#    'callsign': 'SPIRIT WINGS',
#    'hub_code': 'FLL',
#    'iata_code': 'NK',
#    'icao_code': 'NKS',
#    'country_iso2': 'UM',
#    'date_founded': '1980',
#    'iata_prefix_accounting': '487',
#    'airline_name': 'Spirit Airlines',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '84',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '67',
#    'fleet_average_age': '10.3',
#    'airline_id': '67',
#    'callsign': 'ASIANA',
#    'hub_code': 'ICN',
#    'iata_code': 'OZ',
#    'icao_code': 'AAR',
#    'country_iso2': 'KR',
#    'date_founded': '1988',
#    'iata_prefix_accounting': '988',
#    'airline_name': 'Asiana',
#    'country_name': 'South Korea',
#    'fleet_size': '84',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '68',
#    'fleet_average_age': '9.6',
#    'airline_id': '68',
#    'callsign': 'DYNASTY',
#    'hub_code': 'TPE',
#    'iata_code': 'CI',
#    'icao_code': 'CAL',
#    'country_iso2': 'TW',
#    'date_founded': '1959',
#    'iata_prefix_accounting': '297',
#    'airline_name': 'China Airlines',
#    'country_name': 'Chinese Taipei',
#    'fleet_size': '83',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '69',
#    'fleet_average_age': '21.6',
#    'airline_id': '69',
#    'callsign': 'ALLEGIANT',
#    'hub_code': 'LAS',
#    'iata_code': 'G4',
#    'icao_code': 'AAY',
#    'country_iso2': 'UM',
#    'date_founded': '1997',
#    'iata_prefix_accounting': '268',
#    'airline_name': 'Allegiant Air LLC',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '83',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '70',
#    'fleet_average_age': '4.3',
#    'airline_id': '70',
#    'callsign': 'MALAYSIAN',
#    'hub_code': 'KUL',
#    'iata_code': 'MH',
#    'icao_code': 'MAS',
#    'country_iso2': 'MY',
#    'date_founded': '1971',
#    'iata_prefix_accounting': '232',
#    'airline_name': 'Malaysia Airlines',
#    'country_name': 'Malaysia',
#    'fleet_size': '83',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '71',
#    'fleet_average_age': '5.6',
#    'airline_id': '71',
#    'callsign': 'ASIAN EXPRESS',
#    'hub_code': 'KUL',
#    'iata_code': 'AK',
#    'icao_code': 'AXM',
#    'country_iso2': 'MY',
#    'date_founded': '1993',
#    'iata_prefix_accounting': '807',
#    'airline_name': 'AirAsia Berhad dba AirAsia',
#    'country_name': 'Malaysia',
#    'fleet_size': '82',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '72',
#    'fleet_average_age': '9.5',
#    'airline_id': '72',
#    'callsign': 'THAI',
#    'hub_code': 'BKK',
#    'iata_code': 'TG',
#    'icao_code': 'THA',
#    'country_iso2': 'TH',
#    'date_founded': '1959',
#    'iata_prefix_accounting': '217',
#    'airline_name': 'Thai Airways International',
#    'country_name': 'Thailand',
#    'fleet_size': '81',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '73',
#    'fleet_average_age': '9.9',
#    'airline_id': '73',
#    'callsign': 'IBERIA',
#    'hub_code': 'MAD',
#    'iata_code': 'IB',
#    'icao_code': 'IBE',
#    'country_iso2': 'ES',
#    'date_founded': '1927',
#    'iata_prefix_accounting': '75',
#    'airline_name': 'IBERIA',
#    'country_name': 'Spain',
#    'fleet_size': '78',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '74',
#    'fleet_average_age': '11.7',
#    'airline_id': '74',
#    'callsign': 'JERSEY',
#    'hub_code': 'EXT',
#    'iata_code': 'BE',
#    'icao_code': 'BEE',
#    'country_iso2': 'GB',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '267',
#    'airline_name': 'flybe',
#    'country_name': 'United Kingdom',
#    'fleet_size': '63',
#    'status': 'historical/administration',
#    'type': 'scheduled'},
#   {'id': '75',
#    'fleet_average_age': '5.9',
#    'airline_id': '75',
#    'callsign': 'ETHIOPIAN',
#    'hub_code': 'ADD',
#    'iata_code': 'ET',
#    'icao_code': 'ETH',
#    'country_iso2': 'ET',
#    'date_founded': '1945',
#    'iata_prefix_accounting': '71',
#    'airline_name': 'Ethiopian Airlines',
#    'country_name': 'Ethiopia',
#    'fleet_size': '69',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '76',
#    'fleet_average_age': '6.2',
#    'airline_id': '76',
#    'callsign': 'JETSTAR',
#    'hub_code': 'MEL',
#    'iata_code': 'JQ',
#    'icao_code': 'JST',
#    'country_iso2': 'AU',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '41',
#    'airline_name': 'Jetstar Airways Pty Limited',
#    'country_name': 'Australia',
#    'fleet_size': '69',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '77',
#    'fleet_average_age': '4.2',
#    'airline_id': '77',
#    'callsign': 'WIZZ AIR',
#    'hub_code': 'BUD',
#    'iata_code': 'W6',
#    'icao_code': 'WZZ',
#    'country_iso2': 'HU',
#    'date_founded': '2004',
#    'iata_prefix_accounting': None,
#    'airline_name': 'Wizz Air Hungary Ltd.',
#    'country_name': 'Hungary',
#    'fleet_size': '68',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '78',
#    'fleet_average_age': '13.8',
#    'airline_id': '78',
#    'callsign': 'AIR WISCONSIN',
#    'hub_code': 'ATW',
#    'iata_code': 'ZW',
#    'icao_code': 'AWI',
#    'country_iso2': 'UM',
#    'date_founded': '1965',
#    'iata_prefix_accounting': '303',
#    'airline_name': 'Air Wisconsin Airlines Corporation (AWAC)',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '68',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '79',
#    'fleet_average_age': '12.9',
#    'airline_id': '79',
#    'callsign': 'SWISS',
#    'hub_code': 'ZRH',
#    'iata_code': 'LX',
#    'icao_code': 'SWR',
#    'country_iso2': 'CH',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '724',
#    'airline_name': 'SWISS',
#    'country_name': 'Switzerland',
#    'fleet_size': '67',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '80',
#    'fleet_average_age': '14.4',
#    'airline_id': '80',
#    'callsign': 'WATERSKI',
#    'hub_code': 'STL',
#    'iata_code': 'AX',
#    'icao_code': 'LOF',
#    'country_iso2': 'US',
#    'date_founded': '1982',
#    'iata_prefix_accounting': '414',
#    'airline_name': 'Trans States Airlines, LLC',
#    'country_name': 'United States',
#    'fleet_size': '65',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '81',
#    'fleet_average_age': '6.8',
#    'airline_id': '81',
#    'callsign': 'EVA',
#    'hub_code': 'TPE',
#    'iata_code': 'BR',
#    'icao_code': 'EVA',
#    'country_iso2': 'TW',
#    'date_founded': '1989',
#    'iata_prefix_accounting': '695',
#    'airline_name': 'EVA Air',
#    'country_name': 'Chinese Taipei',
#    'fleet_size': '65',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '82',
#    'fleet_average_age': '9.3',
#    'airline_id': '82',
#    'callsign': 'SIBERIAN AIRLINES',
#    'hub_code': 'DME',
#    'iata_code': 'S7',
#    'icao_code': 'SBI',
#    'country_iso2': 'RU',
#    'date_founded': '1992',
#    'iata_prefix_accounting': '421',
#    'airline_name': 'S7 Airlines',
#    'country_name': 'Russia',
#    'fleet_size': '65',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '83',
#    'fleet_average_age': '7.2',
#    'airline_id': '83',
#    'callsign': 'AEROMEXICO',
#    'hub_code': 'MEX',
#    'iata_code': 'AM',
#    'icao_code': 'AMX',
#    'country_iso2': 'MX',
#    'date_founded': '1972',
#    'iata_prefix_accounting': '139',
#    'airline_name': 'Aeromexico',
#    'country_name': 'Mexico',
#    'fleet_size': '64',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '84',
#    'fleet_average_age': '6.4',
#    'airline_id': '84',
#    'callsign': 'INTERJET',
#    'hub_code': 'TLC',
#    'iata_code': '4O',
#    'icao_code': 'AIJ',
#    'country_iso2': 'MX',
#    'date_founded': '2005',
#    'iata_prefix_accounting': '837',
#    'airline_name': 'Interjet',
#    'country_name': 'Mexico',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '85',
#    'fleet_average_age': '8.9',
#    'airline_id': '85',
#    'callsign': 'COSTERA',
#    'hub_code': 'MTY',
#    'iata_code': '5D',
#    'icao_code': 'SLI',
#    'country_iso2': 'MX',
#    'date_founded': '2007',
#    'iata_prefix_accounting': '642',
#    'airline_name': 'Aerolitoral S.A. de C.V.',
#    'country_name': 'Mexico',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '86',
#    'fleet_average_age': '8.1',
#    'airline_id': '86',
#    'callsign': 'CAPITAL JET',
#    'hub_code': 'HAK',
#    'iata_code': 'JD',
#    'icao_code': 'CBJ',
#    'country_iso2': 'CN',
#    'date_founded': '1995',
#    'iata_prefix_accounting': '898',
#    'airline_name': 'Capital Airlines',
#    'country_name': 'China',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '87',
#    'fleet_average_age': '5.2',
#    'airline_id': '87',
#    'callsign': 'SUNTURK',
#    'hub_code': 'SAW',
#    'iata_code': 'PC',
#    'icao_code': 'PGT',
#    'country_iso2': 'TR',
#    'date_founded': '1990',
#    'iata_prefix_accounting': '624',
#    'airline_name': 'Pegasus Airlines',
#    'country_name': 'Turkey',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '88',
#    'fleet_average_age': '14.2',
#    'airline_id': '88',
#    'callsign': 'TJUMAVI',
#    'hub_code': 'SGC',
#    'iata_code': 'UT',
#    'icao_code': 'UTA',
#    'country_iso2': 'RU',
#    'date_founded': '1991',
#    'iata_prefix_accounting': '298',
#    'airline_name': 'UTair',
#    'country_name': 'Russia',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '89',
#    'fleet_average_age': '8.6',
#    'airline_id': '89',
#    'callsign': 'TOMJET',
#    'hub_code': 'LTN',
#    'iata_code': 'BY',
#    'icao_code': 'TOM',
#    'country_iso2': 'GB',
#    'date_founded': '1962',
#    'iata_prefix_accounting': '754',
#    'airline_name': 'TUI Airways Limited',
#    'country_name': 'United Kingdom',
#    'fleet_size': '58',
#    'status': 'active',
#    'type': 'scheduled,charter'},
#   {'id': '90',
#    'fleet_average_age': '5.8',
#    'airline_id': '90',
#    'callsign': 'COMPASS',
#    'hub_code': 'MSP',
#    'iata_code': 'CP',
#    'icao_code': 'CPZ',
#    'country_iso2': 'UM',
#    'date_founded': '2007',
#    'iata_prefix_accounting': '3',
#    'airline_name': 'Compass Airlines LLC',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '91',
#    'fleet_average_age': '14.9',
#    'airline_id': '91',
#    'callsign': 'AIR PORTUGAL',
#    'hub_code': 'LIS',
#    'iata_code': 'TP',
#    'icao_code': 'TAP',
#    'country_iso2': 'PT',
#    'date_founded': '1945',
#    'iata_prefix_accounting': '47',
#    'airline_name': 'TAP Portugal',
#    'country_name': 'Portugal',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '92',
#    'fleet_average_age': '6.3',
#    'airline_id': '92',
#    'callsign': 'REDWOOD',
#    'hub_code': 'SFO',
#    'iata_code': 'VX',
#    'icao_code': 'VRD',
#    'country_iso2': 'US',
#    'date_founded': '2006',
#    'iata_prefix_accounting': '984',
#    'airline_name': 'Virgin America',
#    'country_name': 'United States',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '93',
#    'fleet_average_age': '4.5',
#    'airline_id': '93',
#    'callsign': 'VOLARIS',
#    'hub_code': 'TLC',
#    'iata_code': 'Y4',
#    'icao_code': 'VOI',
#    'country_iso2': 'MX',
#    'date_founded': '2006',
#    'iata_prefix_accounting': '36',
#    'airline_name': 'Volaris',
#    'country_name': 'Mexico',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '94',
#    'fleet_average_age': '14.6',
#    'airline_id': '94',
#    'callsign': 'GERMAN WINGS',
#    'hub_code': 'CGN',
#    'iata_code': '4U',
#    'icao_code': 'GWI',
#    'country_iso2': 'DE',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '51',
#    'airline_name': 'Germanwings GmbH',
#    'country_name': 'Germany',
#    'fleet_size': '61',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '95',
#    'fleet_average_age': '21.9',
#    'airline_id': '95',
#    'callsign': 'CHANNEX',
#    'hub_code': 'LBA',
#    'iata_code': 'LS',
#    'icao_code': 'EXS',
#    'country_iso2': 'GB',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '949',
#    'airline_name': 'Jet2.com Limited',
#    'country_name': 'United Kingdom',
#    'fleet_size': '61',
#    'status': 'active',
#    'type': 'scheduled,cargo'},
#   {'id': '96',
#    'fleet_average_age': '4.7',
#    'airline_id': '96',
#    'callsign': 'PHILIPPINE',
#    'hub_code': 'MNL',
#    'iata_code': 'PR',
#    'icao_code': 'PAL',
#    'country_iso2': 'PH',
#    'date_founded': '1941',
#    'iata_prefix_accounting': '79',
#    'airline_name': 'Philippine Airlines',
#    'country_name': 'Philippines',
#    'fleet_size': '59',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '97',
#    'fleet_average_age': '3.5',
#    'airline_id': '97',
#    'callsign': 'AIR SPRING',
#    'hub_code': 'SHA',
#    'iata_code': '9C',
#    'icao_code': 'CQH',
#    'country_iso2': 'CN',
#    'date_founded': '2005',
#    'iata_prefix_accounting': '89',
#    'airline_name': 'Spring Airlines Limited Corporation',
#    'country_name': 'China',
#    'fleet_size': '58',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '98',
#    'fleet_average_age': '7.7',
#    'airline_id': '98',
#    'callsign': 'FRONTIER FLIGHT',
#    'hub_code': 'DEN',
#    'iata_code': 'F9',
#    'icao_code': 'FFT',
#    'country_iso2': 'UM',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '422',
#    'airline_name': 'Frontier Airlines, Inc.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '58',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '99',
#    'fleet_average_age': '5',
#    'airline_id': '99',
#    'callsign': 'CEBU AIR',
#    'hub_code': 'MNL',
#    'iata_code': '5J',
#    'icao_code': 'CEB',
#    'country_iso2': 'PH',
#    'date_founded': '1996',
#    'iata_prefix_accounting': '203',
#    'airline_name': 'Cebu Pacific Air',
#    'country_name': 'Philippines',
#    'fleet_size': '57',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '100',
#    'fleet_average_age': '3.7',
#    'airline_id': '100',
#    'callsign': 'NOR SHUTTLE',
#    'hub_code': 'OSL',
#    'iata_code': 'DY',
#    'icao_code': 'NAX',
#    'country_iso2': 'NO',
#    'date_founded': '1993',
#    'iata_prefix_accounting': '328',
#    'airline_name': 'Norwegian Air Shuttle A.S.',
#    'country_name': 'Norway',
#    'fleet_size': '57',
#    'status': 'active',
#    'type': 'scheduled'}]}

# %%
# basic plan must use http, not https
FLIGHT_API_URL = AVIATION_API_URL + "flights"
params = {"access_key": AVIATION_API_KEY, "airline_name": "Malaysia Airlines"}

# %%
api_result = requests.get(FLIGHT_API_URL, params)
api_response = api_result.json()

# %%
api_response.keys()
# Out:
# dict_keys(['pagination', 'data'])

# %%
api_response["pagination"]
# Out:
# {'limit': 100, 'offset': 0, 'count': 100, 'total': 2570}

# %%
api_response["data"]
# Out:
# [{'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kansai International',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'KIX',
#    'icao': 'RJBB',
#    'terminal': '1',
#    'gate': '40',
#    'delay': None,
#    'scheduled': '2023-08-23T06:40:00+00:00',
#    'estimated': '2023-08-23T06:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Haneda Airport',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'HND',
#    'icao': 'RJTT',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:45:00+00:00',
#    'estimated': '2023-08-23T07:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9170',
#    'iata': 'MH9170',
#    'icao': 'MAS9170',
#    'codeshared': {'airline_name': 'jal',
#     'airline_iata': 'jl',
#     'airline_icao': 'jal',
#     'flight_number': '220',
#     'flight_iata': 'jl220',
#     'flight_icao': 'jal220'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kota-Kinabalu International Airport',
#    'timezone': 'Asia/Kuching',
#    'iata': 'BKI',
#    'icao': 'WBKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T05:25:00+00:00',
#    'estimated': '2023-08-23T05:25:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T08:00:00+00:00',
#    'estimated': '2023-08-23T08:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2637',
#    'iata': 'MH2637',
#    'icao': 'MAS2637',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuching',
#    'timezone': 'Asia/Kuching',
#    'iata': 'KCH',
#    'icao': 'WBGG',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T05:40:00+00:00',
#    'estimated': '2023-08-23T05:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:30:00+00:00',
#    'estimated': '2023-08-23T07:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2547',
#    'iata': 'MH2547',
#    'icao': 'MAS2547',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Cairo International Airport',
#    'timezone': 'Africa/Cairo',
#    'iata': 'CAI',
#    'icao': 'HECA',
#    'terminal': '2',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T00:55:00+00:00',
#    'estimated': '2023-08-23T00:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'King Abdulaziz International',
#    'timezone': 'Asia/Riyadh',
#    'iata': 'JED',
#    'icao': 'OEJN',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T03:15:00+00:00',
#    'estimated': '2023-08-23T03:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4770',
#    'iata': 'MH4770',
#    'icao': 'MAS4770',
#    'codeshared': {'airline_name': 'saudia',
#     'airline_iata': 'sv',
#     'airline_icao': 'sva',
#     'flight_number': '386',
#     'flight_iata': 'sv386',
#     'flight_icao': 'sva386'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Haneda Airport',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'HND',
#    'icao': 'RJTT',
#    'terminal': '1',
#    'gate': '18',
#    'delay': None,
#    'scheduled': '2023-08-23T06:55:00+00:00',
#    'estimated': '2023-08-23T06:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kansai International',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'KIX',
#    'icao': 'RJBB',
#    'terminal': '1',
#    'gate': '40',
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T08:10:00+00:00',
#    'estimated': '2023-08-23T08:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9167',
#    'iata': 'MH9167',
#    'icao': 'MAS9167',
#    'codeshared': {'airline_name': 'jal',
#     'airline_iata': 'jl',
#     'airline_icao': 'jal',
#     'flight_number': '221',
#     'flight_iata': 'jl221',
#     'flight_icao': 'jal221'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Haneda Airport',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'HND',
#    'icao': 'RJTT',
#    'terminal': '1',
#    'gate': '12',
#    'delay': None,
#    'scheduled': '2023-08-23T06:35:00+00:00',
#    'estimated': '2023-08-23T06:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Chitose',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'CTS',
#    'icao': 'RJCC',
#    'terminal': 'D',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T08:10:00+00:00',
#    'estimated': '2023-08-23T08:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4053',
#    'iata': 'MH4053',
#    'icao': 'MAS4053',
#    'codeshared': {'airline_name': 'jet linx aviation',
#     'airline_iata': 'jl',
#     'airline_icao': 'jtl',
#     'flight_number': '501',
#     'flight_iata': 'jl501',
#     'flight_icao': 'jtl501'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Haneda Airport',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'HND',
#    'icao': 'RJTT',
#    'terminal': '1',
#    'gate': '9',
#    'delay': None,
#    'scheduled': '2023-08-23T06:30:00+00:00',
#    'estimated': '2023-08-23T06:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Naha',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'OKA',
#    'icao': 'ROAH',
#    'terminal': 'D',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T09:05:00+00:00',
#    'estimated': '2023-08-23T09:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9034',
#    'iata': 'MH9034',
#    'icao': 'MAS9034',
#    'codeshared': {'airline_name': 'jet linx aviation',
#     'airline_iata': 'jl',
#     'airline_icao': 'jtl',
#     'flight_number': '901',
#     'flight_iata': 'jl901',
#     'flight_icao': 'jtl901'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Haneda Airport',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'HND',
#    'icao': 'RJTT',
#    'terminal': '1',
#    'gate': '15',
#    'delay': None,
#    'scheduled': '2023-08-23T06:30:00+00:00',
#    'estimated': '2023-08-23T06:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Itami',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'ITM',
#    'icao': 'RJOO',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:35:00+00:00',
#    'estimated': '2023-08-23T07:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4077',
#    'iata': 'MH4077',
#    'icao': 'MAS4077',
#    'codeshared': {'airline_name': 'jet linx aviation',
#     'airline_iata': 'jl',
#     'airline_icao': 'jtl',
#     'flight_number': '101',
#     'flight_iata': 'jl101',
#     'flight_icao': 'jtl101'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Haneda Airport',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'HND',
#    'icao': 'RJTT',
#    'terminal': '1',
#    'gate': '11',
#    'delay': None,
#    'scheduled': '2023-08-23T06:25:00+00:00',
#    'estimated': '2023-08-23T06:25:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Fukuoka',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'FUK',
#    'icao': 'RJFF',
#    'terminal': 'D',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T08:10:00+00:00',
#    'estimated': '2023-08-23T08:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4067',
#    'iata': 'MH4067',
#    'icao': 'MAS4067',
#    'codeshared': {'airline_name': 'jet linx aviation',
#     'airline_iata': 'jl',
#     'airline_icao': 'jtl',
#     'flight_number': '303',
#     'flight_iata': 'jl303',
#     'flight_icao': 'jtl303'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Soekarno-Hatta International',
#    'timezone': 'Asia/Jakarta',
#    'iata': 'CGK',
#    'icao': 'WIII',
#    'terminal': '3',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T04:15:00+00:00',
#    'estimated': '2023-08-23T04:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:25:00+00:00',
#    'estimated': '2023-08-23T07:25:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '726',
#    'iata': 'MH726',
#    'icao': 'MAS726',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Suvarnabhumi International',
#    'timezone': 'Asia/Bangkok',
#    'iata': 'BKK',
#    'icao': 'VTBS',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T00:15:00+00:00',
#    'estimated': '2023-08-23T00:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Queen Alia International',
#    'timezone': 'Asia/Amman',
#    'iata': 'AMM',
#    'icao': 'OJAI',
#    'terminal': None,
#    'gate': '116',
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T04:30:00+00:00',
#    'estimated': '2023-08-23T04:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9043',
#    'iata': 'MH9043',
#    'icao': 'MAS9043',
#    'codeshared': {'airline_name': 'royal jordanian',
#     'airline_iata': 'rj',
#     'airline_icao': 'rja',
#     'flight_number': '183',
#     'flight_iata': 'rj183',
#     'flight_icao': 'rja183'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T05:00:00+00:00',
#    'estimated': '2023-08-23T05:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Francisco Bangoy International',
#    'timezone': 'Asia/Manila',
#    'iata': 'DVO',
#    'icao': 'RPMD',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:00:00+00:00',
#    'estimated': '2023-08-23T07:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5925',
#    'iata': 'MH5925',
#    'icao': 'MAS5925',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2811',
#     'flight_iata': 'pr2811',
#     'flight_icao': 'pal2811'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Soekarno-Hatta International',
#    'timezone': 'Asia/Jakarta',
#    'iata': 'CGK',
#    'icao': 'WIII',
#    'terminal': '3',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T04:05:00+00:00',
#    'estimated': '2023-08-23T04:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Hasanudin',
#    'timezone': 'Asia/Makassar',
#    'iata': 'UPG',
#    'icao': 'WAAA',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:40:00+00:00',
#    'estimated': '2023-08-23T07:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4042',
#    'iata': 'MH4042',
#    'icao': 'MAS4042',
#    'codeshared': {'airline_name': 'garuda indonesia',
#     'airline_iata': 'ga',
#     'airline_icao': 'gia',
#     'flight_number': '604',
#     'flight_iata': 'ga604',
#     'flight_icao': 'gia604'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T02:15:00+00:00',
#    'estimated': '2023-08-23T02:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Bandaranaike International',
#    'timezone': 'Asia/Colombo',
#    'iata': 'CMB',
#    'icao': 'VCBI',
#    'terminal': 'MAIN',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T03:20:00+00:00',
#    'estimated': '2023-08-23T03:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9011',
#    'iata': 'MH9011',
#    'icao': 'MAS9011',
#    'codeshared': {'airline_name': 'srilankan airlines',
#     'airline_iata': 'ul',
#     'airline_icao': 'alk',
#     'flight_number': '319',
#     'flight_iata': 'ul319',
#     'flight_icao': 'alk319'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T02:15:00+00:00',
#    'estimated': '2023-08-23T02:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'King Abdulaziz International',
#    'timezone': 'Asia/Riyadh',
#    'iata': 'JED',
#    'icao': 'OEJN',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T06:00:00+00:00',
#    'estimated': '2023-08-23T06:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4753',
#    'iata': 'MH4753',
#    'icao': 'MAS4753',
#    'codeshared': {'airline_name': 'saudia',
#     'airline_iata': 'sv',
#     'airline_icao': 'sva',
#     'flight_number': '841',
#     'flight_iata': 'sv841',
#     'flight_icao': 'sva841'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': 'C32',
#    'delay': 45,
#    'scheduled': '2023-08-23T01:00:00+00:00',
#    'estimated': '2023-08-23T01:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Schiphol',
#    'timezone': 'Europe/Amsterdam',
#    'iata': 'AMS',
#    'icao': 'EHAM',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:45:00+00:00',
#    'estimated': '2023-08-23T07:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5656',
#    'iata': 'MH5656',
#    'icao': 'MAS5656',
#    'codeshared': {'airline_name': 'klm',
#     'airline_iata': 'kl',
#     'airline_icao': 'klm',
#     'flight_number': '806',
#     'flight_iata': 'kl806',
#     'flight_icao': 'klm806'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Auckland International',
#    'timezone': 'Pacific/Auckland',
#    'iata': 'AKL',
#    'icao': 'NZAA',
#    'terminal': 'I',
#    'gate': '7',
#    'delay': None,
#    'scheduled': '2023-08-23T07:40:00+00:00',
#    'estimated': '2023-08-23T07:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Sydney Kingsford Smith Airport',
#    'timezone': 'Australia/Sydney',
#    'iata': 'SYD',
#    'icao': 'YSSY',
#    'terminal': '1',
#    'gate': '30',
#    'baggage': '5',
#    'delay': None,
#    'scheduled': '2023-08-23T09:20:00+00:00',
#    'estimated': '2023-08-23T09:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9781',
#    'iata': 'MH9781',
#    'icao': 'MAS9781',
#    'codeshared': {'airline_name': 'latam airlines',
#     'airline_iata': 'la',
#     'airline_icao': 'lan',
#     'flight_number': '801',
#     'flight_iata': 'la801',
#     'flight_icao': 'lan801'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Francisco Bangoy International',
#    'timezone': 'Asia/Manila',
#    'iata': 'DVO',
#    'icao': 'RPMD',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T03:10:00+00:00',
#    'estimated': '2023-08-23T03:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T05:10:00+00:00',
#    'estimated': '2023-08-23T05:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5526',
#    'iata': 'MH5526',
#    'icao': 'MAS5526',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2808',
#     'flight_iata': 'pr2808',
#     'flight_icao': 'pal2808'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Zia International',
#    'timezone': 'Asia/Dhaka',
#    'iata': 'DAC',
#    'icao': 'VGHS',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T02:05:00+00:00',
#    'estimated': '2023-08-23T02:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T08:00:00+00:00',
#    'estimated': '2023-08-23T08:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '197',
#    'iata': 'MH197',
#    'icao': 'MAS197',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T04:00:00+00:00',
#    'estimated': '2023-08-23T04:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Puerto Princesa',
#    'timezone': 'Asia/Manila',
#    'iata': 'PPS',
#    'icao': 'RPVP',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T05:20:00+00:00',
#    'estimated': '2023-08-23T05:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5997',
#    'iata': 'MH5997',
#    'icao': 'MAS5997',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2781',
#     'flight_iata': 'pr2781',
#     'flight_icao': 'pal2781'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T04:10:00+00:00',
#    'estimated': '2023-08-23T04:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Cagayan De Oro Domestic Airport',
#    'timezone': 'Asia/Manila',
#    'iata': 'CGY',
#    'icao': 'RPMY',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T05:50:00+00:00',
#    'estimated': '2023-08-23T05:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5917',
#    'iata': 'MH5917',
#    'icao': 'MAS5917',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2519',
#     'flight_iata': 'pr2519',
#     'flight_icao': 'pal2519'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Guangzhou Baiyun International',
#    'timezone': 'Asia/Shanghai',
#    'iata': 'CAN',
#    'icao': 'ZGGG',
#    'terminal': '2',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T04:15:00+00:00',
#    'estimated': '2023-08-23T04:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T08:15:00+00:00',
#    'estimated': '2023-08-23T08:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '6179',
#    'iata': 'MH6179',
#    'icao': 'MAS6179',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Perth International',
#    'timezone': 'Australia/Perth',
#    'iata': 'PER',
#    'icao': 'YPPH',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T02:10:00+00:00',
#    'estimated': '2023-08-23T02:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:50:00+00:00',
#    'estimated': '2023-08-23T07:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '126',
#    'iata': 'MH126',
#    'icao': 'MAS126',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Bangalore International Airport',
#    'timezone': 'Asia/Kolkata',
#    'iata': 'BLR',
#    'icao': 'VOBL',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T00:35:00+00:00',
#    'estimated': '2023-08-23T00:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:20:00+00:00',
#    'estimated': '2023-08-23T07:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '193',
#    'iata': 'MH193',
#    'icao': 'MAS193',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Bandaranaike International',
#    'timezone': 'Asia/Colombo',
#    'iata': 'CMB',
#    'icao': 'VCBI',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T00:05:00+00:00',
#    'estimated': '2023-08-23T00:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T06:20:00+00:00',
#    'estimated': '2023-08-23T06:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '178',
#    'iata': 'MH178',
#    'icao': 'MAS178',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hyderabad Airport',
#    'timezone': 'Asia/Kolkata',
#    'iata': 'HYD',
#    'icao': 'VOHS',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T00:30:00+00:00',
#    'estimated': '2023-08-23T00:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:30:00+00:00',
#    'estimated': '2023-08-23T07:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '199',
#    'iata': 'MH199',
#    'icao': 'MAS199',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T02:55:00+00:00',
#    'estimated': '2023-08-23T02:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'baggage': '7',
#    'delay': None,
#    'scheduled': '2023-08-23T05:15:00+00:00',
#    'estimated': '2023-08-23T05:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '164',
#    'iata': 'MH164',
#    'icao': 'MAS164',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hong Kong International',
#    'timezone': 'Asia/Hong_Kong',
#    'iata': 'HKG',
#    'icao': 'VHHH',
#    'terminal': '1',
#    'gate': '6',
#    'delay': None,
#    'scheduled': '2023-08-23T02:00:00+00:00',
#    'estimated': '2023-08-23T02:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T06:00:00+00:00',
#    'estimated': '2023-08-23T06:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9210',
#    'iata': 'MH9210',
#    'icao': 'MAS9210',
#    'codeshared': {'airline_name': 'cathay pacific',
#     'airline_iata': 'cx',
#     'airline_icao': 'cpa',
#     'flight_number': '844',
#     'flight_iata': 'cx844',
#     'flight_icao': 'cpa844'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hong Kong International',
#    'timezone': 'Asia/Hong_Kong',
#    'iata': 'HKG',
#    'icao': 'VHHH',
#    'terminal': '1',
#    'gate': '3',
#    'delay': None,
#    'scheduled': '2023-08-23T00:05:00+00:00',
#    'estimated': '2023-08-23T00:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': 'B',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T22:35:00+00:00',
#    'estimated': '2023-08-22T22:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9190',
#    'iata': 'MH9190',
#    'icao': 'MAS9190',
#    'codeshared': {'airline_name': 'cathay pacific',
#     'airline_iata': 'cx',
#     'airline_icao': 'cpa',
#     'flight_number': '880',
#     'flight_iata': 'cx880',
#     'flight_icao': 'cpa880'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Mactan-Cebu International',
#    'timezone': 'Asia/Manila',
#    'iata': 'CEB',
#    'icao': 'RPVM',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-23T02:50:00+00:00',
#    'estimated': '2023-08-23T02:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T04:20:00+00:00',
#    'estimated': '2023-08-23T04:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5522',
#    'iata': 'MH5522',
#    'icao': 'MAS5522',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2836',
#     'flight_iata': 'pr2836',
#     'flight_icao': 'pal2836'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hong Kong International',
#    'timezone': 'Asia/Hong_Kong',
#    'iata': 'HKG',
#    'icao': 'VHHH',
#    'terminal': '1',
#    'gate': '9',
#    'delay': None,
#    'scheduled': '2023-08-23T00:50:00+00:00',
#    'estimated': '2023-08-23T00:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'San Francisco International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'SFO',
#    'icao': 'KSFO',
#    'terminal': 'INTL',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T22:45:00+00:00',
#    'estimated': '2023-08-22T22:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9198',
#    'iata': 'MH9198',
#    'icao': 'MAS9198',
#    'codeshared': {'airline_name': 'cathay pacific',
#     'airline_iata': 'cx',
#     'airline_icao': 'cpa',
#     'flight_number': '872',
#     'flight_iata': 'cx872',
#     'flight_icao': 'cpa872'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-23',
#   'flight_status': 'active',
#   'departure': {'airport': 'Auckland International',
#    'timezone': 'Pacific/Auckland',
#    'iata': 'AKL',
#    'icao': 'NZAA',
#    'terminal': 'I',
#    'gate': '10',
#    'delay': 45,
#    'scheduled': '2023-08-23T00:15:00+00:00',
#    'estimated': '2023-08-23T00:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:40:00+00:00',
#    'estimated': '2023-08-23T07:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '132',
#    'iata': 'MH132',
#    'icao': 'MAS132',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-22T20:30:00+00:00',
#    'estimated': '2023-08-22T20:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kastrup',
#    'timezone': 'Europe/Copenhagen',
#    'iata': 'CPH',
#    'icao': 'EKCH',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T23:25:00+00:00',
#    'estimated': '2023-08-22T23:25:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9804',
#    'iata': 'MH9804',
#    'icao': 'MAS9804',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '822',
#     'flight_iata': 'ba822',
#     'flight_icao': 'baw822'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': '36',
#    'delay': None,
#    'scheduled': '2023-08-22T11:00:00+00:00',
#    'estimated': '2023-08-22T11:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D26',
#    'baggage': '24',
#    'delay': None,
#    'scheduled': '2023-08-22T14:12:00+00:00',
#    'estimated': '2023-08-22T14:12:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9471',
#    'iata': 'MH9471',
#    'icao': 'MAS9471',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '688',
#     'flight_iata': 'aa688',
#     'flight_icao': 'aal688'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': None,
#    'delay': 13,
#    'scheduled': '2023-08-22T10:45:00+00:00',
#    'estimated': '2023-08-22T10:45:00+00:00',
#    'actual': '2023-08-22T10:58:00+00:00',
#    'estimated_runway': '2023-08-22T10:58:00+00:00',
#    'actual_runway': '2023-08-22T10:58:00+00:00'},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'baggage': '8',
#    'delay': None,
#    'scheduled': '2023-08-23T06:25:00+00:00',
#    'estimated': '2023-08-23T06:25:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9068',
#    'iata': 'MH9068',
#    'icao': 'MAS9068',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '704',
#     'flight_iata': 'qr704',
#     'flight_icao': 'qtr704'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': "Chicago O'hare International",
#    'timezone': 'America/Chicago',
#    'iata': 'ORD',
#    'icao': 'KORD',
#    'terminal': '3',
#    'gate': 'H6',
#    'delay': 18,
#    'scheduled': '2023-08-22T10:00:00+00:00',
#    'estimated': '2023-08-22T10:00:00+00:00',
#    'actual': '2023-08-22T10:17:00+00:00',
#    'estimated_runway': '2023-08-22T10:17:00+00:00',
#    'actual_runway': '2023-08-22T10:17:00+00:00'},
#   'arrival': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '4',
#    'gate': '47A',
#    'baggage': 'T4A',
#    'delay': None,
#    'scheduled': '2023-08-22T12:20:00+00:00',
#    'estimated': '2023-08-22T12:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9461',
#    'iata': 'MH9461',
#    'icao': 'MAS9461',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '2980',
#     'flight_iata': 'aa2980',
#     'flight_icao': 'aal2980'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-22T20:40:00+00:00',
#    'estimated': '2023-08-22T20:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Blagnac',
#    'timezone': 'Europe/Paris',
#    'iata': 'TLS',
#    'icao': 'LFBO',
#    'terminal': '1',
#    'gate': '4',
#    'baggage': '7',
#    'delay': None,
#    'scheduled': '2023-08-22T23:30:00+00:00',
#    'estimated': '2023-08-22T23:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9900',
#    'iata': 'MH9900',
#    'icao': 'MAS9900',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '376',
#     'flight_iata': 'ba376',
#     'flight_icao': 'baw376'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Philadelphia International',
#    'timezone': 'America/New_York',
#    'iata': 'PHL',
#    'icao': 'KPHL',
#    'terminal': 'B',
#    'gate': 'B13',
#    'delay': None,
#    'scheduled': '2023-08-22T17:34:00+00:00',
#    'estimated': '2023-08-22T17:34:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D51',
#    'baggage': '23',
#    'delay': None,
#    'scheduled': '2023-08-22T20:28:00+00:00',
#    'estimated': '2023-08-22T20:28:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9560',
#    'iata': 'MH9560',
#    'icao': 'MAS9560',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '442',
#     'flight_iata': 'aa442',
#     'flight_icao': 'aal442'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Philadelphia International',
#    'timezone': 'America/New_York',
#    'iata': 'PHL',
#    'icao': 'KPHL',
#    'terminal': 'B',
#    'gate': 'B9',
#    'delay': None,
#    'scheduled': '2023-08-22T17:28:00+00:00',
#    'estimated': '2023-08-22T17:28:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Logan International',
#    'timezone': 'America/New_York',
#    'iata': 'BOS',
#    'icao': 'KBOS',
#    'terminal': 'B',
#    'gate': 'B12',
#    'baggage': '1',
#    'delay': None,
#    'scheduled': '2023-08-22T18:50:00+00:00',
#    'estimated': '2023-08-22T18:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9493',
#    'iata': 'MH9493',
#    'icao': 'MAS9493',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1514',
#     'flight_iata': 'aa1514',
#     'flight_icao': 'aal1514'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '5',
#    'gate': '51B',
#    'delay': None,
#    'scheduled': '2023-08-22T08:08:00+00:00',
#    'estimated': '2023-08-22T08:08:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Ronald Reagan Washington National Airport',
#    'timezone': 'America/New_York',
#    'iata': 'DCA',
#    'icao': 'KDCA',
#    'terminal': '2',
#    'gate': 'C31',
#    'baggage': '9',
#    'delay': None,
#    'scheduled': '2023-08-22T16:16:00+00:00',
#    'estimated': '2023-08-22T16:16:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9332',
#    'iata': 'MH9332',
#    'icao': 'MAS9332',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '2725',
#     'flight_iata': 'aa2725',
#     'flight_icao': 'aal2725'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '4',
#    'gate': '47A',
#    'delay': None,
#    'scheduled': '2023-08-22T08:05:00+00:00',
#    'estimated': '2023-08-22T08:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D2',
#    'baggage': '24',
#    'delay': None,
#    'scheduled': '2023-08-22T16:22:00+00:00',
#    'estimated': '2023-08-22T16:22:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9404',
#    'iata': 'MH9404',
#    'icao': 'MAS9404',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1114',
#     'flight_iata': 'aa1114',
#     'flight_icao': 'aal1114'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': 'B',
#    'gate': '157',
#    'delay': 8,
#    'scheduled': '2023-08-22T07:48:00+00:00',
#    'estimated': '2023-08-22T07:48:00+00:00',
#    'actual': '2023-08-22T07:55:00+00:00',
#    'estimated_runway': '2023-08-22T07:55:00+00:00',
#    'actual_runway': '2023-08-22T07:55:00+00:00'},
#   'arrival': {'airport': "Chicago O'hare International",
#    'timezone': 'America/Chicago',
#    'iata': 'ORD',
#    'icao': 'KORD',
#    'terminal': '3',
#    'gate': 'H18',
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T14:02:00+00:00',
#    'estimated': '2023-08-22T14:02:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9664',
#    'iata': 'MH9664',
#    'icao': 'MAS9664',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '475',
#     'flight_iata': 'aa475',
#     'flight_icao': 'aal475'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Charles De Gaulle',
#    'timezone': 'Europe/Paris',
#    'iata': 'CDG',
#    'icao': 'LFPG',
#    'terminal': '2D',
#    'gate': 'B31',
#    'delay': 23,
#    'scheduled': '2023-08-22T16:30:00+00:00',
#    'estimated': '2023-08-22T16:30:00+00:00',
#    'actual': '2023-08-22T16:53:00+00:00',
#    'estimated_runway': '2023-08-22T16:53:00+00:00',
#    'actual_runway': '2023-08-22T16:53:00+00:00'},
#   'arrival': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T16:45:00+00:00',
#    'estimated': '2023-08-22T16:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9671',
#    'iata': 'MH9671',
#    'icao': 'MAS9671',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '319',
#     'flight_iata': 'ba319',
#     'flight_icao': 'baw319'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Charles De Gaulle',
#    'timezone': 'Europe/Paris',
#    'iata': 'CDG',
#    'icao': 'LFPG',
#    'terminal': '1',
#    'gate': '18',
# ...
#    'actual': '2023-08-22T10:37:00+00:00',
#    'estimated_runway': '2023-08-22T10:37:00+00:00',
#    'actual_runway': '2023-08-22T10:37:00+00:00'},
#   'arrival': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '4',
#    'gate': '42A',
#    'baggage': 'T4A',
#    'delay': None,
#    'scheduled': '2023-08-22T12:50:00+00:00',
#    'estimated': '2023-08-22T12:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9371',
#    'iata': 'MH9371',
#    'icao': 'MAS9371',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1247',
#     'flight_iata': 'aa1247',
#     'flight_icao': 'aal1247'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'King Khaled International',
#    'timezone': 'Asia/Riyadh',
#    'iata': 'RUH',
#    'icao': 'OERK',
#    'terminal': '4',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-22T22:40:00+00:00',
#    'estimated': '2023-08-22T22:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T11:50:00+00:00',
#    'estimated': '2023-08-23T11:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4756',
#    'iata': 'MH4756',
#    'icao': 'MAS4756',
#    'codeshared': {'airline_name': 'saudia',
#     'airline_iata': 'sv',
#     'airline_icao': 'sva',
#     'flight_number': '828',
#     'flight_iata': 'sv828',
#     'flight_icao': 'sva828'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'King Khaled International',
#    'timezone': 'Asia/Riyadh',
#    'iata': 'RUH',
#    'icao': 'OERK',
#    'terminal': '3',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-22T22:30:00+00:00',
#    'estimated': '2023-08-22T22:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'baggage': '7',
#    'delay': None,
#    'scheduled': '2023-08-23T00:05:00+00:00',
#    'estimated': '2023-08-23T00:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4193',
#    'iata': 'MH4193',
#    'icao': 'MAS4193',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '1169',
#     'flight_iata': 'qr1169',
#     'flight_icao': 'qtr1169'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Esenboga International',
#    'timezone': 'Europe/Istanbul',
#    'iata': 'ESB',
#    'icao': 'LTAC',
#    'terminal': None,
#    'gate': '114',
#    'delay': 10,
#    'scheduled': '2023-08-22T22:55:00+00:00',
#    'estimated': '2023-08-22T22:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Istanbul Airport',
#    'timezone': 'Europe/Istanbul',
#    'iata': 'IST',
#    'icao': 'LTFM',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T00:05:00+00:00',
#    'estimated': '2023-08-23T00:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4295',
#    'iata': 'MH4295',
#    'icao': 'MAS4295',
#    'codeshared': {'airline_name': 'turkish airlines',
#     'airline_iata': 'tk',
#     'airline_icao': 'thy',
#     'flight_number': '2183',
#     'flight_iata': 'tk2183',
#     'flight_icao': 'thy2183'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-22T23:20:00+00:00',
#    'estimated': '2023-08-22T23:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Seoul (Incheon)',
#    'timezone': 'Asia/Seoul',
#    'iata': 'ICN',
#    'icao': 'RKSI',
#    'terminal': '2',
#    'gate': '233',
#    'baggage': '1',
#    'delay': None,
#    'scheduled': '2023-08-23T06:50:00+00:00',
#    'estimated': '2023-08-23T06:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5620',
#    'iata': 'MH5620',
#    'icao': 'MAS5620',
#    'codeshared': {'airline_name': 'korean air',
#     'airline_iata': 'ke',
#     'airline_icao': 'kal',
#     'flight_number': '672',
#     'flight_iata': 'ke672',
#     'flight_icao': 'kal672'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': 'C25',
#    'delay': None,
#    'scheduled': '2023-08-22T23:15:00+00:00',
#    'estimated': '2023-08-22T23:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': 'F54',
#    'baggage': '36',
#    'delay': None,
#    'scheduled': '2023-08-23T00:35:00+00:00',
#    'estimated': '2023-08-23T00:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5973',
#    'iata': 'MH5973',
#    'icao': 'MAS5973',
#    'codeshared': {'airline_name': 'ethiopian airlines',
#     'airline_iata': 'et',
#     'airline_icao': 'eth',
#     'flight_number': '639',
#     'flight_iata': 'et639',
#     'flight_icao': 'eth639'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Washington Dulles International',
#    'timezone': 'America/New_York',
#    'iata': 'IAD',
#    'icao': 'KIAD',
#    'terminal': None,
#    'gate': None,
#    'delay': 15,
#    'scheduled': '2023-08-22T10:55:00+00:00',
#    'estimated': '2023-08-22T10:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'baggage': '4',
#    'delay': None,
#    'scheduled': '2023-08-23T06:50:00+00:00',
#    'estimated': '2023-08-23T06:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9792',
#    'iata': 'MH9792',
#    'icao': 'MAS9792',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '710',
#     'flight_iata': 'qr710',
#     'flight_icao': 'qtr710'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A20',
#    'delay': 16,
#    'scheduled': '2023-08-22T13:20:00+00:00',
#    'estimated': '2023-08-22T13:20:00+00:00',
#    'actual': '2023-08-22T13:35:00+00:00',
#    'estimated_runway': '2023-08-22T13:35:00+00:00',
#    'actual_runway': '2023-08-22T13:35:00+00:00'},
#   'arrival': {'airport': 'Charles De Gaulle',
#    'timezone': 'Europe/Paris',
#    'iata': 'CDG',
#    'icao': 'LFPG',
#    'terminal': '2D',
#    'gate': None,
#    'baggage': '02',
#    'delay': None,
#    'scheduled': '2023-08-22T15:35:00+00:00',
#    'estimated': '2023-08-22T15:35:00+00:00',
#    'actual': '2023-08-22T15:13:00+00:00',
#    'estimated_runway': '2023-08-22T15:13:00+00:00',
#    'actual_runway': '2023-08-22T15:13:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9672',
#    'iata': 'MH9672',
#    'icao': 'MAS9672',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '314',
#     'flight_iata': 'ba314',
#     'flight_icao': 'baw314'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'El Prat De Llobregat',
#    'timezone': 'Europe/Madrid',
#    'iata': 'BCN',
#    'icao': 'LEBL',
#    'terminal': '1',
#    'gate': 'E74',
#    'delay': 13,
#    'scheduled': '2023-08-22T16:25:00+00:00',
#    'estimated': '2023-08-22T16:25:00+00:00',
#    'actual': '2023-08-22T16:37:00+00:00',
#    'estimated_runway': '2023-08-22T16:37:00+00:00',
#    'actual_runway': '2023-08-22T16:37:00+00:00'},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'baggage': '6',
#    'delay': None,
#    'scheduled': '2023-08-22T23:35:00+00:00',
#    'estimated': '2023-08-22T23:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9246',
#    'iata': 'MH9246',
#    'icao': 'MAS9246',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '146',
#     'flight_iata': 'qr146',
#     'flight_icao': 'qtr146'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': '37',
#    'delay': 15,
#    'scheduled': '2023-08-22T08:29:00+00:00',
#    'estimated': '2023-08-22T08:29:00+00:00',
#    'actual': '2023-08-22T08:44:00+00:00',
#    'estimated_runway': '2023-08-22T08:44:00+00:00',
#    'actual_runway': '2023-08-22T08:44:00+00:00'},
#   'arrival': {'airport': "Chicago O'hare International",
#    'timezone': 'America/Chicago',
#    'iata': 'ORD',
#    'icao': 'KORD',
#    'terminal': '3',
#    'gate': 'H17',
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T10:32:00+00:00',
#    'estimated': '2023-08-22T10:32:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9376',
#    'iata': 'MH9376',
#    'icao': 'MAS9376',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '2819',
#     'flight_iata': 'aa2819',
#     'flight_icao': 'aal2819'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'King Abdulaziz International',
#    'timezone': 'Asia/Riyadh',
#    'iata': 'JED',
#    'icao': 'OEJN',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-22T21:00:00+00:00',
#    'estimated': '2023-08-22T21:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T11:15:00+00:00',
#    'estimated': '2023-08-23T11:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '157',
#    'iata': 'MH157',
#    'icao': 'MAS157',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Zurich',
#    'timezone': 'Europe/Zurich',
#    'iata': 'ZRH',
#    'icao': 'LSZH',
#    'terminal': '2',
#    'gate': 'E52',
#    'delay': None,
#    'scheduled': '2023-08-22T18:40:00+00:00',
#    'estimated': '2023-08-22T18:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T19:30:00+00:00',
#    'estimated': '2023-08-22T19:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9933',
#    'iata': 'MH9933',
#    'icao': 'MAS9933',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '717',
#     'flight_iata': 'ba717',
#     'flight_icao': 'baw717'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D19',
#    'delay': 51,
#    'scheduled': '2023-08-22T10:04:00+00:00',
#    'estimated': '2023-08-22T10:04:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': '43',
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-22T13:09:00+00:00',
#    'estimated': '2023-08-22T13:09:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9338',
#    'iata': 'MH9338',
#    'icao': 'MAS9338',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '309',
#     'flight_iata': 'aa309',
#     'flight_icao': 'aal309'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-22',
#   'flight_status': 'active',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': 'C22',
#    'delay': 10,
#    'scheduled': '2023-08-22T22:50:00+00:00',
#    'estimated': '2023-08-22T22:50:00+00:00',
#    'actual': '2023-08-22T22:59:00+00:00',
#    'estimated_runway': '2023-08-22T22:59:00+00:00',
#    'actual_runway': '2023-08-22T22:59:00+00:00'},
#   'arrival': {'airport': 'Narita International Airport',
#    'timezone': 'Asia/Tokyo',
#    'iata': 'NRT',
#    'icao': 'RJAA',
#    'terminal': '2',
#    'gate': '67A',
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-08-23T07:05:00+00:00',
#    'estimated': '2023-08-23T07:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9118',
#    'iata': 'MH9118',
#    'icao': 'MAS9118',
#    'codeshared': {'airline_name': 'jal',
#     'airline_iata': 'jl',
#     'airline_icao': 'jal',
#     'flight_number': '724',
#     'flight_iata': 'jl724',
#     'flight_icao': 'jal724'}},
#   'aircraft': None,
#   'live': None}]

# %% [markdown]
# ### Filter for delays

# %%
params = {
    "access_key": AVIATION_API_KEY,
    "airline_name": "Malaysia Airlines",
    "min_delay_arr": 30,
    "flight_date": "2023-08-22",
}
api_result = requests.get(FLIGHT_API_URL, params)
api_response = api_result.json()

# %%
api_response
# Out:
# {'error': {'code': 'function_access_restricted',
#   'message': 'Your current subscription plan does not support this API function.'}}

# %% [markdown]
# Basic plan cannot filter by date???

# %%
params = {
    "access_key": AVIATION_API_KEY,
    "airline_name": "Malaysia Airlines",
    "min_delay_arr": 30,
    # "flight_date": "2023-08-22",
}
api_result = requests.get(FLIGHT_API_URL, params)
api_response = api_result.json()

# %%
api_response["pagination"]
# Out:
# {'limit': 100, 'offset': 0, 'count': 100, 'total': 130}

# %%
api_response["data"]
# Out:
# [{'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': 'C37',
#    'delay': 25,
#    'scheduled': '2023-08-29T02:05:00+00:00',
#    'estimated': '2023-08-29T02:05:00+00:00',
#    'actual': '2023-08-29T03:10:00+00:00',
#    'estimated_runway': '2023-08-29T03:10:00+00:00',
#    'actual_runway': '2023-08-29T03:10:00+00:00'},
#   'arrival': {'airport': 'Cape Town International',
#    'timezone': 'Africa/Johannesburg',
#    'iata': 'CPT',
#    'icao': 'FACT',
#    'terminal': 'B',
#    'gate': 'A5',
#    'baggage': '1.4',
#    'delay': 31,
#    'scheduled': '2023-08-29T10:50:00+00:00',
#    'estimated': '2023-08-29T10:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9305',
#    'iata': 'MH9305',
#    'icao': 'MAS9305',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '1369',
#     'flight_iata': 'qr1369',
#     'flight_icao': 'qtr1369'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'active',
#   'departure': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-29T01:53:00+00:00',
#    'estimated': '2023-08-29T01:53:00+00:00',
#    'actual': '2023-08-29T01:53:00+00:00',
#    'estimated_runway': '2023-08-29T01:53:00+00:00',
#    'actual_runway': '2023-08-29T01:53:00+00:00'},
#   'arrival': {'airport': None,
#    'timezone': None,
#    'iata': 'DWC',
#    'icao': 'OMDW',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': 35,
#    'scheduled': '2023-08-29T03:26:00+00:00',
#    'estimated': '2023-08-29T03:26:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '6127',
#    'iata': 'MH6127',
#    'icao': 'MAS6127',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Guangzhou Baiyun International',
#    'timezone': 'Asia/Shanghai',
#    'iata': 'CAN',
#    'icao': 'ZGGG',
#    'terminal': '2',
#    'gate': None,
#    'delay': 45,
#    'scheduled': '2023-08-29T08:15:00+00:00',
#    'estimated': '2023-08-29T08:15:00+00:00',
#    'actual': '2023-08-29T09:36:00+00:00',
#    'estimated_runway': '2023-08-29T09:36:00+00:00',
#    'actual_runway': '2023-08-29T09:36:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 54,
#    'scheduled': '2023-08-29T12:00:00+00:00',
#    'estimated': '2023-08-29T12:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4481',
#    'iata': 'MH4481',
#    'icao': 'MAS4481',
#    'codeshared': {'airline_name': 'china southern airlines',
#     'airline_iata': 'cz',
#     'airline_icao': 'csn',
#     'flight_number': '349',
#     'flight_iata': 'cz349',
#     'flight_icao': 'csn349'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': 'C36',
#    'delay': 22,
#    'scheduled': '2023-08-29T02:10:00+00:00',
#    'estimated': '2023-08-29T02:10:00+00:00',
#    'actual': '2023-08-29T05:18:00+00:00',
#    'estimated_runway': '2023-08-29T05:18:00+00:00',
#    'actual_runway': '2023-08-29T05:18:00+00:00'},
#   'arrival': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#    'timezone': 'Europe/Rome',
#    'iata': 'FCO',
#    'icao': 'LIRF',
#    'terminal': '3',
#    'gate': None,
#    'baggage': '12',
#    'delay': 131,
#    'scheduled': '2023-08-29T07:15:00+00:00',
#    'estimated': '2023-08-29T07:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9237',
#    'iata': 'MH9237',
#    'icao': 'MAS9237',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '115',
#     'flight_iata': 'qr115',
#     'flight_icao': 'qtr115'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Sultan Abdul Aziz Shah',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'SZB',
#    'icao': 'WMSA',
#    'terminal': None,
#    'gate': None,
#    'delay': 32,
#    'scheduled': '2023-08-29T10:10:00+00:00',
#    'estimated': '2023-08-29T10:10:00+00:00',
#    'actual': '2023-08-29T10:41:00+00:00',
#    'estimated_runway': '2023-08-29T10:41:00+00:00',
#    'actual_runway': '2023-08-29T10:41:00+00:00'},
#   'arrival': {'airport': 'Sultan Ismail International',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'JHB',
#    'icao': 'WMKJ',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 38,
#    'scheduled': '2023-08-29T11:15:00+00:00',
#    'estimated': '2023-08-29T11:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5337',
#    'iata': 'MH5337',
#    'icao': 'MAS5337',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '1338',
#     'flight_iata': 'fy1338',
#     'flight_icao': 'ffm1338'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 85,
#    'scheduled': '2023-08-29T09:40:00+00:00',
#    'estimated': '2023-08-29T09:40:00+00:00',
#    'actual': '2023-08-29T11:05:00+00:00',
#    'estimated_runway': '2023-08-29T11:05:00+00:00',
#    'actual_runway': '2023-08-29T11:05:00+00:00'},
#   'arrival': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': None,
#    'baggage': '37',
#    'delay': 56,
#    'scheduled': '2023-08-29T10:55:00+00:00',
#    'estimated': '2023-08-29T10:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '627',
#    'iata': 'MH627',
#    'icao': 'MAS627',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 77,
#    'scheduled': '2023-08-29T09:25:00+00:00',
#    'estimated': '2023-08-29T09:25:00+00:00',
#    'actual': '2023-08-29T10:42:00+00:00',
#    'estimated_runway': '2023-08-29T10:42:00+00:00',
#    'actual_runway': '2023-08-29T10:42:00+00:00'},
#   'arrival': {'airport': 'Madras International (Meenambakkam)',
#    'timezone': 'Asia/Kolkata',
#    'iata': 'MAA',
#    'icao': 'VOMM',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 50,
#    'scheduled': '2023-08-29T10:45:00+00:00',
#    'estimated': '2023-08-29T10:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '182',
#    'iata': 'MH182',
#    'icao': 'MAS182',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 76,
#    'scheduled': '2023-08-29T09:15:00+00:00',
#    'estimated': '2023-08-29T09:15:00+00:00',
#    'actual': '2023-08-29T10:30:00+00:00',
#    'estimated_runway': '2023-08-29T10:30:00+00:00',
#    'actual_runway': '2023-08-29T10:30:00+00:00'},
#   'arrival': {'airport': 'Kota-Kinabalu International Airport',
#    'timezone': 'Asia/Kuching',
#    'iata': 'BKI',
#    'icao': 'WBKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 55,
#    'scheduled': '2023-08-29T11:55:00+00:00',
#    'estimated': '2023-08-29T11:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2610',
#    'iata': 'MH2610',
#    'icao': 'MAS2610',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 84,
#    'scheduled': '2023-08-29T09:15:00+00:00',
#    'estimated': '2023-08-29T09:15:00+00:00',
#    'actual': '2023-08-29T10:39:00+00:00',
#    'estimated_runway': '2023-08-29T10:39:00+00:00',
#    'actual_runway': '2023-08-29T10:39:00+00:00'},
#   'arrival': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#    'timezone': 'Asia/Taipei',
#    'iata': 'TPE',
#    'icao': 'RCTP',
#    'terminal': '1',
#    'gate': 'A2',
#    'baggage': '3B',
#    'delay': 61,
#    'scheduled': '2023-08-29T14:10:00+00:00',
#    'estimated': '2023-08-29T14:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '366',
#    'iata': 'MH366',
#    'icao': 'MAS366',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 87,
#    'scheduled': '2023-08-29T09:10:00+00:00',
#    'estimated': '2023-08-29T09:10:00+00:00',
#    'actual': '2023-08-29T10:37:00+00:00',
#    'estimated_runway': '2023-08-29T10:37:00+00:00',
#    'actual_runway': '2023-08-29T10:37:00+00:00'},
#   'arrival': {'airport': 'Zia International',
#    'timezone': 'Asia/Dhaka',
#    'iata': 'DAC',
#    'icao': 'VGHS',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 62,
#    'scheduled': '2023-08-29T11:05:00+00:00',
#    'estimated': '2023-08-29T11:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '102',
#    'iata': 'MH102',
#    'icao': 'MAS102',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': 'F37',
#    'delay': 34,
#    'scheduled': '2023-08-29T09:55:00+00:00',
#    'estimated': '2023-08-29T09:55:00+00:00',
#    'actual': '2023-08-29T10:29:00+00:00',
#    'estimated_runway': '2023-08-29T10:29:00+00:00',
#    'actual_runway': '2023-08-29T10:29:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 35,
#    'scheduled': '2023-08-29T10:55:00+00:00',
#    'estimated': '2023-08-29T10:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '604',
#    'iata': 'MH604',
#    'icao': 'MAS604',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 95,
#    'scheduled': '2023-08-29T09:00:00+00:00',
#    'estimated': '2023-08-29T09:00:00+00:00',
#    'actual': '2023-08-29T10:35:00+00:00',
#    'estimated_runway': '2023-08-29T10:35:00+00:00',
#    'actual_runway': '2023-08-29T10:35:00+00:00'},
#   'arrival': {'airport': 'Suvarnabhumi International',
#    'timezone': 'Asia/Bangkok',
#    'iata': 'BKK',
#    'icao': 'VTBS',
#    'terminal': 'D',
#    'gate': None,
#    'baggage': None,
#    'delay': 72,
#    'scheduled': '2023-08-29T10:15:00+00:00',
#    'estimated': '2023-08-29T10:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '784',
#    'iata': 'MH784',
#    'icao': 'MAS784',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Sultan Ismail Petra',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KBR',
#    'icao': 'WMKC',
#    'terminal': None,
#    'gate': None,
#    'delay': 40,
#    'scheduled': '2023-08-29T08:50:00+00:00',
#    'estimated': '2023-08-29T08:50:00+00:00',
#    'actual': '2023-08-29T09:30:00+00:00',
#    'estimated_runway': '2023-08-29T09:30:00+00:00',
#    'actual_runway': '2023-08-29T09:30:00+00:00'},
#   'arrival': {'airport': 'Sultan Abdul Aziz Shah',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'SZB',
#    'icao': 'WMSA',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': 31,
#    'scheduled': '2023-08-29T09:55:00+00:00',
#    'estimated': '2023-08-29T09:55:00+00:00',
#    'actual': '2023-08-29T10:25:00+00:00',
#    'estimated_runway': '2023-08-29T10:25:00+00:00',
#    'actual_runway': '2023-08-29T10:25:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5301',
#    'iata': 'MH5301',
#    'icao': 'MAS5301',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '1145',
#     'flight_iata': 'fy1145',
#     'flight_icao': 'ffm1145'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': 'F35',
#    'delay': 45,
#    'scheduled': '2023-08-29T06:40:00+00:00',
#    'estimated': '2023-08-29T06:40:00+00:00',
#    'actual': '2023-08-29T07:24:00+00:00',
#    'estimated_runway': '2023-08-29T07:24:00+00:00',
#    'actual_runway': '2023-08-29T07:24:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 30,
#    'scheduled': '2023-08-29T07:40:00+00:00',
#    'estimated': '2023-08-29T07:40:00+00:00',
#    'actual': '2023-08-29T08:09:00+00:00',
#    'estimated_runway': '2023-08-29T08:09:00+00:00',
#    'actual_runway': '2023-08-29T08:09:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '602',
#    'iata': 'MH602',
#    'icao': 'MAS602',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Puerto Princesa',
#    'timezone': 'Asia/Manila',
#    'iata': 'PPS',
#    'icao': 'RPVP',
#    'terminal': None,
#    'gate': None,
#    'delay': 108,
#    'scheduled': '2023-08-29T06:00:00+00:00',
#    'estimated': '2023-08-29T06:00:00+00:00',
#    'actual': '2023-08-29T07:47:00+00:00',
#    'estimated_runway': '2023-08-29T07:47:00+00:00',
#    'actual_runway': '2023-08-29T07:47:00+00:00'},
#   'arrival': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 95,
#    'scheduled': '2023-08-29T07:20:00+00:00',
#    'estimated': '2023-08-29T07:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5964',
#    'iata': 'MH5964',
#    'icao': 'MAS5964',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2782',
#     'flight_iata': 'pr2782',
#     'flight_icao': 'pal2782'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'delay': 110,
#    'scheduled': '2023-08-29T04:00:00+00:00',
#    'estimated': '2023-08-29T04:00:00+00:00',
#    'actual': '2023-08-29T05:49:00+00:00',
#    'estimated_runway': '2023-08-29T05:49:00+00:00',
#    'actual_runway': '2023-08-29T05:49:00+00:00'},
#   'arrival': {'airport': 'Puerto Princesa',
#    'timezone': 'Asia/Manila',
#    'iata': 'PPS',
#    'icao': 'RPVP',
#    'terminal': '3',
#    'gate': None,
#    'baggage': None,
#    'delay': 87,
#    'scheduled': '2023-08-29T05:20:00+00:00',
#    'estimated': '2023-08-29T05:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5997',
#    'iata': 'MH5997',
#    'icao': 'MAS5997',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2781',
#     'flight_iata': 'pr2781',
#     'flight_icao': 'pal2781'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 105,
#    'scheduled': '2023-08-29T02:55:00+00:00',
#    'estimated': '2023-08-29T02:55:00+00:00',
#    'actual': '2023-08-29T04:39:00+00:00',
#    'estimated_runway': '2023-08-29T04:39:00+00:00',
#    'actual_runway': '2023-08-29T04:39:00+00:00'},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '4',
#    'delay': 78,
#    'scheduled': '2023-08-29T05:15:00+00:00',
#    'estimated': '2023-08-29T05:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '164',
#    'iata': 'MH164',
#    'icao': 'MAS164',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Auckland International',
#    'timezone': 'Pacific/Auckland',
#    'iata': 'AKL',
#    'icao': 'NZAA',
#    'terminal': 'I',
#    'gate': '2',
#    'delay': 123,
#    'scheduled': '2023-08-29T00:15:00+00:00',
#    'estimated': '2023-08-29T00:15:00+00:00',
#    'actual': '2023-08-29T02:17:00+00:00',
#    'estimated_runway': '2023-08-29T02:17:00+00:00',
#    'actual_runway': '2023-08-29T02:17:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 72,
#    'scheduled': '2023-08-29T07:40:00+00:00',
#    'estimated': '2023-08-29T07:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '132',
#    'iata': 'MH132',
#    'icao': 'MAS132',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MTW',
#    'iata': 'A332',
#    'icao': 'A332',
#    'icao24': '75046C'},
#   'live': {'updated': '2023-08-28T22:21:02+00:00',
#    'latitude': -6.12,
#    'longitude': 118.43,
#    'altitude': 12192,
#    'direction': 296,
#    'speed_horizontal': 918.592,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hartsfield-jackson Atlanta International',
#    'timezone': 'America/New_York',
#    'iata': 'ATL',
#    'icao': 'KATL',
#    'terminal': 'N',
#    'gate': 'T9',
#    'delay': 133,
#    'scheduled': '2023-08-28T18:24:00+00:00',
#    'estimated': '2023-08-28T18:24:00+00:00',
#    'actual': '2023-08-28T20:36:00+00:00',
#    'estimated_runway': '2023-08-28T20:36:00+00:00',
#    'actual_runway': '2023-08-28T20:36:00+00:00'},
#   'arrival': {'airport': "Chicago O'hare International",
#    'timezone': 'America/Chicago',
#    'iata': 'ORD',
#    'icao': 'KORD',
#    'terminal': '3',
#    'gate': 'L10A',
#    'baggage': None,
#    'delay': 79,
#    'scheduled': '2023-08-28T19:43:00+00:00',
#    'estimated': '2023-08-28T19:43:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9456',
#    'iata': 'MH9456',
#    'icao': 'MAS9456',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '4621',
#     'flight_iata': 'aa4621',
#     'flight_icao': 'aal4621'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Logan International',
#    'timezone': 'America/New_York',
#    'iata': 'BOS',
#    'icao': 'KBOS',
#    'terminal': 'B',
#    'gate': 'B12',
#    'delay': 81,
#    'scheduled': '2023-08-28T18:33:00+00:00',
#    'estimated': '2023-08-28T18:33:00+00:00',
#    'actual': '2023-08-28T19:59:00+00:00',
#    'estimated_runway': '2023-08-28T19:59:00+00:00',
#    'actual_runway': '2023-08-28T19:59:00+00:00'},
#   'arrival': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': '37',
#    'baggage': '9',
#    'delay': 46,
#    'scheduled': '2023-08-28T19:59:00+00:00',
#    'estimated': '2023-08-28T19:59:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9340',
#    'iata': 'MH9340',
#    'icao': 'MAS9340',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '4294',
#     'flight_iata': 'aa4294',
#     'flight_icao': 'aal4294'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': "Chicago O'hare International",
#    'timezone': 'America/Chicago',
#    'iata': 'ORD',
#    'icao': 'KORD',
#    'terminal': '3',
#    'gate': 'K16',
#    'delay': 164,
#    'scheduled': '2023-08-28T16:55:00+00:00',
#    'estimated': '2023-08-28T16:55:00+00:00',
#    'actual': '2023-08-28T19:46:00+00:00',
#    'estimated_runway': '2023-08-28T19:46:00+00:00',
#    'actual_runway': '2023-08-28T19:46:00+00:00'},
#   'arrival': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '5',
#    'gate': '53A',
#    'baggage': 'T5C5',
#    'delay': 137,
#    'scheduled': '2023-08-28T19:12:00+00:00',
#    'estimated': '2023-08-28T19:12:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9455',
#    'iata': 'MH9455',
#    'icao': 'MAS9455',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '2364',
#     'flight_iata': 'aa2364',
#     'flight_icao': 'aal2364'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'B13',
#    'delay': 96,
#    'scheduled': '2023-08-28T18:09:00+00:00',
#    'estimated': '2023-08-28T18:09:00+00:00',
#    'actual': '2023-08-28T19:45:00+00:00',
#    'estimated_runway': '2023-08-28T19:45:00+00:00',
#    'actual_runway': '2023-08-28T19:45:00+00:00'},
#   'arrival': {'airport': 'La Guardia',
#    'timezone': 'America/New_York',
#    'iata': 'LGA',
#    'icao': 'KLGA',
#    'terminal': 'B',
#    'gate': '17',
#    'baggage': '3',
#    'delay': 60,
#    'scheduled': '2023-08-28T20:00:00+00:00',
#    'estimated': '2023-08-28T20:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9604',
#    'iata': 'MH9604',
#    'icao': 'MAS9604',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1893',
#     'flight_iata': 'aa1893',
#     'flight_icao': 'aal1893'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'C12',
#    'delay': 133,
#    'scheduled': '2023-08-28T18:05:00+00:00',
#    'estimated': '2023-08-28T18:05:00+00:00',
#    'actual': '2023-08-28T20:17:00+00:00',
#    'estimated_runway': '2023-08-28T20:17:00+00:00',
#    'actual_runway': '2023-08-28T20:17:00+00:00'},
#   'arrival': {'airport': 'Dallas/Fort Worth International',
#    'timezone': 'America/Chicago',
#    'iata': 'DFW',
#    'icao': 'KDFW',
#    'terminal': 'C',
#    'gate': 'C36',
#    'baggage': 'C26',
#    'delay': 91,
#    'scheduled': '2023-08-28T19:54:00+00:00',
#    'estimated': '2023-08-28T19:54:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9505',
#    'iata': 'MH9505',
#    'icao': 'MAS9505',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1571',
#     'flight_iata': 'aa1571',
#     'flight_icao': 'aal1571'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D4',
#    'delay': 115,
#    'scheduled': '2023-08-28T17:30:00+00:00',
#    'estimated': '2023-08-28T17:30:00+00:00',
#    'actual': '2023-08-28T19:22:00+00:00',
#    'estimated_runway': '2023-08-28T19:22:00+00:00',
#    'actual_runway': '2023-08-28T19:22:00+00:00'},
#   'arrival': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '4',
#    'gate': '47A',
#    'baggage': 'T4A',
#    'delay': 65,
#    'scheduled': '2023-08-28T19:56:00+00:00',
#    'estimated': '2023-08-28T19:56:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9409',
#    'iata': 'MH9409',
#    'icao': 'MAS9409',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1998',
#     'flight_iata': 'aa1998',
#     'flight_icao': 'aal1998'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'C8',
#    'delay': 70,
#    'scheduled': '2023-08-28T17:31:00+00:00',
#    'estimated': '2023-08-28T17:31:00+00:00',
#    'actual': '2023-08-28T18:41:00+00:00',
#    'estimated_runway': '2023-08-28T18:41:00+00:00',
#    'actual_runway': '2023-08-28T18:41:00+00:00'},
#   'arrival': {'airport': 'Logan International',
#    'timezone': 'America/New_York',
#    'iata': 'BOS',
#    'icao': 'KBOS',
#    'terminal': 'B',
#    'gate': 'B21',
#    'baggage': '1',
#    'delay': 34,
#    'scheduled': '2023-08-28T19:42:00+00:00',
#    'estimated': '2023-08-28T19:42:00+00:00',
#    'actual': '2023-08-28T20:16:00+00:00',
#    'estimated_runway': '2023-08-28T20:16:00+00:00',
#    'actual_runway': '2023-08-28T20:16:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9462',
#    'iata': 'MH9462',
#    'icao': 'MAS9462',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1978',
#     'flight_iata': 'aa1978',
#     'flight_icao': 'aal1978'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': '35',
#    'delay': 150,
#    'scheduled': '2023-08-28T15:55:00+00:00',
#    'estimated': '2023-08-28T15:55:00+00:00',
#    'actual': '2023-08-28T18:25:00+00:00',
#    'estimated_runway': '2023-08-28T18:25:00+00:00',
#    'actual_runway': '2023-08-28T18:25:00+00:00'},
#   'arrival': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D1',
#    'baggage': '27',
#    'delay': 107,
#    'scheduled': '2023-08-28T19:17:00+00:00',
#    'estimated': '2023-08-28T19:17:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9377',
#    'iata': 'MH9377',
#    'icao': 'MAS9377',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '320',
#     'flight_iata': 'aa320',
#     'flight_icao': 'aal320'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '5',
#    'gate': '53A',
#    'delay': 87,
#    'scheduled': '2023-08-28T15:22:00+00:00',
#    'estimated': '2023-08-28T15:22:00+00:00',
#    'actual': '2023-08-28T16:48:00+00:00',
#    'estimated_runway': '2023-08-28T16:48:00+00:00',
#    'actual_runway': '2023-08-28T16:48:00+00:00'},
#   'arrival': {'airport': 'Nashville International',
#    'timezone': 'America/Chicago',
#    'iata': 'BNA',
#    'icao': 'KBNA',
#    'terminal': None,
#    'gate': 'C18',
#    'baggage': None,
#    'delay': 55,
#    'scheduled': '2023-08-28T21:27:00+00:00',
#    'estimated': '2023-08-28T21:27:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9419',
#    'iata': 'MH9419',
#    'icao': 'MAS9419',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1287',
#     'flight_iata': 'aa1287',
#     'flight_icao': 'aal1287'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'C11',
#    'delay': 126,
#    'scheduled': '2023-08-28T14:59:00+00:00',
#    'estimated': '2023-08-28T14:59:00+00:00',
#    'actual': '2023-08-28T17:04:00+00:00',
#    'estimated_runway': '2023-08-28T17:04:00+00:00',
#    'actual_runway': '2023-08-28T17:04:00+00:00'},
#   'arrival': {'airport': 'Logan International',
#    'timezone': 'America/New_York',
#    'iata': 'BOS',
#    'icao': 'KBOS',
#    'terminal': 'B',
#    'gate': 'B20',
#    'baggage': '1',
#    'delay': 92,
#    'scheduled': '2023-08-28T17:11:00+00:00',
#    'estimated': '2023-08-28T17:11:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9549',
#    'iata': 'MH9549',
#    'icao': 'MAS9549',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '806',
#     'flight_iata': 'aa806',
#     'flight_icao': 'aal806'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A11',
#    'delay': 130,
#    'scheduled': '2023-08-28T19:25:00+00:00',
#    'estimated': '2023-08-28T19:25:00+00:00',
#    'actual': '2023-08-28T21:34:00+00:00',
#    'estimated_runway': '2023-08-28T21:34:00+00:00',
#    'actual_runway': '2023-08-28T21:34:00+00:00'},
#   'arrival': {'airport': 'El Prat De Llobregat',
#    'timezone': 'Europe/Madrid',
#    'iata': 'BCN',
#    'icao': 'LEBL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '13',
#    'delay': 97,
#    'scheduled': '2023-08-28T22:30:00+00:00',
#    'estimated': '2023-08-28T22:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9704',
#    'iata': 'MH9704',
#    'icao': 'MAS9704',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '482',
#     'flight_iata': 'ba482',
#     'flight_icao': 'baw482'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'D13',
#    'delay': 92,
#    'scheduled': '2023-08-28T14:31:00+00:00',
#    'estimated': '2023-08-28T14:31:00+00:00',
#    'actual': '2023-08-28T16:02:00+00:00',
#    'estimated_runway': '2023-08-28T16:02:00+00:00',
#    'actual_runway': '2023-08-28T16:02:00+00:00'},
#   'arrival': {'airport': 'Dallas/Fort Worth International',
#    'timezone': 'America/Chicago',
#    'iata': 'DFW',
#    'icao': 'KDFW',
#    'terminal': 'C',
#    'gate': 'C19',
#    'baggage': 'C15',
#    'delay': 51,
#    'scheduled': '2023-08-28T16:21:00+00:00',
#    'estimated': '2023-08-28T16:21:00+00:00',
#    'actual': '2023-08-28T17:11:00+00:00',
#    'estimated_runway': '2023-08-28T17:11:00+00:00',
#    'actual_runway': '2023-08-28T17:11:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9518',
#    'iata': 'MH9518',
#    'icao': 'MAS9518',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '877',
#     'flight_iata': 'aa877',
#     'flight_icao': 'aal877'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'B12',
#    'delay': 69,
#    'scheduled': '2023-08-28T15:00:00+00:00',
#    'estimated': '2023-08-28T15:00:00+00:00',
#    'actual': '2023-08-28T16:09:00+00:00',
#    'estimated_runway': '2023-08-28T16:09:00+00:00',
#    'actual_runway': '2023-08-28T16:09:00+00:00'},
#   'arrival': {'airport': 'Baltimore/Washington International Thurgood Marshall',
#    'timezone': 'America/New_York',
#    'iata': 'BWI',
#    'icao': 'KBWI',
#    'terminal': 'E',
#    'gate': 'C5',
#    'baggage': '9',
#    'delay': 43,
#    'scheduled': '2023-08-28T16:26:00+00:00',
#    'estimated': '2023-08-28T16:26:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9517',
#    'iata': 'MH9517',
#    'icao': 'MAS9517',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1232',
#     'flight_iata': 'aa1232',
#     'flight_icao': 'aal1232'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Baltimore/Washington International Thurgood Marshall',
#    'timezone': 'America/New_York',
#    'iata': 'BWI',
#    'icao': 'KBWI',
#    'terminal': None,
#    'gate': 'C5',
#    'delay': 63,
#    'scheduled': '2023-08-28T17:16:00+00:00',
#    'estimated': '2023-08-28T17:16:00+00:00',
#    'actual': '2023-08-28T18:40:00+00:00',
#    'estimated_runway': '2023-08-28T18:40:00+00:00',
#    'actual_runway': '2023-08-28T18:40:00+00:00'},
#   'arrival': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': '3',
#    'gate': 'B14',
#    'baggage': 'C3',
#    'delay': 53,
#    'scheduled': '2023-08-28T18:46:00+00:00',
#    'estimated': '2023-08-28T18:46:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9606',
#    'iata': 'MH9606',
#    'icao': 'MAS9606',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1232',
#     'flight_iata': 'aa1232',
#     'flight_icao': 'aal1232'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '3',
#    'gate': '3A',
#    'delay': 89,
#    'scheduled': '2023-08-28T19:20:00+00:00',
#    'estimated': '2023-08-28T19:20:00+00:00',
#    'actual': '2023-08-28T20:48:00+00:00',
#    'estimated_runway': '2023-08-28T20:48:00+00:00',
#    'actual_runway': '2023-08-28T20:48:00+00:00'},
#   'arrival': {'airport': 'Vienna International',
#    'timezone': 'Europe/Vienna',
#    'iata': 'VIE',
#    'icao': 'LOWW',
#    'terminal': '3',
#    'gate': None,
#    'baggage': None,
#    'delay': 65,
#    'scheduled': '2023-08-28T22:40:00+00:00',
#    'estimated': '2023-08-28T22:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9920',
#    'iata': 'MH9920',
#    'icao': 'MAS9920',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '706',
#     'flight_iata': 'ba706',
#     'flight_icao': 'baw706'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'B45',
#    'delay': 85,
#    'scheduled': '2023-08-28T20:30:00+00:00',
#    'estimated': '2023-08-28T20:30:00+00:00',
#    'actual': '2023-08-28T21:55:00+00:00',
#    'estimated_runway': '2023-08-28T21:55:00+00:00',
#    'actual_runway': '2023-08-28T21:55:00+00:00'},
#   'arrival': {'airport': 'St-Exupéry',
#    'timezone': 'Europe/Paris',
#    'iata': 'LYS',
#    'icao': 'LFLL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '106',
#    'delay': 51,
#    'scheduled': '2023-08-28T23:10:00+00:00',
#    'estimated': '2023-08-28T23:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9874',
#    'iata': 'MH9874',
#    'icao': 'MAS9874',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '364',
#     'flight_iata': 'ba364',
#     'flight_icao': 'baw364'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charles De Gaulle',
#    'timezone': 'Europe/Paris',
#    'iata': 'CDG',
#    'icao': 'LFPG',
#    'terminal': '1',
#    'gate': '26',
#    'delay': 123,
#    'scheduled': '2023-08-28T16:05:00+00:00',
#    'estimated': '2023-08-28T16:05:00+00:00',
#    'actual': '2023-08-28T18:08:00+00:00',
#    'estimated_runway': '2023-08-28T18:08:00+00:00',
#    'actual_runway': '2023-08-28T18:08:00+00:00'},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '3',
#    'delay': 93,
#    'scheduled': '2023-08-28T23:25:00+00:00',
#    'estimated': '2023-08-28T23:25:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9216',
#    'iata': 'MH9216',
#    'icao': 'MAS9216',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '40',
#     'flight_iata': 'qr40',
#     'flight_icao': 'qtr40'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Helsinki-vantaa',
#    'timezone': 'Europe/Helsinki',
#    'iata': 'HEL',
#    'icao': 'EFHK',
#    'terminal': '2',
#    'gate': '19',
#    'delay': 45,
#    'scheduled': '2023-08-28T18:10:00+00:00',
#    'estimated': '2023-08-28T18:10:00+00:00',
#    'actual': '2023-08-28T18:55:00+00:00',
#    'estimated_runway': '2023-08-28T18:55:00+00:00',
#    'actual_runway': '2023-08-28T18:55:00+00:00'},
#   'arrival': {'airport': 'Schiphol',
#    'timezone': 'Europe/Amsterdam',
#    'iata': 'AMS',
#    'icao': 'EHAM',
#    'terminal': '2',
#    'gate': 'D85',
#    'baggage': '009',
#    'delay': 33,
#    'scheduled': '2023-08-28T19:40:00+00:00',
#    'estimated': '2023-08-28T19:40:00+00:00',
#    'actual': '2023-08-28T20:13:00+00:00',
#    'estimated_runway': '2023-08-28T20:13:00+00:00',
#    'actual_runway': '2023-08-28T20:13:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5674',
#    'iata': 'MH5674',
#    'icao': 'MAS5674',
#    'codeshared': {'airline_name': 'klm',
#     'airline_iata': 'kl',
#     'airline_icao': 'klm',
#     'flight_number': '1170',
#     'flight_iata': 'kl1170',
#     'flight_icao': 'klm1170'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#    'timezone': 'Europe/Rome',
#    'iata': 'FCO',
#    'icao': 'LIRF',
#    'terminal': '1',
#    'gate': 'A61',
#    'delay': 98,
#    'scheduled': '2023-08-28T17:25:00+00:00',
#    'estimated': '2023-08-28T17:25:00+00:00',
#    'actual': '2023-08-28T19:03:00+00:00',
#    'estimated_runway': '2023-08-28T19:03:00+00:00',
#    'actual_runway': '2023-08-28T19:03:00+00:00'},
#   'arrival': {'airport': 'Schiphol',
#    'timezone': 'Europe/Amsterdam',
#    'iata': 'AMS',
#    'icao': 'EHAM',
#    'terminal': '3',
#    'gate': 'C15',
#    'baggage': '015',
#    'delay': 53,
#    'scheduled': '2023-08-28T20:00:00+00:00',
#    'estimated': '2023-08-28T20:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5680',
#    'iata': 'MH5680',
#    'icao': 'MAS5680',
#    'codeshared': {'airline_name': 'klm',
#     'airline_iata': 'kl',
#     'airline_icao': 'klm',
#     'flight_number': '1604',
#     'flight_iata': 'kl1604',
#     'flight_icao': 'klm1604'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A21',
#    'delay': 63,
#    'scheduled': '2023-08-28T19:55:00+00:00',
#    'estimated': '2023-08-28T19:55:00+00:00',
#    'actual': '2023-08-28T20:58:00+00:00',
#    'estimated_runway': '2023-08-28T20:58:00+00:00',
#    'actual_runway': '2023-08-28T20:58:00+00:00'},
#   'arrival': {'airport': 'Kastrup',
#    'timezone': 'Europe/Copenhagen',
#    'iata': 'CPH',
#    'icao': 'EKCH',
#    'terminal': '2',
#    'gate': 'C27',
#    'baggage': None,
#    'delay': 33,
#    'scheduled': '2023-08-28T22:50:00+00:00',
#    'estimated': '2023-08-28T22:50:00+00:00',
#    'actual': '2023-08-28T23:23:00+00:00',
#    'estimated_runway': '2023-08-28T23:23:00+00:00',
#    'actual_runway': '2023-08-28T23:23:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9804',
#    'iata': 'MH9804',
#    'icao': 'MAS9804',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '822',
#     'flight_iata': 'ba822',
#     'flight_icao': 'baw822'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A10',
#    'delay': 108,
#    'scheduled': '2023-08-28T20:05:00+00:00',
#    'estimated': '2023-08-28T20:05:00+00:00',
#    'actual': '2023-08-28T21:53:00+00:00',
#    'estimated_runway': '2023-08-28T21:53:00+00:00',
#    'actual_runway': '2023-08-28T21:53:00+00:00'},
#   'arrival': {'airport': 'Geneve-cointrin',
#    'timezone': 'Europe/Zurich',
#    'iata': 'GVA',
#    'icao': 'LSGG',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '7',
#    'delay': 82,
#    'scheduled': '2023-08-28T22:45:00+00:00',
#    'estimated': '2023-08-28T22:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9860',
#    'iata': 'MH9860',
#    'icao': 'MAS9860',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '738',
#     'flight_iata': 'ba738',
#     'flight_icao': 'baw738'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'B45',
#    'delay': 153,
#    'scheduled': '2023-08-28T13:30:00+00:00',
#    'estimated': '2023-08-28T13:30:00+00:00',
#    'actual': '2023-08-28T16:03:00+00:00',
#    'estimated_runway': '2023-08-28T16:03:00+00:00',
#    'actual_runway': '2023-08-28T16:03:00+00:00'},
#   'arrival': {'airport': 'El Prat De Llobregat',
#    'timezone': 'Europe/Madrid',
#    'iata': 'BCN',
#    'icao': 'LEBL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '11',
#    'delay': 118,
#    'scheduled': '2023-08-28T16:40:00+00:00',
#    'estimated': '2023-08-28T16:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9700',
#    'iata': 'MH9700',
#    'icao': 'MAS9700',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '406',
#     'flight_iata': 'ba406',
#     'flight_icao': 'baw406'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A13',
#    'delay': 127,
#    'scheduled': '2023-08-28T13:20:00+00:00',
#    'estimated': '2023-08-28T13:20:00+00:00',
#    'actual': '2023-08-28T15:27:00+00:00',
#    'estimated_runway': '2023-08-28T15:27:00+00:00',
#    'actual_runway': '2023-08-28T15:27:00+00:00'},
#   'arrival': {'airport': 'Charles De Gaulle',
#    'timezone': 'Europe/Paris',
# ...
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 43,
#    'scheduled': '2023-08-28T17:50:00+00:00',
#    'estimated': '2023-08-28T17:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '865',
#    'iata': 'MH865',
#    'icao': 'MAS865',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Miri',
#    'timezone': 'Asia/Kuching',
#    'iata': 'MYY',
#    'icao': 'WBGR',
#    'terminal': None,
#    'gate': None,
#    'delay': 59,
#    'scheduled': '2023-08-28T16:25:00+00:00',
#    'estimated': '2023-08-28T16:25:00+00:00',
#    'actual': '2023-08-28T17:23:00+00:00',
#    'estimated_runway': '2023-08-28T17:23:00+00:00',
#    'actual_runway': '2023-08-28T17:23:00+00:00'},
#   'arrival': {'airport': 'Kuching',
#    'timezone': 'Asia/Kuching',
#    'iata': 'KCH',
#    'icao': 'WBGG',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 45,
#    'scheduled': '2023-08-28T17:25:00+00:00',
#    'estimated': '2023-08-28T17:25:00+00:00',
#    'actual': '2023-08-28T18:10:00+00:00',
#    'estimated_runway': '2023-08-28T18:10:00+00:00',
#    'actual_runway': '2023-08-28T18:10:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4713',
#    'iata': 'MH4713',
#    'icao': 'MAS4713',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '2681',
#     'flight_iata': 'fy2681',
#     'flight_icao': 'ffm2681'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 58,
#    'scheduled': '2023-08-28T15:55:00+00:00',
#    'estimated': '2023-08-28T15:55:00+00:00',
#    'actual': '2023-08-28T16:52:00+00:00',
#    'estimated_runway': '2023-08-28T16:52:00+00:00',
#    'actual_runway': '2023-08-28T16:52:00+00:00'},
#   'arrival': {'airport': 'Langakawi International',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'LGK',
#    'icao': 'WMKL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 42,
#    'scheduled': '2023-08-28T17:00:00+00:00',
#    'estimated': '2023-08-28T17:00:00+00:00',
#    'actual': '2023-08-28T17:41:00+00:00',
#    'estimated_runway': '2023-08-28T17:41:00+00:00',
#    'actual_runway': '2023-08-28T17:41:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '1446',
#    'iata': 'MH1446',
#    'icao': 'MAS1446',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 76,
#    'scheduled': '2023-08-28T15:25:00+00:00',
#    'estimated': '2023-08-28T15:25:00+00:00',
#    'actual': '2023-08-28T16:40:00+00:00',
#    'estimated_runway': '2023-08-28T16:40:00+00:00',
#    'actual_runway': '2023-08-28T16:40:00+00:00'},
#   'arrival': {'airport': 'Kuching',
#    'timezone': 'Asia/Kuching',
#    'iata': 'KCH',
#    'icao': 'WBGG',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 60,
#    'scheduled': '2023-08-28T17:15:00+00:00',
#    'estimated': '2023-08-28T17:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2544',
#    'iata': 'MH2544',
#    'icao': 'MAS2544',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 93,
#    'scheduled': '2023-08-28T15:10:00+00:00',
#    'estimated': '2023-08-28T15:10:00+00:00',
#    'actual': '2023-08-28T16:42:00+00:00',
#    'estimated_runway': '2023-08-28T16:42:00+00:00',
#    'actual_runway': '2023-08-28T16:42:00+00:00'},
#   'arrival': {'airport': 'King Abdulaziz International',
#    'timezone': 'Asia/Riyadh',
#    'iata': 'JED',
#    'icao': 'OEJN',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 65,
#    'scheduled': '2023-08-28T19:00:00+00:00',
#    'estimated': '2023-08-28T19:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '156',
#    'iata': 'MH156',
#    'icao': 'MAS156',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MTJ',
#    'iata': 'A333',
#    'icao': 'A333',
#    'icao24': '75025D'},
#   'live': {'updated': '2023-08-28T14:06:49+00:00',
#    'latitude': 19.2,
#    'longitude': 61.27,
#    'altitude': 12192,
#    'direction': 281,
#    'speed_horizontal': 898.22,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Penang International',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'PEN',
#    'icao': 'WMKP',
#    'terminal': None,
#    'gate': None,
#    'delay': 74,
#    'scheduled': '2023-08-28T15:30:00+00:00',
#    'estimated': '2023-08-28T15:30:00+00:00',
#    'actual': '2023-08-28T16:43:00+00:00',
#    'estimated_runway': '2023-08-28T16:43:00+00:00',
#    'actual_runway': '2023-08-28T16:43:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 56,
#    'scheduled': '2023-08-28T16:35:00+00:00',
#    'estimated': '2023-08-28T16:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '1149',
#    'iata': 'MH1149',
#    'icao': 'MAS1149',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Sultan Ismail Petra',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KBR',
#    'icao': 'WMKC',
#    'terminal': None,
#    'gate': None,
#    'delay': 49,
#    'scheduled': '2023-08-28T20:55:00+00:00',
#    'estimated': '2023-08-28T20:55:00+00:00',
#    'actual': '2023-08-28T21:43:00+00:00',
#    'estimated_runway': '2023-08-28T21:43:00+00:00',
#    'actual_runway': '2023-08-28T21:43:00+00:00'},
#   'arrival': {'airport': 'Sultan Abdul Aziz Shah',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'SZB',
#    'icao': 'WMSA',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': 37,
#    'scheduled': '2023-08-28T22:00:00+00:00',
#    'estimated': '2023-08-28T22:00:00+00:00',
#    'actual': '2023-08-28T22:36:00+00:00',
#    'estimated_runway': '2023-08-28T22:36:00+00:00',
#    'actual_runway': '2023-08-28T22:36:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5325',
#    'iata': 'MH5325',
#    'icao': 'MAS5325',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '1153',
#     'flight_iata': 'fy1153',
#     'flight_icao': 'ffm1153'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': 'E1',
#    'delay': 50,
#    'scheduled': '2023-08-28T15:35:00+00:00',
#    'estimated': '2023-08-28T15:35:00+00:00',
#    'actual': '2023-08-28T16:25:00+00:00',
#    'estimated_runway': '2023-08-28T16:25:00+00:00',
#    'actual_runway': '2023-08-28T16:25:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 40,
#    'scheduled': '2023-08-28T16:35:00+00:00',
#    'estimated': '2023-08-28T16:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '624',
#    'iata': 'MH624',
#    'icao': 'MAS624',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kota-Kinabalu International Airport',
#    'timezone': 'Asia/Kuching',
#    'iata': 'BKI',
#    'icao': 'WBKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 29,
#    'scheduled': '2023-08-28T15:30:00+00:00',
#    'estimated': '2023-08-28T15:30:00+00:00',
#    'actual': '2023-08-28T15:59:00+00:00',
#    'estimated_runway': '2023-08-28T15:59:00+00:00',
#    'actual_runway': '2023-08-28T15:59:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 31,
#    'scheduled': '2023-08-28T18:05:00+00:00',
#    'estimated': '2023-08-28T18:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2641',
#    'iata': 'MH2641',
#    'icao': 'MAS2641',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MXR',
#    'iata': 'B738',
#    'icao': 'B738',
#    'icao24': '75021C'},
#   'live': {'updated': '2023-08-28T08:03:02+00:00',
#    'latitude': 5.79,
#    'longitude': 115.9,
#    'altitude': 2240.28,
#    'direction': 256,
#    'speed_horizontal': 483.372,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Sydney Kingsford Smith Airport',
#    'timezone': 'Australia/Sydney',
#    'iata': 'SYD',
#    'icao': 'YSSY',
#    'terminal': None,
#    'gate': None,
#    'delay': 336,
#    'scheduled': '2023-08-28T16:40:00+00:00',
#    'estimated': '2023-08-28T16:40:00+00:00',
#    'actual': '2023-08-28T22:16:00+00:00',
#    'estimated_runway': '2023-08-28T22:16:00+00:00',
#    'actual_runway': '2023-08-28T22:16:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 390,
#    'scheduled': '2023-08-28T22:05:00+00:00',
#    'estimated': '2023-08-28T22:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '6204',
#    'iata': 'MH6204',
#    'icao': 'MAS6204',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MUA',
#    'iata': 'A332',
#    'icao': 'A332',
#    'icao24': '750263'},
#   'live': {'updated': '2023-08-28T12:36:20+00:00',
#    'latitude': -33.31,
#    'longitude': 148.87,
#    'altitude': 11201.4,
#    'direction': 288,
#    'speed_horizontal': 859.328,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuching',
#    'timezone': 'Asia/Kuching',
#    'iata': 'KCH',
#    'icao': 'WBGG',
#    'terminal': None,
#    'gate': None,
#    'delay': 51,
#    'scheduled': '2023-08-28T14:45:00+00:00',
#    'estimated': '2023-08-28T14:45:00+00:00',
#    'actual': '2023-08-28T15:35:00+00:00',
#    'estimated_runway': '2023-08-28T15:35:00+00:00',
#    'actual_runway': '2023-08-28T15:35:00+00:00'},
#   'arrival': {'airport': 'Miri',
#    'timezone': 'Asia/Kuching',
#    'iata': 'MYY',
#    'icao': 'WBGR',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 41,
#    'scheduled': '2023-08-28T15:45:00+00:00',
#    'estimated': '2023-08-28T15:45:00+00:00',
#    'actual': '2023-08-28T16:26:00+00:00',
#    'estimated_runway': '2023-08-28T16:26:00+00:00',
#    'actual_runway': '2023-08-28T16:26:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4712',
#    'iata': 'MH4712',
#    'icao': 'MAS4712',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '2680',
#     'flight_iata': 'fy2680',
#     'flight_icao': 'ffm2680'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 82,
#    'scheduled': '2023-08-28T15:05:00+00:00',
#    'estimated': '2023-08-28T15:05:00+00:00',
#    'actual': '2023-08-28T16:26:00+00:00',
#    'estimated_runway': '2023-08-28T16:26:00+00:00',
#    'actual_runway': '2023-08-28T16:26:00+00:00'},
#   'arrival': {'airport': 'Suvarnabhumi International',
#    'timezone': 'Asia/Bangkok',
#    'iata': 'BKK',
#    'icao': 'VTBS',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 55,
#    'scheduled': '2023-08-28T16:20:00+00:00',
#    'estimated': '2023-08-28T16:20:00+00:00',
#    'actual': '2023-08-28T17:15:00+00:00',
#    'estimated_runway': '2023-08-28T17:15:00+00:00',
#    'actual_runway': '2023-08-28T17:15:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '782',
#    'iata': 'MH782',
#    'icao': 'MAS782',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 65,
#    'scheduled': '2023-08-28T14:55:00+00:00',
#    'estimated': '2023-08-28T14:55:00+00:00',
#    'actual': '2023-08-28T15:59:00+00:00',
#    'estimated_runway': '2023-08-28T15:59:00+00:00',
#    'actual_runway': '2023-08-28T15:59:00+00:00'},
#   'arrival': {'airport': None,
#    'timezone': None,
#    'iata': 'KNO',
#    'icao': 'WIMM',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 40,
#    'scheduled': '2023-08-28T15:00:00+00:00',
#    'estimated': '2023-08-28T15:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '864',
#    'iata': 'MH864',
#    'icao': 'MAS864',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 58,
#    'scheduled': '2023-08-28T14:40:00+00:00',
#    'estimated': '2023-08-28T14:40:00+00:00',
#    'actual': '2023-08-28T15:37:00+00:00',
#    'estimated_runway': '2023-08-28T15:37:00+00:00',
#    'actual_runway': '2023-08-28T15:37:00+00:00'},
#   'arrival': {'airport': 'Labuan',
#    'timezone': 'Asia/Kuching',
#    'iata': 'LBU',
#    'icao': 'WBKL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 32,
#    'scheduled': '2023-08-28T17:10:00+00:00',
#    'estimated': '2023-08-28T17:10:00+00:00',
#    'actual': '2023-08-28T17:41:00+00:00',
#    'estimated_runway': '2023-08-28T17:41:00+00:00',
#    'actual_runway': '2023-08-28T17:41:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2634',
#    'iata': 'MH2634',
#    'icao': 'MAS2634',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None}]

# %%
with open("../tests/data/sample_flight_response.json", "w") as j:
    j.write(json.dumps(api_response))

# %%
for key in api_response["data"][0]:
    print(key)
# Out:
# flight_date
# flight_status
# departure
# arrival
# airline
# flight
# aircraft
# live

# %%
api_response["data"][0]["airline"]
# Out:
# {'name': 'Lion Air', 'iata': 'JT', 'icao': 'LNI'}

# %%
mh = [flight for flight in api_response["data"] if "malaysia" in flight["airline"]]
mh
# Out:
# []

# %%
airlines = [flight["airline"]["name"] for flight in api_response["data"]]
airlines = set(airlines)
airlines
# Out:
# {'Air Astana',
#  'Air Canada',
#  'Air China LTD',
#  'Air India',
#  'Air New Zealand',
#  'Airblue',
#  'Alaska Airlines',
#  'Alliance Airlines',
#  'Aurora',
#  'Bamboo Airways',
#  'Bangkok Airways',
#  'China Eastern Airlines',
#  'China Postal Airlines',
#  'Emirates',
#  'Etihad Airways',
#  'Finnair',
#  'FlexFlight',
#  'Hawaiian Airlines',
#  'Jet Linx Aviation',
#  'Jetstar',
#  'Kuwait Airways',
#  'LATAM Airlines',
#  'Lion Air',
#  'Longhao Airlines',
#  'Myanmar Airways International',
#  None,
#  'Philippine Airlines',
#  'Qantas',
#  'Qatar Airways',
#  'S7 Airlines',
#  'SF Airlines',
#  'Sichuan Airlines',
#  'Singapore Airlines',
#  'SriLankan Airlines',
#  'Sriwijaya Air',
#  'Virgin Australia',
#  'Yakutia'}

# %%
"Malaysia Airlines" in airlines
# Out:
# False
