# %% [markdown]
# # Testing aviationstack's api

# %%
import os
import requests
import sqlite3
import json
from pathlib import Path
from dotenv import load_dotenv

# %%
env_path = Path("../.env")
load_dotenv(env_path)
av_api_key = os.getenv("AVIATION_API_KEY", "")
av_api_url = "http://api.aviationstack.com/v1/"
flight_api_url = av_api_url + "flights"
airline_api_url = av_api_url + "airlines"
params = {
    "access_key": av_api_key,
    "airline_name": "Malaysia Airlines",
    # "flight_date": "2023-08-22",
}

# %% [markdown]
# ## Retrieving flights for malaysia airlines

# %%
# basic plan must use http, not https
params = {"access_key": av_api_key, "limit": 100}

# %%
api_result = requests.get(airline_api_url, params)
airline_response = api_result.json()
airline_response
# Out:
# {'pagination': {'offset': 0, 'limit': 100, 'count': 100, 'total': 13130},
#  'data': [{'id': '1',
#    'fleet_average_age': '10.9',
#    'airline_id': '1',
#    'callsign': 'AMERICAN',
#    'hub_code': 'DFW',
#    'iata_code': 'AA',
#    'icao_code': 'AAL',
#    'country_iso2': 'US',
#    'date_founded': '1934',
#    'iata_prefix_accounting': '1',
#    'airline_name': 'American Airlines',
#    'country_name': 'United States',
#    'fleet_size': '963',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '2',
#    'fleet_average_age': '17',
#    'airline_id': '2',
#    'callsign': 'DELTA',
#    'hub_code': 'ATL',
#    'iata_code': 'DL',
#    'icao_code': 'DAL',
#    'country_iso2': 'US',
#    'date_founded': '1928',
#    'iata_prefix_accounting': '6',
#    'airline_name': 'Delta Air Lines',
#    'country_name': 'United States',
#    'fleet_size': '823',
#    'status': 'active',
#    'type': 'scheduled,division'},
#   {'id': '3',
#    'fleet_average_age': '13.8',
#    'airline_id': '3',
#    'callsign': 'UNITED',
#    'hub_code': 'ORD',
#    'iata_code': 'UA',
#    'icao_code': 'UAL',
#    'country_iso2': 'US',
#    'date_founded': '1931',
#    'iata_prefix_accounting': '16',
#    'airline_name': 'United Airlines',
#    'country_name': 'United States',
#    'fleet_size': '715',
#    'status': 'active',
#    'type': 'scheduled,division'},
#   {'id': '4',
#    'fleet_average_age': '12.3',
#    'airline_id': '4',
#    'callsign': 'SOUTHWEST',
#    'hub_code': 'DAL',
#    'iata_code': 'WN',
#    'icao_code': 'SWA',
#    'country_iso2': 'UM',
#    'date_founded': '1967',
#    'iata_prefix_accounting': '526',
#    'airline_name': 'Southwest Airlines Co.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '712',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '5',
#    'fleet_average_age': '6.9',
#    'airline_id': '5',
#    'callsign': 'CHINA SOUTHERN',
#    'hub_code': 'CAN',
#    'iata_code': 'CZ',
#    'icao_code': 'CSN',
#    'country_iso2': 'CN',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '784',
#    'airline_name': 'China Southern Airlines',
#    'country_name': 'China',
#    'fleet_size': '498',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '6',
#    'fleet_average_age': '8.4',
#    'airline_id': '6',
#    'callsign': 'CHINA EASTERN',
#    'hub_code': 'PVG',
#    'iata_code': 'MU',
#    'icao_code': 'CES',
#    'country_iso2': 'CN',
#    'date_founded': '1988',
#    'iata_prefix_accounting': '781',
#    'airline_name': 'China Eastern',
#    'country_name': 'China',
#    'fleet_size': '407',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '7',
#    'fleet_average_age': '11.1',
#    'airline_id': '7',
#    'callsign': 'SKYWEST',
#    'hub_code': 'SLC',
#    'iata_code': 'OO',
#    'icao_code': 'SKW',
#    'country_iso2': 'UM',
#    'date_founded': '1972',
#    'iata_prefix_accounting': '302',
#    'airline_name': 'SkyWest Airlines',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '382',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '8',
#    'fleet_average_age': '6.2',
#    'airline_id': '8',
#    'callsign': 'AIR CHINA',
#    'hub_code': 'PEK',
#    'iata_code': 'CA',
#    'icao_code': 'CCA',
#    'country_iso2': 'CN',
#    'date_founded': '1988',
#    'iata_prefix_accounting': '999',
#    'airline_name': 'Air China Limited',
#    'country_name': 'China',
#    'fleet_size': '369',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '9',
#    'fleet_average_age': '21.9',
#    'airline_id': '9',
#    'callsign': 'FEDEX',
#    'hub_code': 'MEM',
#    'iata_code': 'FX',
#    'icao_code': 'FDX',
#    'country_iso2': 'US',
#    'date_founded': '1971',
#    'iata_prefix_accounting': '23',
#    'airline_name': 'Federal Express',
#    'country_name': 'United States',
#    'fleet_size': '367',
#    'status': 'active',
#    'type': 'scheduled,cargo'},
#   {'id': '10',
#    'fleet_average_age': '6.4',
#    'airline_id': '10',
#    'callsign': 'RYANAIR',
#    'hub_code': 'STN',
#    'iata_code': 'FR',
#    'icao_code': 'RYR',
#    'country_iso2': 'IE',
#    'date_founded': '1985',
#    'iata_prefix_accounting': '224',
#    'airline_name': 'Ryanair Ltd.',
#    'country_name': 'Ireland',
#    'fleet_size': '353',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '11',
#    'fleet_average_age': '13.2',
#    'airline_id': '11',
#    'callsign': 'JET LINK',
#    'hub_code': None,
#    'iata_code': 'XE',
#    'icao_code': 'BTA',
#    'country_iso2': 'UM',
#    'date_founded': None,
#    'iata_prefix_accounting': None,
#    'airline_name': 'Expressjet',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '319',
#    'status': 'active',
#    'type': None},
#   {'id': '12',
#    'fleet_average_age': '6.3',
#    'airline_id': '12',
#    'callsign': 'TURKISH',
#    'hub_code': 'IST',
#    'iata_code': 'TK',
#    'icao_code': 'THY',
#    'country_iso2': 'TR',
#    'date_founded': '1933',
#    'iata_prefix_accounting': '235',
#    'airline_name': 'THY - Turkish Airlines',
#    'country_name': 'Turkey',
#    'fleet_size': '285',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '13',
#    'fleet_average_age': '10.9',
#    'airline_id': '13',
#    'callsign': 'LUFTHANSA',
#    'hub_code': 'FRA',
#    'iata_code': 'LH',
#    'icao_code': 'GEC',
#    'country_iso2': 'DE',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '20',
#    'airline_name': 'Lufthansa Cargo',
#    'country_name': 'Germany',
#    'fleet_size': '276',
#    'status': 'active',
#    'type': 'scheduled,cargo'},
#   {'id': '14',
#    'fleet_average_age': '12.7',
#    'airline_id': '14',
#    'callsign': 'SPEEDBIRD',
#    'hub_code': 'LHR',
#    'iata_code': 'BA',
#    'icao_code': 'BAW',
#    'country_iso2': 'GB',
#    'date_founded': '1974',
#    'iata_prefix_accounting': '125',
#    'airline_name': 'British Airways',
#    'country_name': 'United Kingdom',
#    'fleet_size': '265',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '15',
#    'fleet_average_age': '6.1',
#    'airline_id': '15',
#    'callsign': 'EMIRATES',
#    'hub_code': 'DXB',
#    'iata_code': 'EK',
#    'icao_code': 'UAE',
#    'country_iso2': 'AE',
#    'date_founded': '1985',
#    'iata_prefix_accounting': '176',
#    'airline_name': 'Emirates',
#    'country_name': 'United Arab Emirates',
#    'fleet_size': '249',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '16',
#    'fleet_average_age': '17.5',
#    'airline_id': '16',
#    'callsign': 'UPS',
#    'hub_code': 'SDF',
#    'iata_code': '5X',
#    'icao_code': 'UPS',
#    'country_iso2': 'US',
#    'date_founded': '1907',
#    'iata_prefix_accounting': '406',
#    'airline_name': 'UPS Airlines',
#    'country_name': 'United States',
#    'fleet_size': '237',
#    'status': 'active',
#    'type': 'cargo'},
#   {'id': '17',
#    'fleet_average_age': '6.6',
#    'airline_id': '17',
#    'callsign': 'EASY',
#    'hub_code': 'LGW',
#    'iata_code': 'U2',
#    'icao_code': 'EZY',
#    'country_iso2': 'GB',
#    'date_founded': '1995',
#    'iata_prefix_accounting': None,
#    'airline_name': 'Easyjet Airline Company Limited',
#    'country_name': 'United Kingdom',
#    'fleet_size': '228',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '18',
#    'fleet_average_age': '11.7',
#    'airline_id': '18',
#    'callsign': 'AIRFRANS',
#    'hub_code': 'CDG',
#    'iata_code': 'AF',
#    'icao_code': 'AFR',
#    'country_iso2': 'FR',
#    'date_founded': '1933',
#    'iata_prefix_accounting': '57',
#    'airline_name': 'Air France',
#    'country_name': 'France',
#    'fleet_size': '226',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '19',
#    'fleet_average_age': '8.7',
#    'airline_id': '19',
#    'callsign': 'JETBLUE',
#    'hub_code': 'JFK',
#    'iata_code': 'B6',
#    'icao_code': 'JBU',
#    'country_iso2': 'US',
#    'date_founded': '2000',
#    'iata_prefix_accounting': '279',
#    'airline_name': 'JetBlue',
#    'country_name': 'United States',
#    'fleet_size': '218',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '20',
#    'fleet_average_age': '9.5',
#    'airline_id': '20',
#    'callsign': 'ALL NIPPON',
#    'hub_code': 'HND',
#    'iata_code': 'NH',
#    'icao_code': 'ANA',
#    'country_iso2': 'JP',
#    'date_founded': '1952',
#    'iata_prefix_accounting': '205',
#    'airline_name': 'All Nippon Airways',
#    'country_name': 'Japan',
#    'fleet_size': '206',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '21',
#    'fleet_average_age': '5.7',
#    'airline_id': '21',
#    'callsign': 'QATARI',
#    'hub_code': 'DOH',
#    'iata_code': 'QR',
#    'icao_code': 'QTR',
#    'country_iso2': 'QA',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '157',
#    'airline_name': 'Qatar Airways',
#    'country_name': 'Qatar',
#    'fleet_size': '176',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '22',
#    'fleet_average_age': '11.6',
#    'airline_id': '22',
#    'callsign': 'ENVOY',
#    'hub_code': 'DFW',
#    'iata_code': 'MQ',
#    'icao_code': 'ENY',
#    'country_iso2': 'UM',
#    'date_founded': '2014',
#    'iata_prefix_accounting': '93',
#    'airline_name': 'Envoy Air Inc.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '171',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '23',
#    'fleet_average_age': '4.3',
#    'airline_id': '23',
#    'callsign': 'AEROFLOT',
#    'hub_code': 'SVO',
#    'iata_code': 'SU',
#    'icao_code': 'AFL',
#    'country_iso2': 'RU',
#    'date_founded': '1923',
#    'iata_prefix_accounting': '555',
#    'airline_name': 'Aeroflot',
#    'country_name': 'Russia',
#    'fleet_size': '168',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '24',
#    'fleet_average_age': '5.8',
#    'airline_id': '24',
#    'callsign': 'SHENZHEN AIR',
#    'hub_code': 'SZX',
#    'iata_code': 'ZH',
#    'icao_code': 'CSZ',
#    'country_iso2': 'CN',
#    'date_founded': '1992',
#    'iata_prefix_accounting': '479',
#    'airline_name': 'Shenzhen Airlines',
#    'country_name': 'China',
#    'fleet_size': '165',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '25',
#    'fleet_average_age': '25',
#    'airline_id': '25',
#    'callsign': 'AIR CANADA',
#    'hub_code': 'YYZ',
#    'iata_code': 'AC',
#    'icao_code': 'ACA',
#    'country_iso2': 'CA',
#    'date_founded': '2001',
#    'iata_prefix_accounting': '14',
#    'airline_name': 'Air Canada',
#    'country_name': 'Canada',
#    'fleet_size': '164',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '26',
#    'fleet_average_age': '7.4',
#    'airline_id': '26',
#    'callsign': 'TAM',
#    'hub_code': 'CGH',
#    'iata_code': 'JJ',
#    'icao_code': 'TAM',
#    'country_iso2': 'BR',
#    'date_founded': '1976',
#    'iata_prefix_accounting': '957',
#    'airline_name': 'TAM Linhas Aereas',
#    'country_name': 'Brazil',
#    'fleet_size': '163',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '27',
#    'fleet_average_age': '9',
#    'airline_id': '27',
#    'callsign': 'JAPANAIR',
#    'hub_code': 'HND',
#    'iata_code': 'JL',
#    'icao_code': 'JAL',
#    'country_iso2': 'JP',
#    'date_founded': '1951',
#    'iata_prefix_accounting': '131',
#    'airline_name': 'Japan Airlines',
#    'country_name': 'Japan',
#    'fleet_size': '163',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '28',
#    'fleet_average_age': '9.5',
#    'airline_id': '28',
#    'callsign': 'KOREANAIR',
#    'hub_code': 'ICN',
#    'iata_code': 'KE',
#    'icao_code': 'KAL',
#    'country_iso2': 'KR',
#    'date_founded': '1962',
#    'iata_prefix_accounting': '180',
#    'airline_name': 'Korean Air',
#    'country_name': 'South Korea',
#    'fleet_size': '159',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '29',
#    'fleet_average_age': '9.5',
#    'airline_id': '29',
#    'callsign': 'ALASKA',
#    'hub_code': 'SEA',
#    'iata_code': 'AS',
#    'icao_code': 'ASA',
#    'country_iso2': 'US',
#    'date_founded': '1932',
#    'iata_prefix_accounting': '27',
#    'airline_name': 'Alaska Airlines',
#    'country_name': 'United States',
#    'fleet_size': '156',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '30',
#    'fleet_average_age': '4.9',
#    'airline_id': '30',
#    'callsign': 'HAINAN',
#    'hub_code': 'HAK',
#    'iata_code': 'HU',
#    'icao_code': 'CHH',
#    'country_iso2': 'CN',
#    'date_founded': '1989',
#    'iata_prefix_accounting': '880',
#    'airline_name': 'Hainan Airlines',
#    'country_name': 'China',
#    'fleet_size': '155',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '31',
#    'fleet_average_age': '11.1',
#    'airline_id': '31',
#    'callsign': 'SCANDINAVIAN',
#    'hub_code': 'CPH',
#    'iata_code': 'SK',
#    'icao_code': 'SAS',
#    'country_iso2': 'SE',
#    'date_founded': '1946',
#    'iata_prefix_accounting': '117',
#    'airline_name': 'SAS',
#    'country_name': 'Sweden',
#    'fleet_size': '155',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '32',
#    'fleet_average_age': '5',
#    'airline_id': '32',
#    'callsign': 'INDONESIA',
#    'hub_code': 'CGK',
#    'iata_code': 'GA',
#    'icao_code': 'GIA',
#    'country_iso2': 'ID',
#    'date_founded': '1949',
#    'iata_prefix_accounting': '126',
#    'airline_name': 'Garuda',
#    'country_name': 'Indonesia',
#    'fleet_size': '148',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '33',
#    'fleet_average_age': '8.3',
#    'airline_id': '33',
#    'callsign': 'CATHAY',
#    'hub_code': 'HKG',
#    'iata_code': 'CX',
#    'icao_code': 'CPA',
#    'country_iso2': 'HK',
#    'date_founded': '1946',
#    'iata_prefix_accounting': '160',
#    'airline_name': 'Cathay Pacific',
#    'country_name': 'Hong Kong',
#    'fleet_size': '143',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '34',
#    'fleet_average_age': '5.9',
#    'airline_id': '34',
#    'callsign': 'BRICKYARD',
#    'hub_code': 'IND',
#    'iata_code': 'RW',
#    'icao_code': 'RPA',
#    'country_iso2': 'US',
#    'date_founded': '2003',
#    'iata_prefix_accounting': '52',
#    'airline_name': 'Republic Airlines',
#    'country_name': 'United States',
#    'fleet_size': '139',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '35',
#    'fleet_average_age': '7.8',
#    'airline_id': '35',
#    'callsign': 'SAUDIA',
#    'hub_code': 'JED',
#    'iata_code': 'SV',
#    'icao_code': 'SVA',
#    'country_iso2': 'SA',
#    'date_founded': '1945',
#    'iata_prefix_accounting': '65',
#    'airline_name': 'Saudi Arabian Airlines',
#    'country_name': 'Saudi Arabia',
#    'fleet_size': '138',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '36',
#    'fleet_average_age': '4.3',
#    'airline_id': '36',
#    'callsign': 'AZUL',
#    'hub_code': 'VCP',
#    'iata_code': 'AD',
#    'icao_code': 'AZU',
#    'country_iso2': 'BR',
#    'date_founded': '2008',
#    'iata_prefix_accounting': '577',
#    'airline_name': 'Azul Brazilian Airlines',
#    'country_name': 'Brazil',
#    'fleet_size': '132',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '37',
#    'fleet_average_age': '5.2',
#    'airline_id': '37',
#    'callsign': 'XIAMEN AIR',
#    'hub_code': 'XMN',
#    'iata_code': 'MF',
#    'icao_code': 'CXA',
#    'country_iso2': 'CN',
#    'date_founded': '1984',
#    'iata_prefix_accounting': '731',
#    'airline_name': 'Xiamen Airlines',
#    'country_name': 'China',
#    'fleet_size': '132',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '38',
#    'fleet_average_age': '7.8',
#    'airline_id': '38',
#    'callsign': 'GOL',
#    'hub_code': 'CGH',
#    'iata_code': 'G3',
#    'icao_code': 'GLO',
#    'country_iso2': 'BR',
#    'date_founded': '2000',
#    'iata_prefix_accounting': '127',
#    'airline_name': 'Gol Linhas Aéreas Inteligentes\nGol Linhas Aéreas Inteligentes\n',
#    'country_name': 'Brazil',
#    'fleet_size': '127',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '39',
#    'fleet_average_age': '16.8',
#    'airline_id': '39',
#    'callsign': 'JAZZ',
#    'hub_code': 'YHZ',
#    'iata_code': 'QK',
#    'icao_code': 'JZA',
#    'country_iso2': 'CA',
#    'date_founded': None,
#    'iata_prefix_accounting': '983',
#    'airline_name': 'Jazz Aviation LP',
#    'country_name': 'Canada',
#    'fleet_size': '127',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '40',
#    'fleet_average_age': '5.8',
#    'airline_id': '40',
#    'callsign': 'ETIHAD',
#    'hub_code': 'AUH',
#    'iata_code': 'EY',
#    'icao_code': 'ETD',
#    'country_iso2': 'AE',
#    'date_founded': '2003',
#    'iata_prefix_accounting': '607',
#    'airline_name': 'Etihad Airways',
#    'country_name': 'United Arab Emirates',
#    'fleet_size': '126',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '41',
#    'fleet_average_age': '5.1',
#    'airline_id': '41',
#    'callsign': 'LAN',
#    'hub_code': 'SCL',
#    'iata_code': 'LA',
#    'icao_code': 'LAN',
#    'country_iso2': 'CL',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '45',
#    'airline_name': 'Lan Airlines',
#    'country_name': 'Chile',
#    'fleet_size': '126',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '42',
#    'fleet_average_age': '7.5',
#    'airline_id': '42',
#    'callsign': 'FLAGSHIP',
#    'hub_code': 'MSP',
#    'iata_code': '9E',
#    'icao_code': 'FLG',
#    'country_iso2': 'UM',
#    'date_founded': '2013',
#    'iata_prefix_accounting': '430',
#    'airline_name': 'Endeavor Air',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '122',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '43',
#    'fleet_average_age': '7.4',
#    'airline_id': '43',
#    'callsign': 'AIR SHUTTLE',
#    'hub_code': 'PHX',
#    'iata_code': 'YV',
#    'icao_code': 'ASH',
#    'country_iso2': 'UM',
#    'date_founded': '1980',
#    'iata_prefix_accounting': '533',
#    'airline_name': 'Mesa Airlines, Inc.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '122',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '44',
#    'fleet_average_age': '9.2',
#    'airline_id': '44',
#    'callsign': 'Q LINK',
#    'hub_code': 'TMW',
#    'iata_code': 'QF',
#    'icao_code': 'QFA',
#    'country_iso2': 'AU',
#    'date_founded': '1920',
#    'iata_prefix_accounting': '81',
#    'airline_name': 'Qantas',
#    'country_name': 'Australia',
#    'fleet_size': '118',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '45',
#    'fleet_average_age': '5.7',
#    'airline_id': '45',
#    'callsign': 'LION INTER',
#    'hub_code': 'CGK',
#    'iata_code': 'JT',
#    'icao_code': 'LNI',
#    'country_iso2': 'ID',
#    'date_founded': '1999',
#    'iata_prefix_accounting': '990',
#    'airline_name': 'Lion Airlines',
#    'country_name': 'Indonesia',
#    'fleet_size': '117',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '46',
#    'fleet_average_age': '8.4',
#    'airline_id': '46',
#    'callsign': 'WESTJET',
#    'hub_code': 'YYC',
#    'iata_code': 'WS',
#    'icao_code': 'WJA',
#    'country_iso2': 'CA',
#    'date_founded': '1995',
#    'iata_prefix_accounting': '838',
#    'airline_name': 'WestJet',
#    'country_name': 'Canada',
#    'fleet_size': '117',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '47',
#    'fleet_average_age': '11.1',
#    'airline_id': '47',
#    'callsign': 'KLM',
#    'hub_code': 'AMS',
#    'iata_code': 'KL',
#    'icao_code': 'KLM',
#    'country_iso2': 'NL',
#    'date_founded': '1919',
#    'iata_prefix_accounting': '74',
#    'airline_name': 'KLM',
#    'country_name': 'Netherlands',
#    'fleet_size': '116',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '48',
#    'fleet_average_age': '8.1',
#    'airline_id': '48',
#    'callsign': 'SINGAPORE',
#    'hub_code': 'SIN',
#    'iata_code': 'SQ',
#    'icao_code': 'SIA',
#    'country_iso2': 'SG',
#    'date_founded': '1972',
#    'iata_prefix_accounting': '618',
#    'airline_name': 'SIA Cargo',
#    'country_name': 'Singapore',
#    'fleet_size': '111',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '49',
#    'fleet_average_age': '7.1',
#    'airline_id': '49',
#    'callsign': 'BLUE STREAK',
#    'hub_code': 'DAY',
#    'iata_code': 'OH',
#    'icao_code': 'JIA',
#    'country_iso2': 'US',
#    'date_founded': '1979',
#    'iata_prefix_accounting': '320',
#    'airline_name': 'PSA Airlines',
#    'country_name': 'United States',
#    'fleet_size': '109',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '50',
#    'fleet_average_age': '9.4',
#    'airline_id': '50',
#    'callsign': 'AIR INDIA',
#    'hub_code': 'DEL',
#    'iata_code': 'AI',
#    'icao_code': 'AIC',
#    'country_iso2': 'IN',
#    'date_founded': '1948',
#    'iata_prefix_accounting': '98',
#    'airline_name': 'Air India',
#    'country_name': 'India',
#    'fleet_size': '108',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '51',
#    'fleet_average_age': '4.8',
#    'airline_id': '51',
#    'callsign': 'SICHUAN',
#    'hub_code': 'CTU',
#    'iata_code': '3U',
#    'icao_code': 'CSC',
#    'country_iso2': 'CN',
#    'date_founded': '1986',
#    'iata_prefix_accounting': '876',
#    'airline_name': 'Sichuan Airlines',
#    'country_name': 'China',
#    'fleet_size': '107',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '52',
#    'fleet_average_age': '4.7',
#    'airline_id': '52',
#    'callsign': 'IFLY',
#    'hub_code': 'DEL',
#    'iata_code': '6E',
#    'icao_code': 'IGO',
#    'country_iso2': 'IN',
#    'date_founded': '2006',
#    'iata_prefix_accounting': '312',
#    'airline_name': 'Interglobe Aviation Ltd. dba Indigo',
#    'country_name': 'India',
#    'fleet_size': '107',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '53',
#    'fleet_average_age': '6.7',
#    'airline_id': '53',
#    'callsign': 'VUELING',
#    'hub_code': 'BCN',
#    'iata_code': 'VY',
#    'icao_code': 'VLG',
#    'country_iso2': 'ES',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '30',
#    'airline_name': 'Vueling',
#    'country_name': 'Spain',
#    'fleet_size': '105',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '54',
#    'fleet_average_age': '10.5',
#    'airline_id': '54',
#    'callsign': 'ALITALIA',
#    'hub_code': 'FCO',
#    'iata_code': 'AZ',
#    'icao_code': 'AZA',
#    'country_iso2': 'IT',
#    'date_founded': '1957',
#    'iata_prefix_accounting': '55',
#    'airline_name': 'Alitalia',
#    'country_name': 'Italy',
#    'fleet_size': '102',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '55',
#    'fleet_average_age': '4.5',
#    'airline_id': '55',
#    'callsign': 'AVIANCA',
#    'hub_code': 'BOG',
#    'iata_code': 'AV',
#    'icao_code': 'AVA',
#    'country_iso2': 'CO',
#    'date_founded': '1933',
#    'iata_prefix_accounting': '134',
#    'airline_name': 'AVIANCA',
#    'country_name': 'Colombia',
#    'fleet_size': '99',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '56',
#    'fleet_average_age': '6.3',
#    'airline_id': '56',
#    'callsign': 'VIRGIN',
#    'hub_code': 'BNE',
#    'iata_code': 'VA',
#    'icao_code': 'VAU',
#    'country_iso2': 'AU',
#    'date_founded': '2011',
#    'iata_prefix_accounting': '795',
#    'airline_name': 'Virgin Australia',
#    'country_name': 'Australia',
#    'fleet_size': '98',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '57',
#    'fleet_average_age': '11.5',
#    'airline_id': '57',
#    'callsign': 'MERCURY',
#    'hub_code': 'FWA',
#    'iata_code': 'S5',
#    'icao_code': 'TCF',
#    'country_iso2': 'UM',
#    'date_founded': None,
#    'iata_prefix_accounting': '919',
#    'airline_name': 'Shuttle America',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '95',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '58',
#    'fleet_average_age': '4.6',
#    'airline_id': '58',
#    'callsign': 'SHANDONG',
#    'hub_code': 'TNA',
#    'iata_code': 'SC',
#    'icao_code': 'CDG',
#    'country_iso2': 'CN',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '324',
#    'airline_name': 'Shandong Airlines',
#    'country_name': 'China',
#    'fleet_size': '93',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '59',
#    'fleet_average_age': '6.7',
#    'airline_id': '59',
#    'callsign': 'JET AIRWAYS',
#    'hub_code': 'BOM',
#    'iata_code': '9W',
#    'icao_code': 'JAI',
#    'country_iso2': 'IN',
#    'date_founded': '1992',
#    'iata_prefix_accounting': '589',
#    'airline_name': 'Jet Airways',
#    'country_name': 'India',
#    'fleet_size': '92',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '60',
#    'fleet_average_age': '5.2',
#    'airline_id': '60',
#    'callsign': 'CHINA DRAGON',
#    'hub_code': 'TSN',
#    'iata_code': 'GS',
#    'icao_code': 'GCR',
#    'country_iso2': 'CN',
#    'date_founded': '2009',
#    'iata_prefix_accounting': '826',
#    'airline_name': 'Tianjin Airlines',
#    'country_name': 'China',
#    'fleet_size': '91',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '61',
#    'fleet_average_age': '5.4',
#    'airline_id': '61',
#    'callsign': 'VIETNAM AIRLINES',
#    'hub_code': 'SGN',
#    'iata_code': 'VN',
#    'icao_code': 'HVN',
#    'country_iso2': 'VN',
#    'date_founded': '1951',
#    'iata_prefix_accounting': '738',
#    'airline_name': 'Vietnam Airlines',
#    'country_name': 'Vietnam',
#    'fleet_size': '89',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '62',
#    'fleet_average_age': '6.1',
#    'airline_id': '62',
#    'callsign': 'COPA',
#    'hub_code': 'PTY',
#    'iata_code': 'CM',
#    'icao_code': 'CMP',
#    'country_iso2': 'PA',
#    'date_founded': '1947',
#    'iata_prefix_accounting': '230',
#    'airline_name': 'COPA Airlines',
#    'country_name': 'Panama',
#    'fleet_size': '88',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '63',
#    'fleet_average_age': '5.7',
#    'airline_id': '63',
#    'callsign': 'SHANGHAI AIR',
#    'hub_code': 'SHA',
#    'iata_code': 'FM',
#    'icao_code': 'CSH',
#    'country_iso2': 'CN',
#    'date_founded': '1985',
#    'iata_prefix_accounting': '774',
#    'airline_name': 'Shanghai Airlines',
#    'country_name': 'China',
#    'fleet_size': '86',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '64',
#    'fleet_average_age': '8.1',
#    'airline_id': '64',
#    'callsign': 'AIR BERLIN',
#    'hub_code': 'TXL',
#    'iata_code': 'AB',
#    'icao_code': 'BER',
#    'country_iso2': 'DE',
#    'date_founded': '1978',
#    'iata_prefix_accounting': '745',
#    'airline_name': 'Air Berlin',
#    'country_name': 'Germany',
#    'fleet_size': '85',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '65',
#    'fleet_average_age': '15.8',
#    'airline_id': '65',
#    'callsign': 'AUSTRIAN',
#    'hub_code': 'VIE',
#    'iata_code': 'OS',
#    'icao_code': 'AUA',
#    'country_iso2': 'AT',
#    'date_founded': '1957',
#    'iata_prefix_accounting': '257',
#    'airline_name': 'Austrian',
#    'country_name': 'Austria',
#    'fleet_size': '85',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '66',
#    'fleet_average_age': '5.2',
#    'airline_id': '66',
#    'callsign': 'SPIRIT WINGS',
#    'hub_code': 'FLL',
#    'iata_code': 'NK',
#    'icao_code': 'NKS',
#    'country_iso2': 'UM',
#    'date_founded': '1980',
#    'iata_prefix_accounting': '487',
#    'airline_name': 'Spirit Airlines',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '84',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '67',
#    'fleet_average_age': '10.3',
#    'airline_id': '67',
#    'callsign': 'ASIANA',
#    'hub_code': 'ICN',
#    'iata_code': 'OZ',
#    'icao_code': 'AAR',
#    'country_iso2': 'KR',
#    'date_founded': '1988',
#    'iata_prefix_accounting': '988',
#    'airline_name': 'Asiana',
#    'country_name': 'South Korea',
#    'fleet_size': '84',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '68',
#    'fleet_average_age': '9.6',
#    'airline_id': '68',
#    'callsign': 'DYNASTY',
#    'hub_code': 'TPE',
#    'iata_code': 'CI',
#    'icao_code': 'CAL',
#    'country_iso2': 'TW',
#    'date_founded': '1959',
#    'iata_prefix_accounting': '297',
#    'airline_name': 'China Airlines',
#    'country_name': 'Chinese Taipei',
#    'fleet_size': '83',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '69',
#    'fleet_average_age': '21.6',
#    'airline_id': '69',
#    'callsign': 'ALLEGIANT',
#    'hub_code': 'LAS',
#    'iata_code': 'G4',
#    'icao_code': 'AAY',
#    'country_iso2': 'UM',
#    'date_founded': '1997',
#    'iata_prefix_accounting': '268',
#    'airline_name': 'Allegiant Air LLC',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '83',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '70',
#    'fleet_average_age': '4.3',
#    'airline_id': '70',
#    'callsign': 'MALAYSIAN',
#    'hub_code': 'KUL',
#    'iata_code': 'MH',
#    'icao_code': 'MAS',
#    'country_iso2': 'MY',
#    'date_founded': '1971',
#    'iata_prefix_accounting': '232',
#    'airline_name': 'Malaysia Airlines',
#    'country_name': 'Malaysia',
#    'fleet_size': '83',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '71',
#    'fleet_average_age': '5.6',
#    'airline_id': '71',
#    'callsign': 'ASIAN EXPRESS',
#    'hub_code': 'KUL',
#    'iata_code': 'AK',
#    'icao_code': 'AXM',
#    'country_iso2': 'MY',
#    'date_founded': '1993',
#    'iata_prefix_accounting': '807',
#    'airline_name': 'AirAsia Berhad dba AirAsia',
#    'country_name': 'Malaysia',
#    'fleet_size': '82',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '72',
#    'fleet_average_age': '9.5',
#    'airline_id': '72',
#    'callsign': 'THAI',
#    'hub_code': 'BKK',
#    'iata_code': 'TG',
#    'icao_code': 'THA',
#    'country_iso2': 'TH',
#    'date_founded': '1959',
#    'iata_prefix_accounting': '217',
#    'airline_name': 'Thai Airways International',
#    'country_name': 'Thailand',
#    'fleet_size': '81',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '73',
#    'fleet_average_age': '9.9',
#    'airline_id': '73',
#    'callsign': 'IBERIA',
#    'hub_code': 'MAD',
#    'iata_code': 'IB',
#    'icao_code': 'IBE',
#    'country_iso2': 'ES',
#    'date_founded': '1927',
#    'iata_prefix_accounting': '75',
#    'airline_name': 'IBERIA',
#    'country_name': 'Spain',
#    'fleet_size': '78',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '74',
#    'fleet_average_age': '11.7',
#    'airline_id': '74',
#    'callsign': 'JERSEY',
#    'hub_code': 'EXT',
#    'iata_code': 'BE',
#    'icao_code': 'BEE',
#    'country_iso2': 'GB',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '267',
#    'airline_name': 'flybe',
#    'country_name': 'United Kingdom',
#    'fleet_size': '63',
#    'status': 'historical/administration',
#    'type': 'scheduled'},
#   {'id': '75',
#    'fleet_average_age': '5.9',
#    'airline_id': '75',
#    'callsign': 'ETHIOPIAN',
#    'hub_code': 'ADD',
#    'iata_code': 'ET',
#    'icao_code': 'ETH',
#    'country_iso2': 'ET',
#    'date_founded': '1945',
#    'iata_prefix_accounting': '71',
#    'airline_name': 'Ethiopian Airlines',
#    'country_name': 'Ethiopia',
#    'fleet_size': '69',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '76',
#    'fleet_average_age': '6.2',
#    'airline_id': '76',
#    'callsign': 'JETSTAR',
#    'hub_code': 'MEL',
#    'iata_code': 'JQ',
#    'icao_code': 'JST',
#    'country_iso2': 'AU',
#    'date_founded': '2004',
#    'iata_prefix_accounting': '41',
#    'airline_name': 'Jetstar Airways Pty Limited',
#    'country_name': 'Australia',
#    'fleet_size': '69',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '77',
#    'fleet_average_age': '4.2',
#    'airline_id': '77',
#    'callsign': 'WIZZ AIR',
#    'hub_code': 'BUD',
#    'iata_code': 'W6',
#    'icao_code': 'WZZ',
#    'country_iso2': 'HU',
#    'date_founded': '2004',
#    'iata_prefix_accounting': None,
#    'airline_name': 'Wizz Air Hungary Ltd.',
#    'country_name': 'Hungary',
#    'fleet_size': '68',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '78',
#    'fleet_average_age': '13.8',
#    'airline_id': '78',
#    'callsign': 'AIR WISCONSIN',
#    'hub_code': 'ATW',
#    'iata_code': 'ZW',
#    'icao_code': 'AWI',
#    'country_iso2': 'UM',
#    'date_founded': '1965',
#    'iata_prefix_accounting': '303',
#    'airline_name': 'Air Wisconsin Airlines Corporation (AWAC)',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '68',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '79',
#    'fleet_average_age': '12.9',
#    'airline_id': '79',
#    'callsign': 'SWISS',
#    'hub_code': 'ZRH',
#    'iata_code': 'LX',
#    'icao_code': 'SWR',
#    'country_iso2': 'CH',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '724',
#    'airline_name': 'SWISS',
#    'country_name': 'Switzerland',
#    'fleet_size': '67',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '80',
#    'fleet_average_age': '14.4',
#    'airline_id': '80',
#    'callsign': 'WATERSKI',
#    'hub_code': 'STL',
#    'iata_code': 'AX',
#    'icao_code': 'LOF',
#    'country_iso2': 'US',
#    'date_founded': '1982',
#    'iata_prefix_accounting': '414',
#    'airline_name': 'Trans States Airlines, LLC',
#    'country_name': 'United States',
#    'fleet_size': '65',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '81',
#    'fleet_average_age': '6.8',
#    'airline_id': '81',
#    'callsign': 'EVA',
#    'hub_code': 'TPE',
#    'iata_code': 'BR',
#    'icao_code': 'EVA',
#    'country_iso2': 'TW',
#    'date_founded': '1989',
#    'iata_prefix_accounting': '695',
#    'airline_name': 'EVA Air',
#    'country_name': 'Chinese Taipei',
#    'fleet_size': '65',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '82',
#    'fleet_average_age': '9.3',
#    'airline_id': '82',
#    'callsign': 'SIBERIAN AIRLINES',
#    'hub_code': 'DME',
#    'iata_code': 'S7',
#    'icao_code': 'SBI',
#    'country_iso2': 'RU',
#    'date_founded': '1992',
#    'iata_prefix_accounting': '421',
#    'airline_name': 'S7 Airlines',
#    'country_name': 'Russia',
#    'fleet_size': '65',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '83',
#    'fleet_average_age': '7.2',
#    'airline_id': '83',
#    'callsign': 'AEROMEXICO',
#    'hub_code': 'MEX',
#    'iata_code': 'AM',
#    'icao_code': 'AMX',
#    'country_iso2': 'MX',
#    'date_founded': '1972',
#    'iata_prefix_accounting': '139',
#    'airline_name': 'Aeromexico',
#    'country_name': 'Mexico',
#    'fleet_size': '64',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '84',
#    'fleet_average_age': '6.4',
#    'airline_id': '84',
#    'callsign': 'INTERJET',
#    'hub_code': 'TLC',
#    'iata_code': '4O',
#    'icao_code': 'AIJ',
#    'country_iso2': 'MX',
#    'date_founded': '2005',
#    'iata_prefix_accounting': '837',
#    'airline_name': 'Interjet',
#    'country_name': 'Mexico',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '85',
#    'fleet_average_age': '8.9',
#    'airline_id': '85',
#    'callsign': 'COSTERA',
#    'hub_code': 'MTY',
#    'iata_code': '5D',
#    'icao_code': 'SLI',
#    'country_iso2': 'MX',
#    'date_founded': '2007',
#    'iata_prefix_accounting': '642',
#    'airline_name': 'Aerolitoral S.A. de C.V.',
#    'country_name': 'Mexico',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '86',
#    'fleet_average_age': '8.1',
#    'airline_id': '86',
#    'callsign': 'CAPITAL JET',
#    'hub_code': 'HAK',
#    'iata_code': 'JD',
#    'icao_code': 'CBJ',
#    'country_iso2': 'CN',
#    'date_founded': '1995',
#    'iata_prefix_accounting': '898',
#    'airline_name': 'Capital Airlines',
#    'country_name': 'China',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '87',
#    'fleet_average_age': '5.2',
#    'airline_id': '87',
#    'callsign': 'SUNTURK',
#    'hub_code': 'SAW',
#    'iata_code': 'PC',
#    'icao_code': 'PGT',
#    'country_iso2': 'TR',
#    'date_founded': '1990',
#    'iata_prefix_accounting': '624',
#    'airline_name': 'Pegasus Airlines',
#    'country_name': 'Turkey',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '88',
#    'fleet_average_age': '14.2',
#    'airline_id': '88',
#    'callsign': 'TJUMAVI',
#    'hub_code': 'SGC',
#    'iata_code': 'UT',
#    'icao_code': 'UTA',
#    'country_iso2': 'RU',
#    'date_founded': '1991',
#    'iata_prefix_accounting': '298',
#    'airline_name': 'UTair',
#    'country_name': 'Russia',
#    'fleet_size': '63',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '89',
#    'fleet_average_age': '8.6',
#    'airline_id': '89',
#    'callsign': 'TOMJET',
#    'hub_code': 'LTN',
#    'iata_code': 'BY',
#    'icao_code': 'TOM',
#    'country_iso2': 'GB',
#    'date_founded': '1962',
#    'iata_prefix_accounting': '754',
#    'airline_name': 'TUI Airways Limited',
#    'country_name': 'United Kingdom',
#    'fleet_size': '58',
#    'status': 'active',
#    'type': 'scheduled,charter'},
#   {'id': '90',
#    'fleet_average_age': '5.8',
#    'airline_id': '90',
#    'callsign': 'COMPASS',
#    'hub_code': 'MSP',
#    'iata_code': 'CP',
#    'icao_code': 'CPZ',
#    'country_iso2': 'UM',
#    'date_founded': '2007',
#    'iata_prefix_accounting': '3',
#    'airline_name': 'Compass Airlines LLC',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '91',
#    'fleet_average_age': '14.9',
#    'airline_id': '91',
#    'callsign': 'AIR PORTUGAL',
#    'hub_code': 'LIS',
#    'iata_code': 'TP',
#    'icao_code': 'TAP',
#    'country_iso2': 'PT',
#    'date_founded': '1945',
#    'iata_prefix_accounting': '47',
#    'airline_name': 'TAP Portugal',
#    'country_name': 'Portugal',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '92',
#    'fleet_average_age': '6.3',
#    'airline_id': '92',
#    'callsign': 'REDWOOD',
#    'hub_code': 'SFO',
#    'iata_code': 'VX',
#    'icao_code': 'VRD',
#    'country_iso2': 'US',
#    'date_founded': '2006',
#    'iata_prefix_accounting': '984',
#    'airline_name': 'Virgin America',
#    'country_name': 'United States',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '93',
#    'fleet_average_age': '4.5',
#    'airline_id': '93',
#    'callsign': 'VOLARIS',
#    'hub_code': 'TLC',
#    'iata_code': 'Y4',
#    'icao_code': 'VOI',
#    'country_iso2': 'MX',
#    'date_founded': '2006',
#    'iata_prefix_accounting': '36',
#    'airline_name': 'Volaris',
#    'country_name': 'Mexico',
#    'fleet_size': '62',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '94',
#    'fleet_average_age': '14.6',
#    'airline_id': '94',
#    'callsign': 'GERMAN WINGS',
#    'hub_code': 'CGN',
#    'iata_code': '4U',
#    'icao_code': 'GWI',
#    'country_iso2': 'DE',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '51',
#    'airline_name': 'Germanwings GmbH',
#    'country_name': 'Germany',
#    'fleet_size': '61',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '95',
#    'fleet_average_age': '21.9',
#    'airline_id': '95',
#    'callsign': 'CHANNEX',
#    'hub_code': 'LBA',
#    'iata_code': 'LS',
#    'icao_code': 'EXS',
#    'country_iso2': 'GB',
#    'date_founded': '2002',
#    'iata_prefix_accounting': '949',
#    'airline_name': 'Jet2.com Limited',
#    'country_name': 'United Kingdom',
#    'fleet_size': '61',
#    'status': 'active',
#    'type': 'scheduled,cargo'},
#   {'id': '96',
#    'fleet_average_age': '4.7',
#    'airline_id': '96',
#    'callsign': 'PHILIPPINE',
#    'hub_code': 'MNL',
#    'iata_code': 'PR',
#    'icao_code': 'PAL',
#    'country_iso2': 'PH',
#    'date_founded': '1941',
#    'iata_prefix_accounting': '79',
#    'airline_name': 'Philippine Airlines',
#    'country_name': 'Philippines',
#    'fleet_size': '59',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '97',
#    'fleet_average_age': '3.5',
#    'airline_id': '97',
#    'callsign': 'AIR SPRING',
#    'hub_code': 'SHA',
#    'iata_code': '9C',
#    'icao_code': 'CQH',
#    'country_iso2': 'CN',
#    'date_founded': '2005',
#    'iata_prefix_accounting': '89',
#    'airline_name': 'Spring Airlines Limited Corporation',
#    'country_name': 'China',
#    'fleet_size': '58',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '98',
#    'fleet_average_age': '7.7',
#    'airline_id': '98',
#    'callsign': 'FRONTIER FLIGHT',
#    'hub_code': 'DEN',
#    'iata_code': 'F9',
#    'icao_code': 'FFT',
#    'country_iso2': 'UM',
#    'date_founded': '1994',
#    'iata_prefix_accounting': '422',
#    'airline_name': 'Frontier Airlines, Inc.',
#    'country_name': 'United States Minor Outlying Islands',
#    'fleet_size': '58',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '99',
#    'fleet_average_age': '5',
#    'airline_id': '99',
#    'callsign': 'CEBU AIR',
#    'hub_code': 'MNL',
#    'iata_code': '5J',
#    'icao_code': 'CEB',
#    'country_iso2': 'PH',
#    'date_founded': '1996',
#    'iata_prefix_accounting': '203',
#    'airline_name': 'Cebu Pacific Air',
#    'country_name': 'Philippines',
#    'fleet_size': '57',
#    'status': 'active',
#    'type': 'scheduled'},
#   {'id': '100',
#    'fleet_average_age': '3.7',
#    'airline_id': '100',
#    'callsign': 'NOR SHUTTLE',
#    'hub_code': 'OSL',
#    'iata_code': 'DY',
#    'icao_code': 'NAX',
#    'country_iso2': 'NO',
#    'date_founded': '1993',
#    'iata_prefix_accounting': '328',
#    'airline_name': 'Norwegian Air Shuttle A.S.',
#    'country_name': 'Norway',
#    'fleet_size': '57',
#    'status': 'active',
#    'type': 'scheduled'}]}

# %%
# basic plan must use http, not https
params = {"access_key": av_api_key, "airline_name": "Malaysia Airlines"}

# %%
api_result = requests.get(flight_api_url, params)
api_response = api_result.json()

# %%
api_response.keys()
# Out:
# dict_keys(['pagination', 'data'])

# %%
api_response["pagination"]
# Out:
# {'limit': 100, 'offset': 0, 'count': 11, 'total': 11}

# %%
api_response["data"]
# Out:
# [{'flight_date': '2023-10-13',
#   'flight_status': 'active',
#   'departure': {'airport': 'Melbourne - Tullamarine Airport',
#    'timezone': 'Australia/Melbourne',
#    'iata': 'MEL',
#    'icao': 'YMML',
#    'terminal': '2',
#    'gate': '6',
#    'delay': 25,
#    'scheduled': '2023-10-13T00:30:00+00:00',
#    'estimated': '2023-10-13T00:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T06:00:00+00:00',
#    'estimated': '2023-10-13T06:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '128',
#    'iata': 'MH128',
#    'icao': 'MAS128',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'active',
#   'departure': {'airport': 'Auckland International',
#    'timezone': 'Pacific/Auckland',
#    'iata': 'AKL',
#    'icao': 'NZAA',
#    'terminal': 'I',
#    'gate': '7',
#    'delay': None,
#    'scheduled': '2023-10-13T01:15:00+00:00',
#    'estimated': '2023-10-13T01:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T07:40:00+00:00',
#    'estimated': '2023-10-13T07:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '132',
#    'iata': 'MH132',
#    'icao': 'MAS132',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Francisco Bangoy International',
#    'timezone': 'Asia/Manila',
#    'iata': 'DVO',
#    'icao': 'RPMD',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T01:50:00+00:00',
#    'estimated': '2023-10-13T01:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T03:50:00+00:00',
#    'estimated': '2023-10-13T03:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5526',
#    'iata': 'MH5526',
#    'icao': 'MAS5526',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2808',
#     'flight_iata': 'pr2808',
#     'flight_icao': 'pal2808'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Bangalore International Airport',
#    'timezone': 'Asia/Kolkata',
#    'iata': 'BLR',
#    'icao': 'VOBL',
#    'terminal': '2',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T00:35:00+00:00',
#    'estimated': '2023-10-13T00:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T07:20:00+00:00',
#    'estimated': '2023-10-13T07:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '193',
#    'iata': 'MH193',
#    'icao': 'MAS193',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hong Kong International',
#    'timezone': 'Asia/Hong_Kong',
#    'iata': 'HKG',
#    'icao': 'VHHH',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T02:00:00+00:00',
#    'estimated': '2023-10-13T02:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T06:00:00+00:00',
#    'estimated': '2023-10-13T06:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9210',
#    'iata': 'MH9210',
#    'icao': 'MAS9210',
#    'codeshared': {'airline_name': 'cathay pacific',
#     'airline_iata': 'cx',
#     'airline_icao': 'cpa',
#     'flight_number': '844',
#     'flight_iata': 'cx844',
#     'flight_icao': 'cpa844'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hong Kong International',
#    'timezone': 'Asia/Hong_Kong',
#    'iata': 'HKG',
#    'icao': 'VHHH',
#    'terminal': '1',
#    'gate': '41',
#    'delay': None,
#    'scheduled': '2023-10-13T00:50:00+00:00',
#    'estimated': '2023-10-13T00:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'San Francisco International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'SFO',
#    'icao': 'KSFO',
#    'terminal': 'INTL',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-12T22:20:00+00:00',
#    'estimated': '2023-10-12T22:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9198',
#    'iata': 'MH9198',
#    'icao': 'MAS9198',
#    'codeshared': {'airline_name': 'cathay pacific',
#     'airline_iata': 'cx',
#     'airline_icao': 'cpa',
#     'flight_number': '872',
#     'flight_iata': 'cx872',
#     'flight_icao': 'cpa872'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hyderabad Airport',
#    'timezone': 'Asia/Kolkata',
#    'iata': 'HYD',
#    'icao': 'VOHS',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T00:30:00+00:00',
#    'estimated': '2023-10-13T00:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T07:30:00+00:00',
#    'estimated': '2023-10-13T07:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '199',
#    'iata': 'MH199',
#    'icao': 'MAS199',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T02:55:00+00:00',
#    'estimated': '2023-10-13T02:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T05:15:00+00:00',
#    'estimated': '2023-10-13T05:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '164',
#    'iata': 'MH164',
#    'icao': 'MAS164',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Perth International',
#    'timezone': 'Australia/Perth',
#    'iata': 'PER',
#    'icao': 'YPPH',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T02:10:00+00:00',
#    'estimated': '2023-10-13T02:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T07:50:00+00:00',
#    'estimated': '2023-10-13T07:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '126',
#    'iata': 'MH126',
#    'icao': 'MAS126',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Mactan-Cebu International',
#    'timezone': 'Asia/Manila',
#    'iata': 'CEB',
#    'icao': 'RPVM',
#    'terminal': '1',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T02:50:00+00:00',
#    'estimated': '2023-10-13T02:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T04:20:00+00:00',
#    'estimated': '2023-10-13T04:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5522',
#    'iata': 'MH5522',
#    'icao': 'MAS5522',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2836',
#     'flight_iata': 'pr2836',
#     'flight_icao': 'pal2836'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-10-13',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Cochin International',
#    'timezone': 'Asia/Kolkata',
#    'iata': 'COK',
#    'icao': 'VOCI',
#    'terminal': '3',
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-10-13T00:10:00+00:00',
#    'estimated': '2023-10-13T00:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': None,
#    'scheduled': '2023-10-13T06:55:00+00:00',
#    'estimated': '2023-10-13T06:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '109',
#    'iata': 'MH109',
#    'icao': 'MAS109',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None}]

# %%
params = {
    "access_key": av_api_key,
    # "airline_name": "American Airlines",
    "min_delay_arr": 30,
    # "flight_date": "2023-08-22",
}
api_result = requests.get(url="http://api.aviationstack.com/v1/flights", params=params)
api_response = api_result.json()
api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}, 'data': []}

# %% [markdown]
# ### Filter for delays

# %%
params = {
    "access_key": av_api_key,
    "airline_name": "Malaysia Airlines",
    "min_delay_arr": 30,
    "flight_date": "2023-08-22",
}
api_result = requests.get(flight_api_url, params)
api_response = api_result.json()

# %%
api_response
# Out:
# {'error': {'code': 'function_access_restricted',
#   'message': 'Your current subscription plan does not support this API function.'}}

# %% [markdown]
# Basic plan cannot filter by date???

# %%
params = {
    "access_key": av_api_key,
    "airline_name": "Malaysia Airlines",
    "min_delay_arr": 30,
    # "flight_date": "2023-08-22",
}
api_result = requests.get(url="http://api.aviationstack.com/v1/flights", params=params)
api_response = api_result.json()

# %%
api_response["pagination"]
# Out:
# {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}

# %%
api_response["data"]
# Out:
# [{'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': 'C37',
#    'delay': 25,
#    'scheduled': '2023-08-29T02:05:00+00:00',
#    'estimated': '2023-08-29T02:05:00+00:00',
#    'actual': '2023-08-29T03:10:00+00:00',
#    'estimated_runway': '2023-08-29T03:10:00+00:00',
#    'actual_runway': '2023-08-29T03:10:00+00:00'},
#   'arrival': {'airport': 'Cape Town International',
#    'timezone': 'Africa/Johannesburg',
#    'iata': 'CPT',
#    'icao': 'FACT',
#    'terminal': 'B',
#    'gate': 'A5',
#    'baggage': '1.4',
#    'delay': 31,
#    'scheduled': '2023-08-29T10:50:00+00:00',
#    'estimated': '2023-08-29T10:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9305',
#    'iata': 'MH9305',
#    'icao': 'MAS9305',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '1369',
#     'flight_iata': 'qr1369',
#     'flight_icao': 'qtr1369'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'active',
#   'departure': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': None,
#    'delay': None,
#    'scheduled': '2023-08-29T01:53:00+00:00',
#    'estimated': '2023-08-29T01:53:00+00:00',
#    'actual': '2023-08-29T01:53:00+00:00',
#    'estimated_runway': '2023-08-29T01:53:00+00:00',
#    'actual_runway': '2023-08-29T01:53:00+00:00'},
#   'arrival': {'airport': None,
#    'timezone': None,
#    'iata': 'DWC',
#    'icao': 'OMDW',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': 35,
#    'scheduled': '2023-08-29T03:26:00+00:00',
#    'estimated': '2023-08-29T03:26:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '6127',
#    'iata': 'MH6127',
#    'icao': 'MAS6127',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Guangzhou Baiyun International',
#    'timezone': 'Asia/Shanghai',
#    'iata': 'CAN',
#    'icao': 'ZGGG',
#    'terminal': '2',
#    'gate': None,
#    'delay': 45,
#    'scheduled': '2023-08-29T08:15:00+00:00',
#    'estimated': '2023-08-29T08:15:00+00:00',
#    'actual': '2023-08-29T09:36:00+00:00',
#    'estimated_runway': '2023-08-29T09:36:00+00:00',
#    'actual_runway': '2023-08-29T09:36:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 54,
#    'scheduled': '2023-08-29T12:00:00+00:00',
#    'estimated': '2023-08-29T12:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4481',
#    'iata': 'MH4481',
#    'icao': 'MAS4481',
#    'codeshared': {'airline_name': 'china southern airlines',
#     'airline_iata': 'cz',
#     'airline_icao': 'csn',
#     'flight_number': '349',
#     'flight_iata': 'cz349',
#     'flight_icao': 'csn349'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': None,
#    'gate': 'C36',
#    'delay': 22,
#    'scheduled': '2023-08-29T02:10:00+00:00',
#    'estimated': '2023-08-29T02:10:00+00:00',
#    'actual': '2023-08-29T05:18:00+00:00',
#    'estimated_runway': '2023-08-29T05:18:00+00:00',
#    'actual_runway': '2023-08-29T05:18:00+00:00'},
#   'arrival': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#    'timezone': 'Europe/Rome',
#    'iata': 'FCO',
#    'icao': 'LIRF',
#    'terminal': '3',
#    'gate': None,
#    'baggage': '12',
#    'delay': 131,
#    'scheduled': '2023-08-29T07:15:00+00:00',
#    'estimated': '2023-08-29T07:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9237',
#    'iata': 'MH9237',
#    'icao': 'MAS9237',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '115',
#     'flight_iata': 'qr115',
#     'flight_icao': 'qtr115'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Sultan Abdul Aziz Shah',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'SZB',
#    'icao': 'WMSA',
#    'terminal': None,
#    'gate': None,
#    'delay': 32,
#    'scheduled': '2023-08-29T10:10:00+00:00',
#    'estimated': '2023-08-29T10:10:00+00:00',
#    'actual': '2023-08-29T10:41:00+00:00',
#    'estimated_runway': '2023-08-29T10:41:00+00:00',
#    'actual_runway': '2023-08-29T10:41:00+00:00'},
#   'arrival': {'airport': 'Sultan Ismail International',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'JHB',
#    'icao': 'WMKJ',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 38,
#    'scheduled': '2023-08-29T11:15:00+00:00',
#    'estimated': '2023-08-29T11:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5337',
#    'iata': 'MH5337',
#    'icao': 'MAS5337',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '1338',
#     'flight_iata': 'fy1338',
#     'flight_icao': 'ffm1338'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 85,
#    'scheduled': '2023-08-29T09:40:00+00:00',
#    'estimated': '2023-08-29T09:40:00+00:00',
#    'actual': '2023-08-29T11:05:00+00:00',
#    'estimated_runway': '2023-08-29T11:05:00+00:00',
#    'actual_runway': '2023-08-29T11:05:00+00:00'},
#   'arrival': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': None,
#    'baggage': '37',
#    'delay': 56,
#    'scheduled': '2023-08-29T10:55:00+00:00',
#    'estimated': '2023-08-29T10:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '627',
#    'iata': 'MH627',
#    'icao': 'MAS627',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 77,
#    'scheduled': '2023-08-29T09:25:00+00:00',
#    'estimated': '2023-08-29T09:25:00+00:00',
#    'actual': '2023-08-29T10:42:00+00:00',
#    'estimated_runway': '2023-08-29T10:42:00+00:00',
#    'actual_runway': '2023-08-29T10:42:00+00:00'},
#   'arrival': {'airport': 'Madras International (Meenambakkam)',
#    'timezone': 'Asia/Kolkata',
#    'iata': 'MAA',
#    'icao': 'VOMM',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 50,
#    'scheduled': '2023-08-29T10:45:00+00:00',
#    'estimated': '2023-08-29T10:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '182',
#    'iata': 'MH182',
#    'icao': 'MAS182',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 76,
#    'scheduled': '2023-08-29T09:15:00+00:00',
#    'estimated': '2023-08-29T09:15:00+00:00',
#    'actual': '2023-08-29T10:30:00+00:00',
#    'estimated_runway': '2023-08-29T10:30:00+00:00',
#    'actual_runway': '2023-08-29T10:30:00+00:00'},
#   'arrival': {'airport': 'Kota-Kinabalu International Airport',
#    'timezone': 'Asia/Kuching',
#    'iata': 'BKI',
#    'icao': 'WBKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 55,
#    'scheduled': '2023-08-29T11:55:00+00:00',
#    'estimated': '2023-08-29T11:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2610',
#    'iata': 'MH2610',
#    'icao': 'MAS2610',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 84,
#    'scheduled': '2023-08-29T09:15:00+00:00',
#    'estimated': '2023-08-29T09:15:00+00:00',
#    'actual': '2023-08-29T10:39:00+00:00',
#    'estimated_runway': '2023-08-29T10:39:00+00:00',
#    'actual_runway': '2023-08-29T10:39:00+00:00'},
#   'arrival': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#    'timezone': 'Asia/Taipei',
#    'iata': 'TPE',
#    'icao': 'RCTP',
#    'terminal': '1',
#    'gate': 'A2',
#    'baggage': '3B',
#    'delay': 61,
#    'scheduled': '2023-08-29T14:10:00+00:00',
#    'estimated': '2023-08-29T14:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '366',
#    'iata': 'MH366',
#    'icao': 'MAS366',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 87,
#    'scheduled': '2023-08-29T09:10:00+00:00',
#    'estimated': '2023-08-29T09:10:00+00:00',
#    'actual': '2023-08-29T10:37:00+00:00',
#    'estimated_runway': '2023-08-29T10:37:00+00:00',
#    'actual_runway': '2023-08-29T10:37:00+00:00'},
#   'arrival': {'airport': 'Zia International',
#    'timezone': 'Asia/Dhaka',
#    'iata': 'DAC',
#    'icao': 'VGHS',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 62,
#    'scheduled': '2023-08-29T11:05:00+00:00',
#    'estimated': '2023-08-29T11:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '102',
#    'iata': 'MH102',
#    'icao': 'MAS102',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': 'F37',
#    'delay': 34,
#    'scheduled': '2023-08-29T09:55:00+00:00',
#    'estimated': '2023-08-29T09:55:00+00:00',
#    'actual': '2023-08-29T10:29:00+00:00',
#    'estimated_runway': '2023-08-29T10:29:00+00:00',
#    'actual_runway': '2023-08-29T10:29:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 35,
#    'scheduled': '2023-08-29T10:55:00+00:00',
#    'estimated': '2023-08-29T10:55:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '604',
#    'iata': 'MH604',
#    'icao': 'MAS604',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 95,
#    'scheduled': '2023-08-29T09:00:00+00:00',
#    'estimated': '2023-08-29T09:00:00+00:00',
#    'actual': '2023-08-29T10:35:00+00:00',
#    'estimated_runway': '2023-08-29T10:35:00+00:00',
#    'actual_runway': '2023-08-29T10:35:00+00:00'},
#   'arrival': {'airport': 'Suvarnabhumi International',
#    'timezone': 'Asia/Bangkok',
#    'iata': 'BKK',
#    'icao': 'VTBS',
#    'terminal': 'D',
#    'gate': None,
#    'baggage': None,
#    'delay': 72,
#    'scheduled': '2023-08-29T10:15:00+00:00',
#    'estimated': '2023-08-29T10:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '784',
#    'iata': 'MH784',
#    'icao': 'MAS784',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Sultan Ismail Petra',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KBR',
#    'icao': 'WMKC',
#    'terminal': None,
#    'gate': None,
#    'delay': 40,
#    'scheduled': '2023-08-29T08:50:00+00:00',
#    'estimated': '2023-08-29T08:50:00+00:00',
#    'actual': '2023-08-29T09:30:00+00:00',
#    'estimated_runway': '2023-08-29T09:30:00+00:00',
#    'actual_runway': '2023-08-29T09:30:00+00:00'},
#   'arrival': {'airport': 'Sultan Abdul Aziz Shah',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'SZB',
#    'icao': 'WMSA',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': 31,
#    'scheduled': '2023-08-29T09:55:00+00:00',
#    'estimated': '2023-08-29T09:55:00+00:00',
#    'actual': '2023-08-29T10:25:00+00:00',
#    'estimated_runway': '2023-08-29T10:25:00+00:00',
#    'actual_runway': '2023-08-29T10:25:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5301',
#    'iata': 'MH5301',
#    'icao': 'MAS5301',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '1145',
#     'flight_iata': 'fy1145',
#     'flight_icao': 'ffm1145'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': 'F35',
#    'delay': 45,
#    'scheduled': '2023-08-29T06:40:00+00:00',
#    'estimated': '2023-08-29T06:40:00+00:00',
#    'actual': '2023-08-29T07:24:00+00:00',
#    'estimated_runway': '2023-08-29T07:24:00+00:00',
#    'actual_runway': '2023-08-29T07:24:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 30,
#    'scheduled': '2023-08-29T07:40:00+00:00',
#    'estimated': '2023-08-29T07:40:00+00:00',
#    'actual': '2023-08-29T08:09:00+00:00',
#    'estimated_runway': '2023-08-29T08:09:00+00:00',
#    'actual_runway': '2023-08-29T08:09:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '602',
#    'iata': 'MH602',
#    'icao': 'MAS602',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Puerto Princesa',
#    'timezone': 'Asia/Manila',
#    'iata': 'PPS',
#    'icao': 'RPVP',
#    'terminal': None,
#    'gate': None,
#    'delay': 108,
#    'scheduled': '2023-08-29T06:00:00+00:00',
#    'estimated': '2023-08-29T06:00:00+00:00',
#    'actual': '2023-08-29T07:47:00+00:00',
#    'estimated_runway': '2023-08-29T07:47:00+00:00',
#    'actual_runway': '2023-08-29T07:47:00+00:00'},
#   'arrival': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 95,
#    'scheduled': '2023-08-29T07:20:00+00:00',
#    'estimated': '2023-08-29T07:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5964',
#    'iata': 'MH5964',
#    'icao': 'MAS5964',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2782',
#     'flight_iata': 'pr2782',
#     'flight_icao': 'pal2782'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Ninoy Aquino International',
#    'timezone': 'Asia/Manila',
#    'iata': 'MNL',
#    'icao': 'RPLL',
#    'terminal': '2',
#    'gate': None,
#    'delay': 110,
#    'scheduled': '2023-08-29T04:00:00+00:00',
#    'estimated': '2023-08-29T04:00:00+00:00',
#    'actual': '2023-08-29T05:49:00+00:00',
#    'estimated_runway': '2023-08-29T05:49:00+00:00',
#    'actual_runway': '2023-08-29T05:49:00+00:00'},
#   'arrival': {'airport': 'Puerto Princesa',
#    'timezone': 'Asia/Manila',
#    'iata': 'PPS',
#    'icao': 'RPVP',
#    'terminal': '3',
#    'gate': None,
#    'baggage': None,
#    'delay': 87,
#    'scheduled': '2023-08-29T05:20:00+00:00',
#    'estimated': '2023-08-29T05:20:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5997',
#    'iata': 'MH5997',
#    'icao': 'MAS5997',
#    'codeshared': {'airline_name': 'philippine airlines',
#     'airline_iata': 'pr',
#     'airline_icao': 'pal',
#     'flight_number': '2781',
#     'flight_iata': 'pr2781',
#     'flight_icao': 'pal2781'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 105,
#    'scheduled': '2023-08-29T02:55:00+00:00',
#    'estimated': '2023-08-29T02:55:00+00:00',
#    'actual': '2023-08-29T04:39:00+00:00',
#    'estimated_runway': '2023-08-29T04:39:00+00:00',
#    'actual_runway': '2023-08-29T04:39:00+00:00'},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '4',
#    'delay': 78,
#    'scheduled': '2023-08-29T05:15:00+00:00',
#    'estimated': '2023-08-29T05:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '164',
#    'iata': 'MH164',
#    'icao': 'MAS164',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-29',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Auckland International',
#    'timezone': 'Pacific/Auckland',
#    'iata': 'AKL',
#    'icao': 'NZAA',
#    'terminal': 'I',
#    'gate': '2',
#    'delay': 123,
#    'scheduled': '2023-08-29T00:15:00+00:00',
#    'estimated': '2023-08-29T00:15:00+00:00',
#    'actual': '2023-08-29T02:17:00+00:00',
#    'estimated_runway': '2023-08-29T02:17:00+00:00',
#    'actual_runway': '2023-08-29T02:17:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 72,
#    'scheduled': '2023-08-29T07:40:00+00:00',
#    'estimated': '2023-08-29T07:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '132',
#    'iata': 'MH132',
#    'icao': 'MAS132',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MTW',
#    'iata': 'A332',
#    'icao': 'A332',
#    'icao24': '75046C'},
#   'live': {'updated': '2023-08-28T22:21:02+00:00',
#    'latitude': -6.12,
#    'longitude': 118.43,
#    'altitude': 12192,
#    'direction': 296,
#    'speed_horizontal': 918.592,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Hartsfield-jackson Atlanta International',
#    'timezone': 'America/New_York',
#    'iata': 'ATL',
#    'icao': 'KATL',
#    'terminal': 'N',
#    'gate': 'T9',
#    'delay': 133,
#    'scheduled': '2023-08-28T18:24:00+00:00',
#    'estimated': '2023-08-28T18:24:00+00:00',
#    'actual': '2023-08-28T20:36:00+00:00',
#    'estimated_runway': '2023-08-28T20:36:00+00:00',
#    'actual_runway': '2023-08-28T20:36:00+00:00'},
#   'arrival': {'airport': "Chicago O'hare International",
#    'timezone': 'America/Chicago',
#    'iata': 'ORD',
#    'icao': 'KORD',
#    'terminal': '3',
#    'gate': 'L10A',
#    'baggage': None,
#    'delay': 79,
#    'scheduled': '2023-08-28T19:43:00+00:00',
#    'estimated': '2023-08-28T19:43:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9456',
#    'iata': 'MH9456',
#    'icao': 'MAS9456',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '4621',
#     'flight_iata': 'aa4621',
#     'flight_icao': 'aal4621'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Logan International',
#    'timezone': 'America/New_York',
#    'iata': 'BOS',
#    'icao': 'KBOS',
#    'terminal': 'B',
#    'gate': 'B12',
#    'delay': 81,
#    'scheduled': '2023-08-28T18:33:00+00:00',
#    'estimated': '2023-08-28T18:33:00+00:00',
#    'actual': '2023-08-28T19:59:00+00:00',
#    'estimated_runway': '2023-08-28T19:59:00+00:00',
#    'actual_runway': '2023-08-28T19:59:00+00:00'},
#   'arrival': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': '37',
#    'baggage': '9',
#    'delay': 46,
#    'scheduled': '2023-08-28T19:59:00+00:00',
#    'estimated': '2023-08-28T19:59:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9340',
#    'iata': 'MH9340',
#    'icao': 'MAS9340',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '4294',
#     'flight_iata': 'aa4294',
#     'flight_icao': 'aal4294'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': "Chicago O'hare International",
#    'timezone': 'America/Chicago',
#    'iata': 'ORD',
#    'icao': 'KORD',
#    'terminal': '3',
#    'gate': 'K16',
#    'delay': 164,
#    'scheduled': '2023-08-28T16:55:00+00:00',
#    'estimated': '2023-08-28T16:55:00+00:00',
#    'actual': '2023-08-28T19:46:00+00:00',
#    'estimated_runway': '2023-08-28T19:46:00+00:00',
#    'actual_runway': '2023-08-28T19:46:00+00:00'},
#   'arrival': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '5',
#    'gate': '53A',
#    'baggage': 'T5C5',
#    'delay': 137,
#    'scheduled': '2023-08-28T19:12:00+00:00',
#    'estimated': '2023-08-28T19:12:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9455',
#    'iata': 'MH9455',
#    'icao': 'MAS9455',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '2364',
#     'flight_iata': 'aa2364',
#     'flight_icao': 'aal2364'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'B13',
#    'delay': 96,
#    'scheduled': '2023-08-28T18:09:00+00:00',
#    'estimated': '2023-08-28T18:09:00+00:00',
#    'actual': '2023-08-28T19:45:00+00:00',
#    'estimated_runway': '2023-08-28T19:45:00+00:00',
#    'actual_runway': '2023-08-28T19:45:00+00:00'},
#   'arrival': {'airport': 'La Guardia',
#    'timezone': 'America/New_York',
#    'iata': 'LGA',
#    'icao': 'KLGA',
#    'terminal': 'B',
#    'gate': '17',
#    'baggage': '3',
#    'delay': 60,
#    'scheduled': '2023-08-28T20:00:00+00:00',
#    'estimated': '2023-08-28T20:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9604',
#    'iata': 'MH9604',
#    'icao': 'MAS9604',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1893',
#     'flight_iata': 'aa1893',
#     'flight_icao': 'aal1893'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'C12',
#    'delay': 133,
#    'scheduled': '2023-08-28T18:05:00+00:00',
#    'estimated': '2023-08-28T18:05:00+00:00',
#    'actual': '2023-08-28T20:17:00+00:00',
#    'estimated_runway': '2023-08-28T20:17:00+00:00',
#    'actual_runway': '2023-08-28T20:17:00+00:00'},
#   'arrival': {'airport': 'Dallas/Fort Worth International',
#    'timezone': 'America/Chicago',
#    'iata': 'DFW',
#    'icao': 'KDFW',
#    'terminal': 'C',
#    'gate': 'C36',
#    'baggage': 'C26',
#    'delay': 91,
#    'scheduled': '2023-08-28T19:54:00+00:00',
#    'estimated': '2023-08-28T19:54:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9505',
#    'iata': 'MH9505',
#    'icao': 'MAS9505',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1571',
#     'flight_iata': 'aa1571',
#     'flight_icao': 'aal1571'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D4',
#    'delay': 115,
#    'scheduled': '2023-08-28T17:30:00+00:00',
#    'estimated': '2023-08-28T17:30:00+00:00',
#    'actual': '2023-08-28T19:22:00+00:00',
#    'estimated_runway': '2023-08-28T19:22:00+00:00',
#    'actual_runway': '2023-08-28T19:22:00+00:00'},
#   'arrival': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '4',
#    'gate': '47A',
#    'baggage': 'T4A',
#    'delay': 65,
#    'scheduled': '2023-08-28T19:56:00+00:00',
#    'estimated': '2023-08-28T19:56:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9409',
#    'iata': 'MH9409',
#    'icao': 'MAS9409',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1998',
#     'flight_iata': 'aa1998',
#     'flight_icao': 'aal1998'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'C8',
#    'delay': 70,
#    'scheduled': '2023-08-28T17:31:00+00:00',
#    'estimated': '2023-08-28T17:31:00+00:00',
#    'actual': '2023-08-28T18:41:00+00:00',
#    'estimated_runway': '2023-08-28T18:41:00+00:00',
#    'actual_runway': '2023-08-28T18:41:00+00:00'},
#   'arrival': {'airport': 'Logan International',
#    'timezone': 'America/New_York',
#    'iata': 'BOS',
#    'icao': 'KBOS',
#    'terminal': 'B',
#    'gate': 'B21',
#    'baggage': '1',
#    'delay': 34,
#    'scheduled': '2023-08-28T19:42:00+00:00',
#    'estimated': '2023-08-28T19:42:00+00:00',
#    'actual': '2023-08-28T20:16:00+00:00',
#    'estimated_runway': '2023-08-28T20:16:00+00:00',
#    'actual_runway': '2023-08-28T20:16:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9462',
#    'iata': 'MH9462',
#    'icao': 'MAS9462',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1978',
#     'flight_iata': 'aa1978',
#     'flight_icao': 'aal1978'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'John F Kennedy International',
#    'timezone': 'America/New_York',
#    'iata': 'JFK',
#    'icao': 'KJFK',
#    'terminal': '8',
#    'gate': '35',
#    'delay': 150,
#    'scheduled': '2023-08-28T15:55:00+00:00',
#    'estimated': '2023-08-28T15:55:00+00:00',
#    'actual': '2023-08-28T18:25:00+00:00',
#    'estimated_runway': '2023-08-28T18:25:00+00:00',
#    'actual_runway': '2023-08-28T18:25:00+00:00'},
#   'arrival': {'airport': 'Miami International Airport',
#    'timezone': 'America/New_York',
#    'iata': 'MIA',
#    'icao': 'KMIA',
#    'terminal': 'N',
#    'gate': 'D1',
#    'baggage': '27',
#    'delay': 107,
#    'scheduled': '2023-08-28T19:17:00+00:00',
#    'estimated': '2023-08-28T19:17:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9377',
#    'iata': 'MH9377',
#    'icao': 'MAS9377',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '320',
#     'flight_iata': 'aa320',
#     'flight_icao': 'aal320'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Los Angeles International',
#    'timezone': 'America/Los_Angeles',
#    'iata': 'LAX',
#    'icao': 'KLAX',
#    'terminal': '5',
#    'gate': '53A',
#    'delay': 87,
#    'scheduled': '2023-08-28T15:22:00+00:00',
#    'estimated': '2023-08-28T15:22:00+00:00',
#    'actual': '2023-08-28T16:48:00+00:00',
#    'estimated_runway': '2023-08-28T16:48:00+00:00',
#    'actual_runway': '2023-08-28T16:48:00+00:00'},
#   'arrival': {'airport': 'Nashville International',
#    'timezone': 'America/Chicago',
#    'iata': 'BNA',
#    'icao': 'KBNA',
#    'terminal': None,
#    'gate': 'C18',
#    'baggage': None,
#    'delay': 55,
#    'scheduled': '2023-08-28T21:27:00+00:00',
#    'estimated': '2023-08-28T21:27:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9419',
#    'iata': 'MH9419',
#    'icao': 'MAS9419',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1287',
#     'flight_iata': 'aa1287',
#     'flight_icao': 'aal1287'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'C11',
#    'delay': 126,
#    'scheduled': '2023-08-28T14:59:00+00:00',
#    'estimated': '2023-08-28T14:59:00+00:00',
#    'actual': '2023-08-28T17:04:00+00:00',
#    'estimated_runway': '2023-08-28T17:04:00+00:00',
#    'actual_runway': '2023-08-28T17:04:00+00:00'},
#   'arrival': {'airport': 'Logan International',
#    'timezone': 'America/New_York',
#    'iata': 'BOS',
#    'icao': 'KBOS',
#    'terminal': 'B',
#    'gate': 'B20',
#    'baggage': '1',
#    'delay': 92,
#    'scheduled': '2023-08-28T17:11:00+00:00',
#    'estimated': '2023-08-28T17:11:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9549',
#    'iata': 'MH9549',
#    'icao': 'MAS9549',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '806',
#     'flight_iata': 'aa806',
#     'flight_icao': 'aal806'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A11',
#    'delay': 130,
#    'scheduled': '2023-08-28T19:25:00+00:00',
#    'estimated': '2023-08-28T19:25:00+00:00',
#    'actual': '2023-08-28T21:34:00+00:00',
#    'estimated_runway': '2023-08-28T21:34:00+00:00',
#    'actual_runway': '2023-08-28T21:34:00+00:00'},
#   'arrival': {'airport': 'El Prat De Llobregat',
#    'timezone': 'Europe/Madrid',
#    'iata': 'BCN',
#    'icao': 'LEBL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '13',
#    'delay': 97,
#    'scheduled': '2023-08-28T22:30:00+00:00',
#    'estimated': '2023-08-28T22:30:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9704',
#    'iata': 'MH9704',
#    'icao': 'MAS9704',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '482',
#     'flight_iata': 'ba482',
#     'flight_icao': 'baw482'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'D13',
#    'delay': 92,
#    'scheduled': '2023-08-28T14:31:00+00:00',
#    'estimated': '2023-08-28T14:31:00+00:00',
#    'actual': '2023-08-28T16:02:00+00:00',
#    'estimated_runway': '2023-08-28T16:02:00+00:00',
#    'actual_runway': '2023-08-28T16:02:00+00:00'},
#   'arrival': {'airport': 'Dallas/Fort Worth International',
#    'timezone': 'America/Chicago',
#    'iata': 'DFW',
#    'icao': 'KDFW',
#    'terminal': 'C',
#    'gate': 'C19',
#    'baggage': 'C15',
#    'delay': 51,
#    'scheduled': '2023-08-28T16:21:00+00:00',
#    'estimated': '2023-08-28T16:21:00+00:00',
#    'actual': '2023-08-28T17:11:00+00:00',
#    'estimated_runway': '2023-08-28T17:11:00+00:00',
#    'actual_runway': '2023-08-28T17:11:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9518',
#    'iata': 'MH9518',
#    'icao': 'MAS9518',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '877',
#     'flight_iata': 'aa877',
#     'flight_icao': 'aal877'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': None,
#    'gate': 'B12',
#    'delay': 69,
#    'scheduled': '2023-08-28T15:00:00+00:00',
#    'estimated': '2023-08-28T15:00:00+00:00',
#    'actual': '2023-08-28T16:09:00+00:00',
#    'estimated_runway': '2023-08-28T16:09:00+00:00',
#    'actual_runway': '2023-08-28T16:09:00+00:00'},
#   'arrival': {'airport': 'Baltimore/Washington International Thurgood Marshall',
#    'timezone': 'America/New_York',
#    'iata': 'BWI',
#    'icao': 'KBWI',
#    'terminal': 'E',
#    'gate': 'C5',
#    'baggage': '9',
#    'delay': 43,
#    'scheduled': '2023-08-28T16:26:00+00:00',
#    'estimated': '2023-08-28T16:26:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9517',
#    'iata': 'MH9517',
#    'icao': 'MAS9517',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1232',
#     'flight_iata': 'aa1232',
#     'flight_icao': 'aal1232'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Baltimore/Washington International Thurgood Marshall',
#    'timezone': 'America/New_York',
#    'iata': 'BWI',
#    'icao': 'KBWI',
#    'terminal': None,
#    'gate': 'C5',
#    'delay': 63,
#    'scheduled': '2023-08-28T17:16:00+00:00',
#    'estimated': '2023-08-28T17:16:00+00:00',
#    'actual': '2023-08-28T18:40:00+00:00',
#    'estimated_runway': '2023-08-28T18:40:00+00:00',
#    'actual_runway': '2023-08-28T18:40:00+00:00'},
#   'arrival': {'airport': 'Charlotte Douglas',
#    'timezone': 'America/New_York',
#    'iata': 'CLT',
#    'icao': 'KCLT',
#    'terminal': '3',
#    'gate': 'B14',
#    'baggage': 'C3',
#    'delay': 53,
#    'scheduled': '2023-08-28T18:46:00+00:00',
#    'estimated': '2023-08-28T18:46:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9606',
#    'iata': 'MH9606',
#    'icao': 'MAS9606',
#    'codeshared': {'airline_name': 'american airlines',
#     'airline_iata': 'aa',
#     'airline_icao': 'aal',
#     'flight_number': '1232',
#     'flight_iata': 'aa1232',
#     'flight_icao': 'aal1232'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '3',
#    'gate': '3A',
#    'delay': 89,
#    'scheduled': '2023-08-28T19:20:00+00:00',
#    'estimated': '2023-08-28T19:20:00+00:00',
#    'actual': '2023-08-28T20:48:00+00:00',
#    'estimated_runway': '2023-08-28T20:48:00+00:00',
#    'actual_runway': '2023-08-28T20:48:00+00:00'},
#   'arrival': {'airport': 'Vienna International',
#    'timezone': 'Europe/Vienna',
#    'iata': 'VIE',
#    'icao': 'LOWW',
#    'terminal': '3',
#    'gate': None,
#    'baggage': None,
#    'delay': 65,
#    'scheduled': '2023-08-28T22:40:00+00:00',
#    'estimated': '2023-08-28T22:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9920',
#    'iata': 'MH9920',
#    'icao': 'MAS9920',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '706',
#     'flight_iata': 'ba706',
#     'flight_icao': 'baw706'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'B45',
#    'delay': 85,
#    'scheduled': '2023-08-28T20:30:00+00:00',
#    'estimated': '2023-08-28T20:30:00+00:00',
#    'actual': '2023-08-28T21:55:00+00:00',
#    'estimated_runway': '2023-08-28T21:55:00+00:00',
#    'actual_runway': '2023-08-28T21:55:00+00:00'},
#   'arrival': {'airport': 'St-Exupéry',
#    'timezone': 'Europe/Paris',
#    'iata': 'LYS',
#    'icao': 'LFLL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '106',
#    'delay': 51,
#    'scheduled': '2023-08-28T23:10:00+00:00',
#    'estimated': '2023-08-28T23:10:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9874',
#    'iata': 'MH9874',
#    'icao': 'MAS9874',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '364',
#     'flight_iata': 'ba364',
#     'flight_icao': 'baw364'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Charles De Gaulle',
#    'timezone': 'Europe/Paris',
#    'iata': 'CDG',
#    'icao': 'LFPG',
#    'terminal': '1',
#    'gate': '26',
#    'delay': 123,
#    'scheduled': '2023-08-28T16:05:00+00:00',
#    'estimated': '2023-08-28T16:05:00+00:00',
#    'actual': '2023-08-28T18:08:00+00:00',
#    'estimated_runway': '2023-08-28T18:08:00+00:00',
#    'actual_runway': '2023-08-28T18:08:00+00:00'},
#   'arrival': {'airport': 'Doha International',
#    'timezone': 'Asia/Qatar',
#    'iata': 'DOH',
#    'icao': 'OTHH',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '3',
#    'delay': 93,
#    'scheduled': '2023-08-28T23:25:00+00:00',
#    'estimated': '2023-08-28T23:25:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9216',
#    'iata': 'MH9216',
#    'icao': 'MAS9216',
#    'codeshared': {'airline_name': 'qatar airways',
#     'airline_iata': 'qr',
#     'airline_icao': 'qtr',
#     'flight_number': '40',
#     'flight_iata': 'qr40',
#     'flight_icao': 'qtr40'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Helsinki-vantaa',
#    'timezone': 'Europe/Helsinki',
#    'iata': 'HEL',
#    'icao': 'EFHK',
#    'terminal': '2',
#    'gate': '19',
#    'delay': 45,
#    'scheduled': '2023-08-28T18:10:00+00:00',
#    'estimated': '2023-08-28T18:10:00+00:00',
#    'actual': '2023-08-28T18:55:00+00:00',
#    'estimated_runway': '2023-08-28T18:55:00+00:00',
#    'actual_runway': '2023-08-28T18:55:00+00:00'},
#   'arrival': {'airport': 'Schiphol',
#    'timezone': 'Europe/Amsterdam',
#    'iata': 'AMS',
#    'icao': 'EHAM',
#    'terminal': '2',
#    'gate': 'D85',
#    'baggage': '009',
#    'delay': 33,
#    'scheduled': '2023-08-28T19:40:00+00:00',
#    'estimated': '2023-08-28T19:40:00+00:00',
#    'actual': '2023-08-28T20:13:00+00:00',
#    'estimated_runway': '2023-08-28T20:13:00+00:00',
#    'actual_runway': '2023-08-28T20:13:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5674',
#    'iata': 'MH5674',
#    'icao': 'MAS5674',
#    'codeshared': {'airline_name': 'klm',
#     'airline_iata': 'kl',
#     'airline_icao': 'klm',
#     'flight_number': '1170',
#     'flight_iata': 'kl1170',
#     'flight_icao': 'klm1170'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#    'timezone': 'Europe/Rome',
#    'iata': 'FCO',
#    'icao': 'LIRF',
#    'terminal': '1',
#    'gate': 'A61',
#    'delay': 98,
#    'scheduled': '2023-08-28T17:25:00+00:00',
#    'estimated': '2023-08-28T17:25:00+00:00',
#    'actual': '2023-08-28T19:03:00+00:00',
#    'estimated_runway': '2023-08-28T19:03:00+00:00',
#    'actual_runway': '2023-08-28T19:03:00+00:00'},
#   'arrival': {'airport': 'Schiphol',
#    'timezone': 'Europe/Amsterdam',
#    'iata': 'AMS',
#    'icao': 'EHAM',
#    'terminal': '3',
#    'gate': 'C15',
#    'baggage': '015',
#    'delay': 53,
#    'scheduled': '2023-08-28T20:00:00+00:00',
#    'estimated': '2023-08-28T20:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5680',
#    'iata': 'MH5680',
#    'icao': 'MAS5680',
#    'codeshared': {'airline_name': 'klm',
#     'airline_iata': 'kl',
#     'airline_icao': 'klm',
#     'flight_number': '1604',
#     'flight_iata': 'kl1604',
#     'flight_icao': 'klm1604'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A21',
#    'delay': 63,
#    'scheduled': '2023-08-28T19:55:00+00:00',
#    'estimated': '2023-08-28T19:55:00+00:00',
#    'actual': '2023-08-28T20:58:00+00:00',
#    'estimated_runway': '2023-08-28T20:58:00+00:00',
#    'actual_runway': '2023-08-28T20:58:00+00:00'},
#   'arrival': {'airport': 'Kastrup',
#    'timezone': 'Europe/Copenhagen',
#    'iata': 'CPH',
#    'icao': 'EKCH',
#    'terminal': '2',
#    'gate': 'C27',
#    'baggage': None,
#    'delay': 33,
#    'scheduled': '2023-08-28T22:50:00+00:00',
#    'estimated': '2023-08-28T22:50:00+00:00',
#    'actual': '2023-08-28T23:23:00+00:00',
#    'estimated_runway': '2023-08-28T23:23:00+00:00',
#    'actual_runway': '2023-08-28T23:23:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9804',
#    'iata': 'MH9804',
#    'icao': 'MAS9804',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '822',
#     'flight_iata': 'ba822',
#     'flight_icao': 'baw822'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A10',
#    'delay': 108,
#    'scheduled': '2023-08-28T20:05:00+00:00',
#    'estimated': '2023-08-28T20:05:00+00:00',
#    'actual': '2023-08-28T21:53:00+00:00',
#    'estimated_runway': '2023-08-28T21:53:00+00:00',
#    'actual_runway': '2023-08-28T21:53:00+00:00'},
#   'arrival': {'airport': 'Geneve-cointrin',
#    'timezone': 'Europe/Zurich',
#    'iata': 'GVA',
#    'icao': 'LSGG',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '7',
#    'delay': 82,
#    'scheduled': '2023-08-28T22:45:00+00:00',
#    'estimated': '2023-08-28T22:45:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9860',
#    'iata': 'MH9860',
#    'icao': 'MAS9860',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '738',
#     'flight_iata': 'ba738',
#     'flight_icao': 'baw738'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'B45',
#    'delay': 153,
#    'scheduled': '2023-08-28T13:30:00+00:00',
#    'estimated': '2023-08-28T13:30:00+00:00',
#    'actual': '2023-08-28T16:03:00+00:00',
#    'estimated_runway': '2023-08-28T16:03:00+00:00',
#    'actual_runway': '2023-08-28T16:03:00+00:00'},
#   'arrival': {'airport': 'El Prat De Llobregat',
#    'timezone': 'Europe/Madrid',
#    'iata': 'BCN',
#    'icao': 'LEBL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': '11',
#    'delay': 118,
#    'scheduled': '2023-08-28T16:40:00+00:00',
#    'estimated': '2023-08-28T16:40:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '9700',
#    'iata': 'MH9700',
#    'icao': 'MAS9700',
#    'codeshared': {'airline_name': 'british airways',
#     'airline_iata': 'ba',
#     'airline_icao': 'baw',
#     'flight_number': '406',
#     'flight_iata': 'ba406',
#     'flight_icao': 'baw406'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Heathrow',
#    'timezone': 'Europe/London',
#    'iata': 'LHR',
#    'icao': 'EGLL',
#    'terminal': '5',
#    'gate': 'A13',
#    'delay': 127,
#    'scheduled': '2023-08-28T13:20:00+00:00',
#    'estimated': '2023-08-28T13:20:00+00:00',
#    'actual': '2023-08-28T15:27:00+00:00',
#    'estimated_runway': '2023-08-28T15:27:00+00:00',
#    'actual_runway': '2023-08-28T15:27:00+00:00'},
#   'arrival': {'airport': 'Charles De Gaulle',
#    'timezone': 'Europe/Paris',
# ...
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 43,
#    'scheduled': '2023-08-28T17:50:00+00:00',
#    'estimated': '2023-08-28T17:50:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '865',
#    'iata': 'MH865',
#    'icao': 'MAS865',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Miri',
#    'timezone': 'Asia/Kuching',
#    'iata': 'MYY',
#    'icao': 'WBGR',
#    'terminal': None,
#    'gate': None,
#    'delay': 59,
#    'scheduled': '2023-08-28T16:25:00+00:00',
#    'estimated': '2023-08-28T16:25:00+00:00',
#    'actual': '2023-08-28T17:23:00+00:00',
#    'estimated_runway': '2023-08-28T17:23:00+00:00',
#    'actual_runway': '2023-08-28T17:23:00+00:00'},
#   'arrival': {'airport': 'Kuching',
#    'timezone': 'Asia/Kuching',
#    'iata': 'KCH',
#    'icao': 'WBGG',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 45,
#    'scheduled': '2023-08-28T17:25:00+00:00',
#    'estimated': '2023-08-28T17:25:00+00:00',
#    'actual': '2023-08-28T18:10:00+00:00',
#    'estimated_runway': '2023-08-28T18:10:00+00:00',
#    'actual_runway': '2023-08-28T18:10:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4713',
#    'iata': 'MH4713',
#    'icao': 'MAS4713',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '2681',
#     'flight_iata': 'fy2681',
#     'flight_icao': 'ffm2681'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 58,
#    'scheduled': '2023-08-28T15:55:00+00:00',
#    'estimated': '2023-08-28T15:55:00+00:00',
#    'actual': '2023-08-28T16:52:00+00:00',
#    'estimated_runway': '2023-08-28T16:52:00+00:00',
#    'actual_runway': '2023-08-28T16:52:00+00:00'},
#   'arrival': {'airport': 'Langakawi International',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'LGK',
#    'icao': 'WMKL',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 42,
#    'scheduled': '2023-08-28T17:00:00+00:00',
#    'estimated': '2023-08-28T17:00:00+00:00',
#    'actual': '2023-08-28T17:41:00+00:00',
#    'estimated_runway': '2023-08-28T17:41:00+00:00',
#    'actual_runway': '2023-08-28T17:41:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '1446',
#    'iata': 'MH1446',
#    'icao': 'MAS1446',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 76,
#    'scheduled': '2023-08-28T15:25:00+00:00',
#    'estimated': '2023-08-28T15:25:00+00:00',
#    'actual': '2023-08-28T16:40:00+00:00',
#    'estimated_runway': '2023-08-28T16:40:00+00:00',
#    'actual_runway': '2023-08-28T16:40:00+00:00'},
#   'arrival': {'airport': 'Kuching',
#    'timezone': 'Asia/Kuching',
#    'iata': 'KCH',
#    'icao': 'WBGG',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 60,
#    'scheduled': '2023-08-28T17:15:00+00:00',
#    'estimated': '2023-08-28T17:15:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2544',
#    'iata': 'MH2544',
#    'icao': 'MAS2544',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 93,
#    'scheduled': '2023-08-28T15:10:00+00:00',
#    'estimated': '2023-08-28T15:10:00+00:00',
#    'actual': '2023-08-28T16:42:00+00:00',
#    'estimated_runway': '2023-08-28T16:42:00+00:00',
#    'actual_runway': '2023-08-28T16:42:00+00:00'},
#   'arrival': {'airport': 'King Abdulaziz International',
#    'timezone': 'Asia/Riyadh',
#    'iata': 'JED',
#    'icao': 'OEJN',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 65,
#    'scheduled': '2023-08-28T19:00:00+00:00',
#    'estimated': '2023-08-28T19:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '156',
#    'iata': 'MH156',
#    'icao': 'MAS156',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MTJ',
#    'iata': 'A333',
#    'icao': 'A333',
#    'icao24': '75025D'},
#   'live': {'updated': '2023-08-28T14:06:49+00:00',
#    'latitude': 19.2,
#    'longitude': 61.27,
#    'altitude': 12192,
#    'direction': 281,
#    'speed_horizontal': 898.22,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Penang International',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'PEN',
#    'icao': 'WMKP',
#    'terminal': None,
#    'gate': None,
#    'delay': 74,
#    'scheduled': '2023-08-28T15:30:00+00:00',
#    'estimated': '2023-08-28T15:30:00+00:00',
#    'actual': '2023-08-28T16:43:00+00:00',
#    'estimated_runway': '2023-08-28T16:43:00+00:00',
#    'actual_runway': '2023-08-28T16:43:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 56,
#    'scheduled': '2023-08-28T16:35:00+00:00',
#    'estimated': '2023-08-28T16:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '1149',
#    'iata': 'MH1149',
#    'icao': 'MAS1149',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Sultan Ismail Petra',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KBR',
#    'icao': 'WMKC',
#    'terminal': None,
#    'gate': None,
#    'delay': 49,
#    'scheduled': '2023-08-28T20:55:00+00:00',
#    'estimated': '2023-08-28T20:55:00+00:00',
#    'actual': '2023-08-28T21:43:00+00:00',
#    'estimated_runway': '2023-08-28T21:43:00+00:00',
#    'actual_runway': '2023-08-28T21:43:00+00:00'},
#   'arrival': {'airport': 'Sultan Abdul Aziz Shah',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'SZB',
#    'icao': 'WMSA',
#    'terminal': None,
#    'gate': None,
#    'baggage': None,
#    'delay': 37,
#    'scheduled': '2023-08-28T22:00:00+00:00',
#    'estimated': '2023-08-28T22:00:00+00:00',
#    'actual': '2023-08-28T22:36:00+00:00',
#    'estimated_runway': '2023-08-28T22:36:00+00:00',
#    'actual_runway': '2023-08-28T22:36:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '5325',
#    'iata': 'MH5325',
#    'icao': 'MAS5325',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '1153',
#     'flight_iata': 'fy1153',
#     'flight_icao': 'ffm1153'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Singapore Changi',
#    'timezone': 'Asia/Singapore',
#    'iata': 'SIN',
#    'icao': 'WSSS',
#    'terminal': '2',
#    'gate': 'E1',
#    'delay': 50,
#    'scheduled': '2023-08-28T15:35:00+00:00',
#    'estimated': '2023-08-28T15:35:00+00:00',
#    'actual': '2023-08-28T16:25:00+00:00',
#    'estimated_runway': '2023-08-28T16:25:00+00:00',
#    'actual_runway': '2023-08-28T16:25:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 40,
#    'scheduled': '2023-08-28T16:35:00+00:00',
#    'estimated': '2023-08-28T16:35:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '624',
#    'iata': 'MH624',
#    'icao': 'MAS624',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kota-Kinabalu International Airport',
#    'timezone': 'Asia/Kuching',
#    'iata': 'BKI',
#    'icao': 'WBKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 29,
#    'scheduled': '2023-08-28T15:30:00+00:00',
#    'estimated': '2023-08-28T15:30:00+00:00',
#    'actual': '2023-08-28T15:59:00+00:00',
#    'estimated_runway': '2023-08-28T15:59:00+00:00',
#    'actual_runway': '2023-08-28T15:59:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 31,
#    'scheduled': '2023-08-28T18:05:00+00:00',
#    'estimated': '2023-08-28T18:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2641',
#    'iata': 'MH2641',
#    'icao': 'MAS2641',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MXR',
#    'iata': 'B738',
#    'icao': 'B738',
#    'icao24': '75021C'},
#   'live': {'updated': '2023-08-28T08:03:02+00:00',
#    'latitude': 5.79,
#    'longitude': 115.9,
#    'altitude': 2240.28,
#    'direction': 256,
#    'speed_horizontal': 483.372,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Sydney Kingsford Smith Airport',
#    'timezone': 'Australia/Sydney',
#    'iata': 'SYD',
#    'icao': 'YSSY',
#    'terminal': None,
#    'gate': None,
#    'delay': 336,
#    'scheduled': '2023-08-28T16:40:00+00:00',
#    'estimated': '2023-08-28T16:40:00+00:00',
#    'actual': '2023-08-28T22:16:00+00:00',
#    'estimated_runway': '2023-08-28T22:16:00+00:00',
#    'actual_runway': '2023-08-28T22:16:00+00:00'},
#   'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 390,
#    'scheduled': '2023-08-28T22:05:00+00:00',
#    'estimated': '2023-08-28T22:05:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '6204',
#    'iata': 'MH6204',
#    'icao': 'MAS6204',
#    'codeshared': None},
#   'aircraft': {'registration': '9M-MUA',
#    'iata': 'A332',
#    'icao': 'A332',
#    'icao24': '750263'},
#   'live': {'updated': '2023-08-28T12:36:20+00:00',
#    'latitude': -33.31,
#    'longitude': 148.87,
#    'altitude': 11201.4,
#    'direction': 288,
#    'speed_horizontal': 859.328,
#    'speed_vertical': 0,
#    'is_ground': False}},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuching',
#    'timezone': 'Asia/Kuching',
#    'iata': 'KCH',
#    'icao': 'WBGG',
#    'terminal': None,
#    'gate': None,
#    'delay': 51,
#    'scheduled': '2023-08-28T14:45:00+00:00',
#    'estimated': '2023-08-28T14:45:00+00:00',
#    'actual': '2023-08-28T15:35:00+00:00',
#    'estimated_runway': '2023-08-28T15:35:00+00:00',
#    'actual_runway': '2023-08-28T15:35:00+00:00'},
#   'arrival': {'airport': 'Miri',
#    'timezone': 'Asia/Kuching',
#    'iata': 'MYY',
#    'icao': 'WBGR',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 41,
#    'scheduled': '2023-08-28T15:45:00+00:00',
#    'estimated': '2023-08-28T15:45:00+00:00',
#    'actual': '2023-08-28T16:26:00+00:00',
#    'estimated_runway': '2023-08-28T16:26:00+00:00',
#    'actual_runway': '2023-08-28T16:26:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '4712',
#    'iata': 'MH4712',
#    'icao': 'MAS4712',
#    'codeshared': {'airline_name': 'firefly',
#     'airline_iata': 'fy',
#     'airline_icao': 'ffm',
#     'flight_number': '2680',
#     'flight_iata': 'fy2680',
#     'flight_icao': 'ffm2680'}},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 82,
#    'scheduled': '2023-08-28T15:05:00+00:00',
#    'estimated': '2023-08-28T15:05:00+00:00',
#    'actual': '2023-08-28T16:26:00+00:00',
#    'estimated_runway': '2023-08-28T16:26:00+00:00',
#    'actual_runway': '2023-08-28T16:26:00+00:00'},
#   'arrival': {'airport': 'Suvarnabhumi International',
#    'timezone': 'Asia/Bangkok',
#    'iata': 'BKK',
#    'icao': 'VTBS',
#    'terminal': '2',
#    'gate': None,
#    'baggage': None,
#    'delay': 55,
#    'scheduled': '2023-08-28T16:20:00+00:00',
#    'estimated': '2023-08-28T16:20:00+00:00',
#    'actual': '2023-08-28T17:15:00+00:00',
#    'estimated_runway': '2023-08-28T17:15:00+00:00',
#    'actual_runway': '2023-08-28T17:15:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '782',
#    'iata': 'MH782',
#    'icao': 'MAS782',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'scheduled',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 65,
#    'scheduled': '2023-08-28T14:55:00+00:00',
#    'estimated': '2023-08-28T14:55:00+00:00',
#    'actual': '2023-08-28T15:59:00+00:00',
#    'estimated_runway': '2023-08-28T15:59:00+00:00',
#    'actual_runway': '2023-08-28T15:59:00+00:00'},
#   'arrival': {'airport': None,
#    'timezone': None,
#    'iata': 'KNO',
#    'icao': 'WIMM',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 40,
#    'scheduled': '2023-08-28T15:00:00+00:00',
#    'estimated': '2023-08-28T15:00:00+00:00',
#    'actual': None,
#    'estimated_runway': None,
#    'actual_runway': None},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '864',
#    'iata': 'MH864',
#    'icao': 'MAS864',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None},
#  {'flight_date': '2023-08-28',
#   'flight_status': 'landed',
#   'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#    'timezone': 'Asia/Kuala_Lumpur',
#    'iata': 'KUL',
#    'icao': 'WMKK',
#    'terminal': '1',
#    'gate': None,
#    'delay': 58,
#    'scheduled': '2023-08-28T14:40:00+00:00',
#    'estimated': '2023-08-28T14:40:00+00:00',
#    'actual': '2023-08-28T15:37:00+00:00',
#    'estimated_runway': '2023-08-28T15:37:00+00:00',
#    'actual_runway': '2023-08-28T15:37:00+00:00'},
#   'arrival': {'airport': 'Labuan',
#    'timezone': 'Asia/Kuching',
#    'iata': 'LBU',
#    'icao': 'WBKL',
#    'terminal': '1',
#    'gate': None,
#    'baggage': None,
#    'delay': 32,
#    'scheduled': '2023-08-28T17:10:00+00:00',
#    'estimated': '2023-08-28T17:10:00+00:00',
#    'actual': '2023-08-28T17:41:00+00:00',
#    'estimated_runway': '2023-08-28T17:41:00+00:00',
#    'actual_runway': '2023-08-28T17:41:00+00:00'},
#   'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#   'flight': {'number': '2634',
#    'iata': 'MH2634',
#    'icao': 'MAS2634',
#    'codeshared': None},
#   'aircraft': None,
#   'live': None}]

# %%
with open("../tests/data/sample_flight_response.json", "w") as j:
    j.write(json.dumps(api_response))

# %%
for key in api_response["data"][0]:
    print(key)
# Out:
# flight_date
# flight_status
# departure
# arrival
# airline
# flight
# aircraft
# live

# %%
api_response["data"][0]["airline"]
# Out:
# {'name': 'Lion Air', 'iata': 'JT', 'icao': 'LNI'}

# %%
mh = [flight for flight in api_response["data"] if "malaysia" in flight["airline"]]
mh
# Out:
# []

# %%
airlines = [flight["airline"]["name"] for flight in api_response["data"]]
airlines = set(airlines)
airlines
# Out:
# {'Air Astana',
#  'Air Canada',
#  'Air China LTD',
#  'Air India',
#  'Air New Zealand',
#  'Airblue',
#  'Alaska Airlines',
#  'Alliance Airlines',
#  'Aurora',
#  'Bamboo Airways',
#  'Bangkok Airways',
#  'China Eastern Airlines',
#  'China Postal Airlines',
#  'Emirates',
#  'Etihad Airways',
#  'Finnair',
#  'FlexFlight',
#  'Hawaiian Airlines',
#  'Jet Linx Aviation',
#  'Jetstar',
#  'Kuwait Airways',
#  'LATAM Airlines',
#  'Lion Air',
#  'Longhao Airlines',
#  'Myanmar Airways International',
#  None,
#  'Philippine Airlines',
#  'Qantas',
#  'Qatar Airways',
#  'S7 Airlines',
#  'SF Airlines',
#  'Sichuan Airlines',
#  'Singapore Airlines',
#  'SriLankan Airlines',
#  'Sriwijaya Air',
#  'Virgin Australia',
#  'Yakutia'}

# %%
"Malaysia Airlines" in airlines
# Out:
# False

# %% [markdown]
# ## Pagination limit
#
# Free tier only offers 100 counts so we must use additional requests to retrieve the rest of the count using offset
#
# First request will retrive the first 100, with offset of 0; second will retrieve the next 100, until the total is met
#
# For example, given total of 563, 6 requests will be made; the last retrieving the remaining 63 flight records

# %%
from time import sleep
from datetime import date

# %%
def get_flight_api(
    offset: int = 0,
    limit: int = 100,
    airline: str = "Malaysia Airlines",
    min_delay: int = 1,
    flight_api_url="http://api.aviationstack.com/v1/flights",
) -> dict:
    params = {
        "access_key": av_api_key,  # retrieved from .env, global scope
        "offset": offset,
        "limit": limit,
        "airline_name": airline,
        "min_delay_arr": min_delay,
    }
    result = requests.get(flight_api_url, params, timeout=5)
    return result.json()


def write_local_json(api_response: dict, offset: int = 0, limit: int = 100):
    local_json_path = Path(
        f"../data/responses/flight-{str(date.today())}-{offset}-{offset+limit}.json"
    )
    with open(local_json_path, "w") as j:
        j.write(json.dumps(api_response))
        print(f"saved to {local_json_path}")
    return local_json_path


def get_all_delays(
    limit: int = 100,
    airline: str = "Malaysia Airlines",
    min_delay: int = 1,
    flight_api_url="http://api.aviationstack.com/v1/flights",
):
    print(f"retrieving 0th to {limit}th records")
    first = get_flight_api()
    write_local_json(first)
    retrieved = limit
    total = first["pagination"]["total"]
    print(f"total: {total}")
    while retrieved < total:
        sleep(0.5)
        print(f"retrieving {retrieved}th to {retrieved + limit}th")
        response = get_flight_api(offset=retrieved, limit=limit)
        # save response
        json_path = write_local_json(response, offset=retrieved)
        retrieved += response["pagination"]["count"]
    return retrieved

# %%
num_records = get_all_delays()
print(f"{num_records} flights were late")
# Out:
# retrieving 0th to 100th records
# saved to ../data/responses/flight-2023-09-16-0-100.json
# total: 714
# retrieving 100th to 200th
# saved to ../data/responses/flight-2023-09-16-100-200.json
# retrieving 200th to 300th
# saved to ../data/responses/flight-2023-09-16-200-300.json
# retrieving 300th to 400th
# saved to ../data/responses/flight-2023-09-16-300-400.json
# retrieving 400th to 500th
# saved to ../data/responses/flight-2023-09-16-400-500.json
# retrieving 500th to 600th
# saved to ../data/responses/flight-2023-09-16-500-600.json
# retrieving 600th to 700th
# saved to ../data/responses/flight-2023-09-16-600-700.json
# retrieving 700th to 800th
# saved to ../data/responses/flight-2023-09-16-700-800.json
# 714 flights were late

# %% [markdown]
# ## Automatic retries with Session
#
# Session object persists params across requests which increases performance when making requests to the same host, and allows for [automatic retries](https://requests.readthedocs.io/en/latest/user/advanced/#example-automatic-retries) through `urllib3`

# %%
from urllib3.util import Retry
from requests import Session
from requests.adapters import HTTPAdapter

# %%
s = Session()

retries = Retry(
    total=3,
    backoff_factor=0.1,
    status_forcelist=[502, 503, 504],
    allowed_methods={"POST"},
)
# mount registers this specific transport adapter to this url prefix
s.mount(av_api_url, HTTPAdapter(max_retries=retries))
params = {
    "access_key": av_api_key,
    "airline_name": "Malaysia Airlines",
    "min_delay_arr": 1,
    # "flight_date": "2023-08-22",
}
res = s.get(url=flight_api_url, params=params)

# %%
res.json()
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 618},
#  'data': [{'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'H4',
#     'delay': 38,
#     'scheduled': '2023-09-25T10:25:00+00:00',
#     'estimated': '2023-09-25T10:25:00+00:00',
#     'actual': '2023-09-25T11:02:00+00:00',
#     'estimated_runway': '2023-09-25T11:02:00+00:00',
#     'actual_runway': '2023-09-25T11:02:00+00:00'},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': None,
#     'baggage': '47',
#     'delay': 15,
#     'scheduled': '2023-09-25T11:35:00+00:00',
#     'estimated': '2023-09-25T11:35:00+00:00',
#     'actual': '2023-09-25T11:41:00+00:00',
#     'estimated_runway': '2023-09-25T11:41:00+00:00',
#     'actual_runway': '2023-09-25T11:41:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5855',
#     'iata': 'MH5855',
#     'icao': 'MAS5855',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '105',
#      'flight_iata': 'sq105',
#      'flight_icao': 'sia105'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Guangzhou Baiyun International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'CAN',
#     'icao': 'ZGGG',
#     'terminal': '2',
#     'gate': None,
#     'delay': 28,
#     'scheduled': '2023-09-25T08:25:00+00:00',
#     'estimated': '2023-09-25T08:25:00+00:00',
#     'actual': '2023-09-25T08:53:00+00:00',
#     'estimated_runway': '2023-09-25T08:53:00+00:00',
#     'actual_runway': '2023-09-25T08:53:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 25,
#     'scheduled': '2023-09-25T12:00:00+00:00',
#     'estimated': '2023-09-25T12:00:00+00:00',
#     'actual': '2023-09-25T12:25:00+00:00',
#     'estimated_runway': '2023-09-25T12:25:00+00:00',
#     'actual_runway': '2023-09-25T12:25:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '4481',
#     'iata': 'MH4481',
#     'icao': 'MAS4481',
#     'codeshared': {'airline_name': 'china southern airlines',
#      'airline_iata': 'cz',
#      'airline_icao': 'csn',
#      'flight_number': '349',
#      'flight_iata': 'cz349',
#      'flight_icao': 'csn349'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'H2',
#     'delay': 26,
#     'scheduled': '2023-09-25T11:10:00+00:00',
#     'estimated': '2023-09-25T11:10:00+00:00',
#     'actual': '2023-09-25T11:35:00+00:00',
#     'estimated_runway': '2023-09-25T11:35:00+00:00',
#     'actual_runway': '2023-09-25T11:35:00+00:00'},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '2',
#     'gate': None,
#     'baggage': '36',
#     'delay': 6,
#     'scheduled': '2023-09-25T12:10:00+00:00',
#     'estimated': '2023-09-25T12:10:00+00:00',
#     'actual': '2023-09-25T12:16:00+00:00',
#     'estimated_runway': '2023-09-25T12:16:00+00:00',
#     'actual_runway': '2023-09-25T12:16:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5725',
#     'iata': 'MH5725',
#     'icao': 'MAS5725',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '107',
#      'flight_iata': 'sq107',
#      'flight_icao': 'sia107'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'active',
#    'departure': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': 'C84',
#     'delay': 39,
#     'scheduled': '2023-09-25T07:35:00+00:00',
#     'estimated': '2023-09-25T07:35:00+00:00',
#     'actual': '2023-09-25T08:13:00+00:00',
#     'estimated_runway': '2023-09-25T08:13:00+00:00',
#     'actual_runway': '2023-09-25T08:13:00+00:00'},
#    'arrival': {'airport': 'Mohamed V',
#     'timezone': 'Africa/Casablanca',
#     'iata': 'CMN',
#     'icao': 'GMMN',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 1,
#     'scheduled': '2023-09-25T13:30:00+00:00',
#     'estimated': '2023-09-25T13:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '4170',
#     'iata': 'MH4170',
#     'icao': 'MAS4170',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '1397',
#      'flight_iata': 'qr1397',
#      'flight_icao': 'qtr1397'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'active',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'C26',
#     'delay': 17,
#     'scheduled': '2023-09-25T13:20:00+00:00',
#     'estimated': '2023-09-25T13:20:00+00:00',
#     'actual': '2023-09-25T13:37:00+00:00',
#     'estimated_runway': '2023-09-25T13:37:00+00:00',
#     'actual_runway': '2023-09-25T13:37:00+00:00'},
#    'arrival': {'airport': 'Suvarnabhumi International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'BKK',
#     'icao': 'VTBS',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2023-09-25T14:30:00+00:00',
#     'estimated': '2023-09-25T14:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5860',
#     'iata': 'MH5860',
#     'icao': 'MAS5860',
#     'codeshared': {'airline_name': 'thai airways international',
#      'airline_iata': 'tg',
#      'airline_icao': 'tha',
#      'flight_number': '416',
#      'flight_iata': 'tg416',
#      'flight_icao': 'tha416'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'C3',
#     'delay': 58,
#     'scheduled': '2023-09-25T09:30:00+00:00',
#     'estimated': '2023-09-25T09:30:00+00:00',
#     'actual': '2023-09-25T10:27:00+00:00',
#     'estimated_runway': '2023-09-25T10:27:00+00:00',
#     'actual_runway': '2023-09-25T10:27:00+00:00'},
#    'arrival': {'airport': 'Seeb',
#     'timezone': 'Asia/Muscat',
#     'iata': 'MCT',
#     'icao': 'OOMS',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 24,
#     'scheduled': '2023-09-25T12:10:00+00:00',
#     'estimated': '2023-09-25T12:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5932',
#     'iata': 'MH5932',
#     'icao': 'MAS5932',
#     'codeshared': {'airline_name': 'oman air',
#      'airline_iata': 'wy',
#      'airline_icao': 'oma',
#      'flight_number': '822',
#      'flight_iata': 'wy822',
#      'flight_icao': 'oma822'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '2',
#     'gate': 'E6',
#     'delay': 37,
#     'scheduled': '2023-09-25T09:20:00+00:00',
#     'estimated': '2023-09-25T09:20:00+00:00',
#     'actual': '2023-09-25T09:57:00+00:00',
#     'estimated_runway': '2023-09-25T09:57:00+00:00',
#     'actual_runway': '2023-09-25T09:57:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 17,
#     'scheduled': '2023-09-25T10:20:00+00:00',
#     'estimated': '2023-09-25T10:20:00+00:00',
#     'actual': '2023-09-25T10:37:00+00:00',
#     'estimated_runway': '2023-09-25T10:37:00+00:00',
#     'actual_runway': '2023-09-25T10:37:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5724',
#     'iata': 'MH5724',
#     'icao': 'MAS5724',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '108',
#      'flight_iata': 'sq108',
#      'flight_icao': 'sia108'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Bandaranaike International',
#     'timezone': 'Asia/Colombo',
#     'iata': 'CMB',
#     'icao': 'VCBI',
#     'terminal': None,
#     'gate': '11',
#     'delay': 119,
#     'scheduled': '2023-09-25T00:05:00+00:00',
#     'estimated': '2023-09-25T00:05:00+00:00',
#     'actual': '2023-09-25T02:04:00+00:00',
#     'estimated_runway': '2023-09-25T02:04:00+00:00',
#     'actual_runway': '2023-09-25T02:04:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 98,
#     'scheduled': '2023-09-25T06:20:00+00:00',
#     'estimated': '2023-09-25T06:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '178',
#     'iata': 'MH178',
#     'icao': 'MAS178',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MXA',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '750201'},
#    'live': {'updated': '2023-09-24T21:06:02+00:00',
#     'latitude': 6.28,
#     'longitude': 83.34,
#     'altitude': 11277.6,
#     'direction': 103,
#     'speed_horizontal': 796.36,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kota-Kinabalu International Airport',
#     'timezone': 'Asia/Kuching',
#     'iata': 'BKI',
#     'icao': 'WBKK',
#     'terminal': '1',
#     'gate': None,
#     'delay': 11,
#     'scheduled': '2023-09-25T00:50:00+00:00',
#     'estimated': '2023-09-25T00:50:00+00:00',
#     'actual': '2023-09-25T01:00:00+00:00',
#     'estimated_runway': '2023-09-25T01:00:00+00:00',
#     'actual_runway': '2023-09-25T01:00:00+00:00'},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '2',
#     'gate': '82',
#     'baggage': None,
#     'delay': 17,
#     'scheduled': '2023-09-25T07:20:00+00:00',
#     'estimated': '2023-09-25T07:20:00+00:00',
#     'actual': '2023-09-25T07:36:00+00:00',
#     'estimated_runway': '2023-09-25T07:36:00+00:00',
#     'actual_runway': '2023-09-25T07:36:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '80',
#     'iata': 'MH80',
#     'icao': 'MAS80',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MXI',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '750209'},
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': '8',
#     'delay': 41,
#     'scheduled': '2023-09-25T00:05:00+00:00',
#     'estimated': '2023-09-25T00:05:00+00:00',
#     'actual': '2023-09-25T00:45:00+00:00',
#     'estimated_runway': '2023-09-25T00:45:00+00:00',
#     'actual_runway': '2023-09-25T00:45:00+00:00'},
#    'arrival': {'airport': 'Los Angeles International',
#     'timezone': 'America/Los_Angeles',
#     'iata': 'LAX',
#     'icao': 'KLAX',
#     'terminal': 'B',
#     'gate': '134',
#     'baggage': None,
#     'delay': 11,
#     'scheduled': '2023-09-24T22:15:00+00:00',
#     'estimated': '2023-09-24T22:15:00+00:00',
#     'actual': '2023-09-24T21:53:00+00:00',
#     'estimated_runway': '2023-09-24T21:53:00+00:00',
#     'actual_runway': '2023-09-24T21:53:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '9190',
#     'iata': 'MH9190',
#     'icao': 'MAS9190',
#     'codeshared': {'airline_name': 'cathay pacific',
#      'airline_iata': 'cx',
#      'airline_icao': 'cpa',
#      'flight_number': '880',
#      'flight_iata': 'cx880',
#      'flight_icao': 'cpa880'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'C16',
#     'delay': 48,
#     'scheduled': '2023-09-25T02:55:00+00:00',
#     'estimated': '2023-09-25T02:55:00+00:00',
#     'actual': '2023-09-25T03:43:00+00:00',
#     'estimated_runway': '2023-09-25T03:43:00+00:00',
#     'actual_runway': '2023-09-25T03:43:00+00:00'},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': '9',
#     'delay': 34,
#     'scheduled': '2023-09-25T05:15:00+00:00',
#     'estimated': '2023-09-25T05:15:00+00:00',
#     'actual': '2023-09-25T05:48:00+00:00',
#     'estimated_runway': '2023-09-25T05:48:00+00:00',
#     'actual_runway': '2023-09-25T05:48:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '164',
#     'iata': 'MH164',
#     'icao': 'MAS164',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MTG',
#     'iata': 'A333',
#     'icao': 'A333',
#     'icao24': '75025A'},
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '2',
#     'gate': None,
#     'delay': 40,
#     'scheduled': '2023-09-25T05:00:00+00:00',
#     'estimated': '2023-09-25T05:00:00+00:00',
#     'actual': '2023-09-25T05:40:00+00:00',
#     'estimated_runway': '2023-09-25T05:40:00+00:00',
#     'actual_runway': '2023-09-25T05:40:00+00:00'},
#    'arrival': {'airport': 'Francisco Bangoy International',
#     'timezone': 'Asia/Manila',
#     'iata': 'DVO',
#     'icao': 'RPMD',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 5,
#     'scheduled': '2023-09-25T07:00:00+00:00',
#     'estimated': '2023-09-25T07:00:00+00:00',
#     'actual': '2023-09-25T07:04:00+00:00',
#     'estimated_runway': '2023-09-25T07:04:00+00:00',
#     'actual_runway': '2023-09-25T07:04:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5925',
#     'iata': 'MH5925',
#     'icao': 'MAS5925',
#     'codeshared': {'airline_name': 'philippine airlines',
#      'airline_iata': 'pr',
#      'airline_icao': 'pal',
#      'flight_number': '2811',
#      'flight_iata': 'pr2811',
#      'flight_icao': 'pal2811'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Hyderabad Airport',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'HYD',
#     'icao': 'VOHS',
#     'terminal': None,
#     'gate': None,
#     'delay': 15,
#     'scheduled': '2023-09-25T00:30:00+00:00',
#     'estimated': '2023-09-25T00:30:00+00:00',
#     'actual': '2023-09-25T00:45:00+00:00',
#     'estimated_runway': '2023-09-25T00:45:00+00:00',
#     'actual_runway': '2023-09-25T00:45:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': 'E',
#     'delay': 5,
#     'scheduled': '2023-09-25T07:30:00+00:00',
#     'estimated': '2023-09-25T07:30:00+00:00',
#     'actual': '2023-09-25T07:35:00+00:00',
#     'estimated_runway': '2023-09-25T07:35:00+00:00',
#     'actual_runway': '2023-09-25T07:35:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '199',
#     'iata': 'MH199',
#     'icao': 'MAS199',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MXO',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '75020F'},
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Bangalore International Airport',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'BLR',
#     'icao': 'VOBL',
#     'terminal': '2',
#     'gate': 'C1',
#     'delay': 32,
#     'scheduled': '2023-09-25T00:35:00+00:00',
#     'estimated': '2023-09-25T00:35:00+00:00',
#     'actual': '2023-09-25T01:07:00+00:00',
#     'estimated_runway': '2023-09-25T01:07:00+00:00',
#     'actual_runway': '2023-09-25T01:07:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '6T2',
#     'delay': 22,
#     'scheduled': '2023-09-25T07:20:00+00:00',
#     'estimated': '2023-09-25T07:20:00+00:00',
#     'actual': '2023-09-25T07:42:00+00:00',
#     'estimated_runway': '2023-09-25T07:42:00+00:00',
#     'actual_runway': '2023-09-25T07:42:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '193',
#     'iata': 'MH193',
#     'icao': 'MAS193',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MXR',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '75021C'},
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Cochin International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'COK',
#     'icao': 'VOCI',
#     'terminal': '3',
#     'gate': None,
#     'delay': 23,
#     'scheduled': '2023-09-25T00:10:00+00:00',
#     'estimated': '2023-09-25T00:10:00+00:00',
#     'actual': '2023-09-25T00:32:00+00:00',
#     'estimated_runway': '2023-09-25T00:32:00+00:00',
#     'actual_runway': '2023-09-25T00:32:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 4,
#     'scheduled': '2023-09-25T06:55:00+00:00',
#     'estimated': '2023-09-25T06:55:00+00:00',
#     'actual': '2023-09-25T06:58:00+00:00',
#     'estimated_runway': '2023-09-25T06:58:00+00:00',
#     'actual_runway': '2023-09-25T06:58:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '109',
#     'iata': 'MH109',
#     'icao': 'MAS109',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MLR',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '7502B2'},
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Tan Son Nhat International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'SGN',
#     'icao': 'VVTS',
#     'terminal': '2',
#     'gate': None,
#     'delay': 83,
#     'scheduled': '2023-09-25T11:00:00+00:00',
#     'estimated': '2023-09-25T11:00:00+00:00',
#     'actual': '2023-09-25T12:23:00+00:00',
#     'estimated_runway': '2023-09-25T12:23:00+00:00',
#     'actual_runway': '2023-09-25T12:23:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 61,
#     'scheduled': '2023-09-25T13:55:00+00:00',
#     'estimated': '2023-09-25T13:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '751',
#     'iata': 'MH751',
#     'icao': 'MAS751',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Jomo Kenyatta International',
#     'timezone': 'Africa/Nairobi',
#     'iata': 'NBO',
#     'icao': 'HKJK',
#     'terminal': '1C',
#     'gate': None,
#     'delay': 62,
#     'scheduled': '2023-09-25T01:25:00+00:00',
#     'estimated': '2023-09-25T01:25:00+00:00',
#     'actual': '2023-09-25T02:26:00+00:00',
#     'estimated_runway': '2023-09-25T02:26:00+00:00',
#     'actual_runway': '2023-09-25T02:26:00+00:00'},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': '6',
#     'delay': 15,
#     'scheduled': '2023-09-25T06:50:00+00:00',
#     'estimated': '2023-09-25T06:50:00+00:00',
#     'actual': '2023-09-25T07:04:00+00:00',
#     'estimated_runway': '2023-09-25T07:04:00+00:00',
#     'actual_runway': '2023-09-25T07:04:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '9748',
#     'iata': 'MH9748',
#     'icao': 'MAS9748',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '1342',
#      'flight_iata': 'qr1342',
#      'flight_icao': 'qtr1342'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'B3',
#     'delay': 68,
#     'scheduled': '2023-09-25T09:30:00+00:00',
#     'estimated': '2023-09-25T09:30:00+00:00',
#     'actual': '2023-09-25T10:38:00+00:00',
#     'estimated_runway': '2023-09-25T10:38:00+00:00',
#     'actual_runway': '2023-09-25T10:38:00+00:00'},
#    'arrival': {'airport': 'Langakawi International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'LGK',
#     'icao': 'WMKL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 50,
#     'scheduled': '2023-09-25T10:35:00+00:00',
#     'estimated': '2023-09-25T10:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '1432',
#     'iata': 'MH1432',
#     'icao': 'MAS1432',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MSF',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '750215'},
#    'live': {'updated': '2023-09-25T03:16:00+00:00',
#     'latitude': 5.87,
#     'longitude': 99.72,
#     'altitude': 2598.42,
#     'direction': 344,
#     'speed_horizontal': 509.3,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'diverted',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': None,
#     'gate': None,
#     'delay': 206,
#     'scheduled': '2023-09-25T03:25:00+00:00',
#     'estimated': '2023-09-25T03:25:00+00:00',
#     'actual': '2023-09-25T06:50:00+00:00',
#     'estimated_runway': '2023-09-25T06:50:00+00:00',
#     'actual_runway': '2023-09-25T06:50:00+00:00'},
#    'arrival': {'airport': 'Sydney Kingsford Smith Airport',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 123,
#     'scheduled': '2023-09-25T14:40:00+00:00',
#     'estimated': '2023-09-25T14:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '6203',
#     'iata': 'MH6203',
#     'icao': 'MAS6203',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MUB',
#     'iata': 'A332',
#     'icao': 'A332',
#     'icao24': '750264'},
#    'live': {'updated': '2023-09-25T02:16:08+00:00',
#     'latitude': -20.8,
#     'longitude': 112.13,
#     'altitude': 11277.6,
#     'direction': 154,
#     'speed_horizontal': 901.924,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '2',
#     'gate': None,
#     'delay': 22,
#     'scheduled': '2023-09-25T04:00:00+00:00',
#     'estimated': '2023-09-25T04:00:00+00:00',
#     'actual': '2023-09-25T04:22:00+00:00',
#     'estimated_runway': '2023-09-25T04:22:00+00:00',
#     'actual_runway': '2023-09-25T04:22:00+00:00'},
#    'arrival': {'airport': 'Puerto Princesa',
#     'timezone': 'Asia/Manila',
#     'iata': 'PPS',
#     'icao': 'RPVP',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 3,
#     'scheduled': '2023-09-25T05:20:00+00:00',
#     'estimated': '2023-09-25T05:20:00+00:00',
#     'actual': '2023-09-25T05:22:00+00:00',
#     'estimated_runway': '2023-09-25T05:22:00+00:00',
#     'actual_runway': '2023-09-25T05:22:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5997',
#     'iata': 'MH5997',
#     'icao': 'MAS5997',
#     'codeshared': {'airline_name': 'philippine airlines',
#      'airline_iata': 'pr',
#      'airline_icao': 'pal',
#      'flight_number': '2781',
#      'flight_iata': 'pr2781',
#      'flight_icao': 'pal2781'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'C31',
#     'delay': 63,
#     'scheduled': '2023-09-25T02:00:00+00:00',
#     'estimated': '2023-09-25T02:00:00+00:00',
#     'actual': '2023-09-25T03:03:00+00:00',
#     'estimated_runway': '2023-09-25T03:03:00+00:00',
#     'actual_runway': '2023-09-25T03:03:00+00:00'},
#    'arrival': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 22,
#     'scheduled': '2023-09-25T06:05:00+00:00',
#     'estimated': '2023-09-25T06:05:00+00:00',
#     'actual': '2023-09-25T06:27:00+00:00',
#     'estimated_runway': '2023-09-25T06:27:00+00:00',
#     'actual_runway': '2023-09-25T06:27:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5912',
#     'iata': 'MH5912',
#     'icao': 'MAS5912',
#     'codeshared': {'airline_name': 'philippine airlines',
#      'airline_iata': 'pr',
#      'airline_icao': 'pal',
#      'flight_number': '530',
#      'flight_iata': 'pr530',
#      'flight_icao': 'pal530'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Suvarnabhumi International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'BKK',
#     'icao': 'VTBS',
#     'terminal': None,
#     'gate': None,
#     'delay': 29,
#     'scheduled': '2023-09-25T00:15:00+00:00',
#     'estimated': '2023-09-25T00:15:00+00:00',
#     'actual': '2023-09-25T00:44:00+00:00',
#     'estimated_runway': '2023-09-25T00:44:00+00:00',
#     'actual_runway': '2023-09-25T00:44:00+00:00'},
#    'arrival': {'airport': 'Queen Alia International',
#     'timezone': 'Asia/Amman',
#     'iata': 'AMM',
#     'icao': 'OJAI',
#     'terminal': '2',
#     'gate': '204',
#     'baggage': None,
#     'delay': 9,
#     'scheduled': '2023-09-25T04:45:00+00:00',
#     'estimated': '2023-09-25T04:45:00+00:00',
#     'actual': '2023-09-25T04:53:00+00:00',
#     'estimated_runway': '2023-09-25T04:53:00+00:00',
#     'actual_runway': '2023-09-25T04:53:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '9043',
#     'iata': 'MH9043',
#     'icao': 'MAS9043',
#     'codeshared': {'airline_name': 'royal jordanian',
#      'airline_iata': 'rj',
#      'airline_icao': 'rja',
#      'flight_number': '183',
#      'flight_iata': 'rj183',
#      'flight_icao': 'rja183'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Miri',
#     'timezone': 'Asia/Kuching',
#     'iata': 'MYY',
#     'icao': 'WBGR',
#     'terminal': None,
#     'gate': None,
#     'delay': 78,
#     'scheduled': '2023-09-25T06:00:00+00:00',
#     'estimated': '2023-09-25T06:00:00+00:00',
#     'actual': '2023-09-25T07:17:00+00:00',
#     'estimated_runway': '2023-09-25T07:17:00+00:00',
#     'actual_runway': '2023-09-25T07:17:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 52,
#     'scheduled': '2023-09-25T08:15:00+00:00',
#     'estimated': '2023-09-25T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '2551',
#     'iata': 'MH2551',
#     'icao': 'MAS2551',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Puerto Princesa',
#     'timezone': 'Asia/Manila',
#     'iata': 'PPS',
#     'icao': 'RPVP',
#     'terminal': None,
#     'gate': None,
#     'delay': 14,
#     'scheduled': '2023-09-25T06:00:00+00:00',
#     'estimated': '2023-09-25T06:00:00+00:00',
#     'actual': '2023-09-25T06:13:00+00:00',
#     'estimated_runway': '2023-09-25T06:13:00+00:00',
#     'actual_runway': '2023-09-25T06:13:00+00:00'},
#    'arrival': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 5,
#     'scheduled': '2023-09-25T07:20:00+00:00',
#     'estimated': '2023-09-25T07:20:00+00:00',
#     'actual': '2023-09-25T07:24:00+00:00',
#     'estimated_runway': '2023-09-25T07:24:00+00:00',
#     'actual_runway': '2023-09-25T07:24:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5964',
#     'iata': 'MH5964',
#     'icao': 'MAS5964',
#     'codeshared': {'airline_name': 'philippine airlines',
#      'airline_iata': 'pr',
#      'airline_icao': 'pal',
#      'flight_number': '2782',
#      'flight_iata': 'pr2782',
#      'flight_icao': 'pal2782'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Cagayan De Oro Domestic Airport',
#     'timezone': 'Asia/Manila',
#     'iata': 'CGY',
#     'icao': 'RPMY',
#     'terminal': None,
#     'gate': None,
#     'delay': 30,
#     'scheduled': '2023-09-25T06:30:00+00:00',
#     'estimated': '2023-09-25T06:30:00+00:00',
#     'actual': '2023-09-25T07:00:00+00:00',
#     'estimated_runway': '2023-09-25T07:00:00+00:00',
#     'actual_runway': '2023-09-25T07:00:00+00:00'},
#    'arrival': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 5,
#     'scheduled': '2023-09-25T08:05:00+00:00',
#     'estimated': '2023-09-25T08:05:00+00:00',
#     'actual': '2023-09-25T08:09:00+00:00',
#     'estimated_runway': '2023-09-25T08:09:00+00:00',
#     'actual_runway': '2023-09-25T08:09:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5940',
#     'iata': 'MH5940',
#     'icao': 'MAS5940',
#     'codeshared': {'airline_name': 'philippine airlines',
#      'airline_iata': 'pr',
#      'airline_icao': 'pal',
#      'flight_number': '2520',
#      'flight_iata': 'pr2520',
#      'flight_icao': 'pal2520'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'G4',
#     'delay': 67,
#     'scheduled': '2023-09-25T09:10:00+00:00',
#     'estimated': '2023-09-25T09:10:00+00:00',
#     'actual': '2023-09-25T10:17:00+00:00',
#     'estimated_runway': '2023-09-25T10:17:00+00:00',
#     'actual_runway': '2023-09-25T10:17:00+00:00'},
#    'arrival': {'airport': 'Mingaladon',
#     'timezone': 'Asia/Rangoon',
#     'iata': 'RGN',
#     'icao': 'VYYY',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 43,
#     'scheduled': '2023-09-25T10:25:00+00:00',
#     'estimated': '2023-09-25T10:25:00+00:00',
#     'actual': '2023-09-25T11:08:00+00:00',
#     'estimated_runway': '2023-09-25T11:08:00+00:00',
#     'actual_runway': '2023-09-25T11:08:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '740',
#     'iata': 'MH740',
#     'icao': 'MAS740',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'active',
#    'departure': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': 'B4',
#     'delay': 25,
#     'scheduled': '2023-09-25T01:50:00+00:00',
#     'estimated': '2023-09-25T01:50:00+00:00',
#     'actual': '2023-09-25T02:14:00+00:00',
#     'estimated_runway': '2023-09-25T02:14:00+00:00',
#     'actual_runway': '2023-09-25T02:14:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 3,
#     'scheduled': '2023-09-25T14:40:00+00:00',
#     'estimated': '2023-09-25T14:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '161',
#     'iata': 'MH161',
#     'icao': 'MAS161',
#     'codeshared': None},
#    'aircraft': {'registration': '9M-MTK',
#     'iata': 'A333',
#     'icao': 'A333',
#     'icao24': '75025E'},
#    'live': {'updated': '2023-09-25T01:30:58+00:00',
#     'latitude': 18.84,
#     'longitude': 69.24,
#     'altitude': 10668,
#     'direction': 111,
#     'speed_horizontal': 890.812,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'A8',
#     'delay': 33,
#     'scheduled': '2023-09-25T07:30:00+00:00',
#     'estimated': '2023-09-25T07:30:00+00:00',
#     'actual': '2023-09-25T08:02:00+00:00',
#     'estimated_runway': '2023-09-25T08:02:00+00:00',
#     'actual_runway': '2023-09-25T08:02:00+00:00'},
#    'arrival': {'airport': 'Kuching',
#     'timezone': 'Asia/Kuching',
#     'iata': 'KCH',
#     'icao': 'WBGG',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 12,
#     'scheduled': '2023-09-25T09:20:00+00:00',
#     'estimated': '2023-09-25T09:20:00+00:00',
#     'actual': '2023-09-25T09:32:00+00:00',
#     'estimated_runway': '2023-09-25T09:32:00+00:00',
#     'actual_runway': '2023-09-25T09:32:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '2542',
#     'iata': 'MH2542',
#     'icao': 'MAS2542',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'delay': 8,
#     'scheduled': '2023-09-25T06:50:00+00:00',
#     'estimated': '2023-09-25T06:50:00+00:00',
#     'actual': '2023-09-25T06:57:00+00:00',
#     'estimated_runway': '2023-09-25T06:57:00+00:00',
#     'actual_runway': '2023-09-25T06:57:00+00:00'},
#    'arrival': {'airport': 'Penang International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'PEN',
#     'icao': 'WMKP',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': 1,
#     'scheduled': '2023-09-25T07:50:00+00:00',
#     'estimated': '2023-09-25T07:50:00+00:00',
#     'actual': '2023-09-25T07:47:00+00:00',
#     'estimated_runway': '2023-09-25T07:47:00+00:00',
#     'actual_runway': '2023-09-25T07:47:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5372',
#     'iata': 'MH5372',
#     'icao': 'MAS5372',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '1424',
#      'flight_iata': 'fy1424',
#      'flight_icao': 'ffm1424'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuching',
#     'timezone': 'Asia/Kuching',
#     'iata': 'KCH',
#     'icao': 'WBGG',
#     'terminal': None,
#     'gate': None,
#     'delay': 30,
#     'scheduled': '2023-09-25T10:05:00+00:00',
#     'estimated': '2023-09-25T10:05:00+00:00',
#     'actual': '2023-09-25T10:35:00+00:00',
#     'estimated_runway': '2023-09-25T10:35:00+00:00',
#     'actual_runway': '2023-09-25T10:35:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 6,
#     'scheduled': '2023-09-25T11:55:00+00:00',
#     'estimated': '2023-09-25T11:55:00+00:00',
#     'actual': '2023-09-25T12:01:00+00:00',
#     'estimated_runway': '2023-09-25T12:01:00+00:00',
#     'actual_runway': '2023-09-25T12:01:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '2543',
#     'iata': 'MH2543',
#     'icao': 'MAS2543',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'B5',
#     'delay': 34,
#     'scheduled': '2023-09-25T01:25:00+00:00',
#     'estimated': '2023-09-25T01:25:00+00:00',
#     'actual': '2023-09-25T01:58:00+00:00',
#     'estimated_runway': '2023-09-25T01:58:00+00:00',
#     'actual_runway': '2023-09-25T01:58:00+00:00'},
#    'arrival': {'airport': 'Zurich',
#     'timezone': 'Europe/Zurich',
#     'iata': 'ZRH',
#     'icao': 'LSZH',
#     'terminal': '2',
#     'gate': None,
#     'baggage': '27',
#     'delay': 3,
#     'scheduled': '2023-09-25T08:15:00+00:00',
#     'estimated': '2023-09-25T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5806',
#     'iata': 'MH5806',
#     'icao': 'MAS5806',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '346',
#      'flight_iata': 'sq346',
#      'flight_icao': 'sia346'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'A10',
#     'delay': 17,
#     'scheduled': '2023-09-25T07:15:00+00:00',
#     'estimated': '2023-09-25T07:15:00+00:00',
#     'actual': '2023-09-25T07:31:00+00:00',
#     'estimated_runway': '2023-09-25T07:31:00+00:00',
#     'actual_runway': '2023-09-25T07:31:00+00:00'},
#    'arrival': {'airport': 'Tawau',
#     'timezone': 'Asia/Kuching',
#     'iata': 'TWU',
#     'icao': 'WBKW',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2023-09-25T10:10:00+00:00',
#     'estimated': '2023-09-25T10:10:00+00:00',
#     'actual': '2023-09-25T10:06:00+00:00',
#     'estimated_runway': '2023-09-25T10:06:00+00:00',
#     'actual_runway': '2023-09-25T10:06:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '2660',
#     'iata': 'MH2660',
#     'icao': 'MAS2660',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'A5',
#     'delay': 14,
#     'scheduled': '2023-09-25T07:20:00+00:00',
#     'estimated': '2023-09-25T07:20:00+00:00',
#     'actual': '2023-09-25T07:33:00+00:00',
#     'estimated_runway': '2023-09-25T07:33:00+00:00',
#     'actual_runway': '2023-09-25T07:33:00+00:00'},
#    'arrival': {'airport': 'Sultan Mahmood',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'TGG',
#     'icao': 'WMKN',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2023-09-25T08:10:00+00:00',
#     'estimated': '2023-09-25T08:10:00+00:00',
#     'actual': '2023-09-25T08:08:00+00:00',
#     'estimated_runway': '2023-09-25T08:08:00+00:00',
#     'actual_runway': '2023-09-25T08:08:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '1326',
#     'iata': 'MH1326',
#     'icao': 'MAS1326',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'delay': 12,
#     'scheduled': '2023-09-25T07:20:00+00:00',
#     'estimated': '2023-09-25T07:20:00+00:00',
#     'actual': '2023-09-25T07:32:00+00:00',
#     'estimated_runway': '2023-09-25T07:32:00+00:00',
#     'actual_runway': '2023-09-25T07:32:00+00:00'},
#    'arrival': {'airport': 'Penang International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'PEN',
#     'icao': 'WMKP',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': 4,
#     'scheduled': '2023-09-25T08:20:00+00:00',
#     'estimated': '2023-09-25T08:20:00+00:00',
#     'actual': '2023-09-25T08:23:00+00:00',
#     'estimated_runway': '2023-09-25T08:23:00+00:00',
#     'actual_runway': '2023-09-25T08:23:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5376',
#     'iata': 'MH5376',
#     'icao': 'MAS5376',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '1426',
#      'flight_iata': 'fy1426',
#      'flight_icao': 'ffm1426'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'delay': 11,
#     'scheduled': '2023-09-25T07:25:00+00:00',
#     'estimated': '2023-09-25T07:25:00+00:00',
#     'actual': '2023-09-25T07:35:00+00:00',
#     'estimated_runway': '2023-09-25T07:35:00+00:00',
#     'actual_runway': '2023-09-25T07:35:00+00:00'},
#    'arrival': {'airport': 'Sultan Ismail Petra',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KBR',
#     'icao': 'WMKC',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 4,
#     'scheduled': '2023-09-25T08:30:00+00:00',
#     'estimated': '2023-09-25T08:30:00+00:00',
#     'actual': '2023-09-25T08:38:00+00:00',
#     'estimated_runway': '2023-09-25T08:38:00+00:00',
#     'actual_runway': '2023-09-25T08:38:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5300',
#     'iata': 'MH5300',
#     'icao': 'MAS5300',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '1144',
#      'flight_iata': 'fy1144',
#      'flight_icao': 'ffm1144'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'active',
#    'departure': {'airport': 'Alama Iqbal International',
#     'timezone': 'Asia/Karachi',
#     'iata': 'LHE',
#     'icao': 'OPLA',
#     'terminal': 'M',
#     'gate': None,
#     'delay': 26,
#     'scheduled': '2023-09-25T07:05:00+00:00',
#     'estimated': '2023-09-25T07:05:00+00:00',
#     'actual': '2023-09-25T07:30:00+00:00',
#     'estimated_runway': '2023-09-25T07:30:00+00:00',
#     'actual_runway': '2023-09-25T07:30:00+00:00'},
#    'arrival': {'airport': 'Bandaranaike International',
#     'timezone': 'Asia/Colombo',
#     'iata': 'CMB',
#     'icao': 'VCBI',
#     'terminal': 'MAIN',
#     'gate': None,
#     'baggage': '03',
#     'delay': 3,
#     'scheduled': '2023-09-25T11:30:00+00:00',
#     'estimated': '2023-09-25T11:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '9032',
#     'iata': 'MH9032',
#     'icao': 'MAS9032',
#     'codeshared': {'airline_name': 'srilankan airlines',
#      'airline_iata': 'ul',
#      'airline_icao': 'alk',
#      'flight_number': '154',
#      'flight_iata': 'ul154',
#      'flight_icao': 'alk154'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '1',
#     'gate': '17',
#     'delay': 26,
#     'scheduled': '2023-09-25T12:40:00+00:00',
#     'estimated': '2023-09-25T12:40:00+00:00',
#     'actual': '2023-09-25T13:05:00+00:00',
#     'estimated_runway': '2023-09-25T13:05:00+00:00',
#     'actual_runway': '2023-09-25T13:05:00+00:00'},
#    'arrival': {'airport': 'Kansai International',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KIX',
#     'icao': 'RJBB',
#     'terminal': '1',
#     'gate': '41',
#     'baggage': None,
#     'delay': 5,
#     'scheduled': '2023-09-25T14:05:00+00:00',
#     'estimated': '2023-09-25T14:05:00+00:00',
#     'actual': '2023-09-25T14:09:00+00:00',
#     'estimated_runway': '2023-09-25T14:09:00+00:00',
#     'actual_runway': '2023-09-25T14:09:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '9165',
#     'iata': 'MH9165',
#     'icao': 'MAS9165',
#     'codeshared': {'airline_name': 'jal',
#      'airline_iata': 'jl',
#      'airline_icao': 'jal',
#      'flight_number': '225',
#      'flight_iata': 'jl225',
#      'flight_icao': 'jal225'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Francisco Bangoy International',
#     'timezone': 'Asia/Manila',
#     'iata': 'DVO',
#     'icao': 'RPMD',
#     'terminal': None,
#     'gate': None,
#     'delay': 37,
#     'scheduled': '2023-09-25T07:40:00+00:00',
#     'estimated': '2023-09-25T07:40:00+00:00',
#     'actual': '2023-09-25T08:17:00+00:00',
#     'estimated_runway': '2023-09-25T08:17:00+00:00',
#     'actual_runway': '2023-09-25T08:17:00+00:00'},
#    'arrival': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 3,
#     'scheduled': '2023-09-25T09:40:00+00:00',
#     'estimated': '2023-09-25T09:40:00+00:00',
#     'actual': '2023-09-25T09:42:00+00:00',
# ...
#     'terminal': '1',
#     'gate': 'H2',
#     'delay': 22,
#     'scheduled': '2023-09-25T08:55:00+00:00',
#     'estimated': '2023-09-25T08:55:00+00:00',
#     'actual': '2023-09-25T09:16:00+00:00',
#     'estimated_runway': '2023-09-25T09:16:00+00:00',
#     'actual_runway': '2023-09-25T09:16:00+00:00'},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '2',
#     'gate': None,
#     'baggage': '37',
#     'delay': 2,
#     'scheduled': '2023-09-25T09:55:00+00:00',
#     'estimated': '2023-09-25T09:55:00+00:00',
#     'actual': '2023-09-25T10:11:00+00:00',
#     'estimated_runway': '2023-09-25T10:11:00+00:00',
#     'actual_runway': '2023-09-25T10:11:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5723',
#     'iata': 'MH5723',
#     'icao': 'MAS5723',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '103',
#      'flight_iata': 'sq103',
#      'flight_icao': 'sia103'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'delay': 25,
#     'scheduled': '2023-09-25T10:00:00+00:00',
#     'estimated': '2023-09-25T10:00:00+00:00',
#     'actual': '2023-09-25T10:24:00+00:00',
#     'estimated_runway': '2023-09-25T10:24:00+00:00',
#     'actual_runway': '2023-09-25T10:24:00+00:00'},
#    'arrival': {'airport': 'Langakawi International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'LGK',
#     'icao': 'WMKL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 14,
#     'scheduled': '2023-09-25T11:15:00+00:00',
#     'estimated': '2023-09-25T11:15:00+00:00',
#     'actual': '2023-09-25T11:28:00+00:00',
#     'estimated_runway': '2023-09-25T11:28:00+00:00',
#     'actual_runway': '2023-09-25T11:28:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5362',
#     'iata': 'MH5362',
#     'icao': 'MAS5362',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '1576',
#      'flight_iata': 'fy1576',
#      'flight_icao': 'ffm1576'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Kota-Kinabalu International Airport',
#     'timezone': 'Asia/Kuching',
#     'iata': 'BKI',
#     'icao': 'WBKK',
#     'terminal': None,
#     'gate': None,
#     'delay': 62,
#     'scheduled': '2023-09-25T10:25:00+00:00',
#     'estimated': '2023-09-25T10:25:00+00:00',
#     'actual': '2023-09-25T11:27:00+00:00',
#     'estimated_runway': '2023-09-25T11:27:00+00:00',
#     'actual_runway': '2023-09-25T11:27:00+00:00'},
#    'arrival': {'airport': 'Penang International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'PEN',
#     'icao': 'WMKP',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': 36,
#     'scheduled': '2023-09-25T13:15:00+00:00',
#     'estimated': '2023-09-25T13:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '4721',
#     'iata': 'MH4721',
#     'icao': 'MAS4721',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '2851',
#      'flight_iata': 'fy2851',
#      'flight_icao': 'ffm2851'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'delay': 19,
#     'scheduled': '2023-09-25T10:15:00+00:00',
#     'estimated': '2023-09-25T10:15:00+00:00',
#     'actual': '2023-09-25T10:34:00+00:00',
#     'estimated_runway': '2023-09-25T10:34:00+00:00',
#     'actual_runway': '2023-09-25T10:34:00+00:00'},
#    'arrival': {'airport': 'Penang International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'PEN',
#     'icao': 'WMKP',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': 10,
#     'scheduled': '2023-09-25T11:15:00+00:00',
#     'estimated': '2023-09-25T11:15:00+00:00',
#     'actual': '2023-09-25T11:24:00+00:00',
#     'estimated_runway': '2023-09-25T11:24:00+00:00',
#     'actual_runway': '2023-09-25T11:24:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5396',
#     'iata': 'MH5396',
#     'icao': 'MAS5396',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '1436',
#      'flight_iata': 'fy1436',
#      'flight_icao': 'ffm1436'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Sultan Ismail Petra',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KBR',
#     'icao': 'WMKC',
#     'terminal': None,
#     'gate': None,
#     'delay': 56,
#     'scheduled': '2023-09-25T10:10:00+00:00',
#     'estimated': '2023-09-25T10:10:00+00:00',
#     'actual': '2023-09-25T11:05:00+00:00',
#     'estimated_runway': '2023-09-25T11:05:00+00:00',
#     'actual_runway': '2023-09-25T11:05:00+00:00'},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': 'L',
#     'delay': 33,
#     'scheduled': '2023-09-25T11:20:00+00:00',
#     'estimated': '2023-09-25T11:20:00+00:00',
#     'actual': '2023-09-25T11:52:00+00:00',
#     'estimated_runway': '2023-09-25T11:52:00+00:00',
#     'actual_runway': '2023-09-25T11:52:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '1385',
#     'iata': 'MH1385',
#     'icao': 'MAS1385',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'G8',
#     'delay': 31,
#     'scheduled': '2023-09-25T09:10:00+00:00',
#     'estimated': '2023-09-25T09:10:00+00:00',
#     'actual': '2023-09-25T10:19:00+00:00',
#     'estimated_runway': '2023-09-25T10:19:00+00:00',
#     'actual_runway': '2023-09-25T10:19:00+00:00'},
#    'arrival': {'airport': 'Phuket International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'HKT',
#     'icao': 'VTSP',
#     'terminal': 'I',
#     'gate': None,
#     'baggage': None,
#     'delay': 59,
#     'scheduled': '2023-09-25T09:45:00+00:00',
#     'estimated': '2023-09-25T09:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '786',
#     'iata': 'MH786',
#     'icao': 'MAS786',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'delay': 37,
#     'scheduled': '2023-09-25T09:30:00+00:00',
#     'estimated': '2023-09-25T09:30:00+00:00',
#     'actual': '2023-09-25T10:07:00+00:00',
#     'estimated_runway': '2023-09-25T10:07:00+00:00',
#     'actual_runway': '2023-09-25T10:07:00+00:00'},
#    'arrival': {'airport': 'Seletar',
#     'timezone': 'Asia/Singapore',
#     'iata': 'XSP',
#     'icao': 'WSSL',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': 18,
#     'scheduled': '2023-09-25T10:50:00+00:00',
#     'estimated': '2023-09-25T10:50:00+00:00',
#     'actual': '2023-09-25T11:07:00+00:00',
#     'estimated_runway': '2023-09-25T11:07:00+00:00',
#     'actual_runway': '2023-09-25T11:07:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5483',
#     'iata': 'MH5483',
#     'icao': 'MAS5483',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '3126',
#      'flight_iata': 'fy3126',
#      'flight_icao': 'ffm3126'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'delay': 30,
#     'scheduled': '2023-09-25T11:10:00+00:00',
#     'estimated': '2023-09-25T11:10:00+00:00',
#     'actual': '2023-09-25T11:39:00+00:00',
#     'estimated_runway': '2023-09-25T11:39:00+00:00',
#     'actual_runway': '2023-09-25T11:39:00+00:00'},
#    'arrival': {'airport': 'Penang International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'PEN',
#     'icao': 'WMKP',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': 52,
#     'scheduled': '2023-09-25T12:10:00+00:00',
#     'estimated': '2023-09-25T12:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5378',
#     'iata': 'MH5378',
#     'icao': 'MAS5378',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '1428',
#      'flight_iata': 'fy1428',
#      'flight_icao': 'ffm1428'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Suvarnabhumi International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'BKK',
#     'icao': 'VTBS',
#     'terminal': None,
#     'gate': None,
#     'delay': 21,
#     'scheduled': '2023-09-25T09:00:00+00:00',
#     'estimated': '2023-09-25T09:00:00+00:00',
#     'actual': '2023-09-25T09:21:00+00:00',
#     'estimated_runway': '2023-09-25T09:21:00+00:00',
#     'actual_runway': '2023-09-25T09:21:00+00:00'},
#    'arrival': {'airport': 'Koh Samui',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'USM',
#     'icao': 'VTSM',
#     'terminal': 'D',
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2023-09-25T10:10:00+00:00',
#     'estimated': '2023-09-25T10:10:00+00:00',
#     'actual': '2023-09-25T10:06:00+00:00',
#     'estimated_runway': '2023-09-25T10:06:00+00:00',
#     'actual_runway': '2023-09-25T10:06:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '4885',
#     'iata': 'MH4885',
#     'icao': 'MAS4885',
#     'codeshared': {'airline_name': 'bangkok airways',
#      'airline_iata': 'pg',
#      'airline_icao': 'bkp',
#      'flight_number': '125',
#      'flight_iata': 'pg125',
#      'flight_icao': 'bkp125'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Seletar',
#     'timezone': 'Asia/Singapore',
#     'iata': 'XSP',
#     'icao': 'WSSL',
#     'terminal': None,
#     'gate': None,
#     'delay': 25,
#     'scheduled': '2023-09-25T11:20:00+00:00',
#     'estimated': '2023-09-25T11:20:00+00:00',
#     'actual': '2023-09-25T11:45:00+00:00',
#     'estimated_runway': '2023-09-25T11:45:00+00:00',
#     'actual_runway': '2023-09-25T11:45:00+00:00'},
#    'arrival': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2023-09-25T12:40:00+00:00',
#     'estimated': '2023-09-25T12:40:00+00:00',
#     'actual': '2023-09-25T12:45:00+00:00',
#     'estimated_runway': '2023-09-25T12:45:00+00:00',
#     'actual_runway': '2023-09-25T12:45:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5488',
#     'iata': 'MH5488',
#     'icao': 'MAS5488',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '3127',
#      'flight_iata': 'fy3127',
#      'flight_icao': 'ffm3127'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Penang International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'PEN',
#     'icao': 'WMKP',
#     'terminal': None,
#     'gate': None,
#     'delay': 25,
#     'scheduled': '2023-09-25T11:35:00+00:00',
#     'estimated': '2023-09-25T11:35:00+00:00',
#     'actual': '2023-09-25T11:59:00+00:00',
#     'estimated_runway': '2023-09-25T11:59:00+00:00',
#     'actual_runway': '2023-09-25T11:59:00+00:00'},
#    'arrival': {'airport': 'Sultan Abdul Aziz Shah',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'SZB',
#     'icao': 'WMSA',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': 13,
#     'scheduled': '2023-09-25T12:35:00+00:00',
#     'estimated': '2023-09-25T12:35:00+00:00',
#     'actual': '2023-09-25T12:42:00+00:00',
#     'estimated_runway': '2023-09-25T12:42:00+00:00',
#     'actual_runway': '2023-09-25T12:42:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5373',
#     'iata': 'MH5373',
#     'icao': 'MAS5373',
#     'codeshared': {'airline_name': 'firefly',
#      'airline_iata': 'fy',
#      'airline_icao': 'ffm',
#      'flight_number': '1425',
#      'flight_iata': 'fy1425',
#      'flight_icao': 'ffm1425'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'A2',
#     'delay': 95,
#     'scheduled': '2023-09-25T11:35:00+00:00',
#     'estimated': '2023-09-25T11:35:00+00:00',
#     'actual': '2023-09-25T13:45:00+00:00',
#     'estimated_runway': '2023-09-25T13:45:00+00:00',
#     'actual_runway': '2023-09-25T13:45:00+00:00'},
#    'arrival': {'airport': 'Kota-Kinabalu International Airport',
#     'timezone': 'Asia/Kuching',
#     'iata': 'BKI',
#     'icao': 'WBKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': 109,
#     'scheduled': '2023-09-25T14:15:00+00:00',
#     'estimated': '2023-09-25T14:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '2646',
#     'iata': 'MH2646',
#     'icao': 'MAS2646',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-09-25',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': 'A11',
#     'delay': 50,
#     'scheduled': '2023-09-25T11:40:00+00:00',
#     'estimated': '2023-09-25T11:40:00+00:00',
#     'actual': '2023-09-25T12:29:00+00:00',
#     'estimated_runway': '2023-09-25T12:29:00+00:00',
#     'actual_runway': '2023-09-25T12:29:00+00:00'},
#    'arrival': {'airport': 'Penang International',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'PEN',
#     'icao': 'WMKP',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': 19,
#     'scheduled': '2023-09-25T12:40:00+00:00',
#     'estimated': '2023-09-25T12:40:00+00:00',
#     'actual': '2023-09-25T13:11:00+00:00',
#     'estimated_runway': '2023-09-25T13:11:00+00:00',
#     'actual_runway': '2023-09-25T13:11:00+00:00'},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '1140',
#     'iata': 'MH1140',
#     'icao': 'MAS1140',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None}]}
